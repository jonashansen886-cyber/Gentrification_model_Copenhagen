# %% [markdown]
# # Notebook 10: Manual CVR data processing for the temporal data
#
# This notebook uses the structure from notebook 9 to process the temporal data from datafordeleren and look up adresses

# %% [markdown]
# This notebook handles CVR data processing manually with data form https://datafordeler.dk/ if API solution is limited due to quota limitations. It still uses DAWA API because there is no limitation on requests

# %%
#pakages
import os
import json
import ijson
import pandas as pd
import gc

# %%
# ── CONFIG: which kommune(r) to keep when streaming the address file ──
KOMMUNE_KODER = {"101", "147"}   # Copenhagen = 101, Frederiksberg = 147

# %% [markdown]
# Import JSON files

# %%
# Stream-parse the address JSON – only keep records whose kommunekode is in KOMMUNE_KODER
# This avoids loading the entire ~10 GB file into memory.
adress_path = "../data/raw/cvr_raw/cvr_temporal/CVR_V1_Adressering_TotalDownload_json_Temporal_324.json"

cvr_adress_cph = []
with open(adress_path, "rb") as f:
    for record in ijson.items(f, "item"):
        if record.get("CVRAdresse_kommunekode") in KOMMUNE_KODER:
            cvr_adress_cph.append(record)

print(f"Kept {len(cvr_adress_cph)} address records matching KOMMUNE_KODER = {KOMMUNE_KODER}")
print(cvr_adress_cph[0].keys())
print(cvr_adress_cph[0])
# Out:
# Kept 2059045 address records matching KOMMUNE_KODER = {'147', '101'}
# dict_keys(['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn', 'CVRAdresse_adresseFritekst', 'CVRAdresse_landekode', 'CVRAdresse_postboks', 'coNavn', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2025-10-24T13:00:46.6541Z', 'AdresseringAnvendelse': 'beliggenhedsadresse', 'CVREnhedsId': '1002588', 'Adresse': None, 'CVRAdresse_vejkode': '4076', 'CVRAdresse_husnummerFra': '53', 'CVRAdresse_etagebetegnelse': None, 'CVRAdresse_doerbetegnelse': None, 'CVRAdresse_kommunekode': '101', 'CVRAdresse_kommunenavn': 'KØBENHAVN', 'CVRAdresse_postdistrikt': 'København K', 'CVRAdresse_vejnavn': 'Købmagergade', 'CVRAdresse_husnummerTil': None, 'CVRAdresse_postnummer': '1150', 'CVRAdresse_supplerendeBynavn': None, 'CVRAdresse_adresseFritekst': None, 'CVRAdresse_landekode': 'DK', 'CVRAdresse_postboks': None, 'coNavn': None, 'registreringFra': '2025-10-24T12:53:53Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '2021-04-28', 'virkningTil': '2021-10-24', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Branche_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_branche = json.load(f)
# Access records directly
print(len(cvr_branche))           # number of records
print(cvr_branche[0].keys())      # keys in each record
print(cvr_branche[0])             # first record
# Out:
# 10469872
# dict_keys(['datafordelerOpdateringstid', 'sekvens', 'CVREnhedsId', 'vaerdi', 'vaerdiTekst', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:36:16.674664Z', 'sekvens': 0, 'CVREnhedsId': '1000568', 'vaerdi': '741100', 'vaerdiTekst': 'Advokatvirksomhed', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': '2007-12-31', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Navn_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_navn = json.load(f)
# Access records directly
print(len(cvr_navn))           # number of records
print(cvr_navn[0].keys())      # keys in each record
print(cvr_navn[0])             # first record
# Out:
# 7927267
# dict_keys(['datafordelerOpdateringstid', 'CVREnhedsId', 'sekvens', 'vaerdi', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:07.258824Z', 'CVREnhedsId': '1000568', 'sekvens': 0, 'vaerdi': 'ADVOKATSELSKABET C. K. LUND. KALUNDBORG/ASNÆS ApS', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1996-12-06', 'virkningTil': '2023-12-27', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Produktionsenhed_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_produktionsenhed = json.load(f)
# Access records directly
print(len(cvr_produktionsenhed))           # number of records
print(cvr_produktionsenhed[0].keys())      # keys in each record
print(cvr_produktionsenhed[0])             # first record
# Out:
# 2876876
# dict_keys(['datafordelerOpdateringstid', 'id', 'pNummer', 'tilknyttetVirksomhedsCVRNummer', 'produktionsenhedStartdato', 'produktionsenhedOphoersdato', 'tilknyttetTilVirksomhedStartdato', 'tilknyttetTilVirksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2026-01-14T09:48:02.395821Z', 'id': '1002173', 'pNummer': 1003223258, 'tilknyttetVirksomhedsCVRNummer': 89224918, 'produktionsenhedStartdato': '1982-01-01', 'produktionsenhedOphoersdato': None, 'tilknyttetTilVirksomhedStartdato': '1982-01-01', 'tilknyttetTilVirksomhedOphoersdato': None, 'registreringFra': '2026-01-14T09:45:38Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1982-01-01', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Virksomhed_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_virksomhed = json.load(f)
# Access records directly
print(len(cvr_virksomhed))           # number of records
print(cvr_virksomhed[0].keys())      # keys in each record
print(cvr_virksomhed[0])             # first record
# Out:
# 2449807
# dict_keys(['datafordelerOpdateringstid', 'id', 'CVRNummer', 'virksomhedStartdato', 'virksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:00.989831Z', 'id': '1000568', 'CVRNummer': 16079944, 'virksomhedStartdato': '1992-01-03', 'virksomhedOphoersdato': None, 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %%
# Filtering already done during streaming load above – just confirm
print(f"cvr_adress_cph: {len(cvr_adress_cph)} records (KOMMUNE_KODER = {KOMMUNE_KODER})")
# Out:
# cvr_adress_cph: 2059045 records (KOMMUNE_KODER = {'147', '101'})

# %% [markdown]
# ### join json on cvr_adress_cph

# %%
# change "id" to "CVREnhedsId" in all datasets for easier merging later
for dataset in [cvr_adress_cph, cvr_branche, cvr_navn, cvr_produktionsenhed, cvr_virksomhed]:
    for record in dataset:
        if "id" in record:
            record["CVREnhedsId"] = record.pop("id")

# %%
# change names in datasets to not overlap

for record in cvr_navn:
    if "vaerdi" in record:
        record["navn"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdi" in record:
        record["branche_kode"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdiTekst" in record:
        record["branche_navn"] = record.pop("vaerdiTekst")

# %%
# cvr_adress was never loaded fully – nothing to free.
# cvr_adress_cph is the only address data in memory.
gc.collect()
print("Memory OK – only filtered addresses in memory")
# Out:
# Memory OK – only filtered addresses in memory

# %%
# join the datasets on "CVREnhedsId" to create a master dataset for Copenhagen
# Memory-efficient: build each lookup and free the source list immediately



def to_lookup(dataset):
    lookup = {}
    for r in dataset:
        eid = r.get("CVREnhedsId")
        if eid is not None:
            lookup[eid] = {k: v for k, v in r.items() if k != "CVREnhedsId"}
    return lookup

# Build lookups one at a time, freeing each source list after
branche_lkp = to_lookup(cvr_branche)
del cvr_branche; gc.collect()

navn_lkp = to_lookup(cvr_navn)
del cvr_navn; gc.collect()

prod_lkp = to_lookup(cvr_produktionsenhed)
del cvr_produktionsenhed; gc.collect()

virk_lkp = to_lookup(cvr_virksomhed)
del cvr_virksomhed; gc.collect()

print("Lookups built, source lists freed")

# Start from cvr_adress_cph and left-join the others
joined_cph = []
for rec in cvr_adress_cph:
    eid = rec.get("CVREnhedsId")
    merged = dict(rec)
    merged.update(branche_lkp.get(eid, {}))
    merged.update(navn_lkp.get(eid, {}))
    merged.update(prod_lkp.get(eid, {}))
    merged.update(virk_lkp.get(eid, {}))
    joined_cph.append(merged)

# Free lookups and the address list now that join is done
del branche_lkp, navn_lkp, prod_lkp, virk_lkp, cvr_adress_cph
gc.collect()

print(f"joined_cph: {len(joined_cph)} records, {len(joined_cph[0].keys())} columns")
print(f"Sample keys: {list(joined_cph[0].keys())[:15]}")
# Out:
# Lookups built, source lists freed
# joined_cph: 2059045 records, 34 columns
# Sample keys: ['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn']

# %%
# filter objects to only include certain feautures for easier handling later
features_to_keep = [
    "CVREnhedsId",
    "Adresse",
    "branche_kode",
    "branche_navn",
    "navn",
    "CVRNummer",
    "virksomhedStartdato",
    "virksomhedOphoersdato",
    "pNummer",
    "tilknyttetVirksomhedsCVRNummer",
    "produktionsenhedStartdato",
    "produktionsenhedOphoersdato",
]

# %%
# filter joined_cph to only include features in features_to_keep
joined_cph = [
    {k: v for k, v in rec.items() if k in features_to_keep}
    for rec in joined_cph
]

# count how many unique keys appear across all records
all_keys = set()
for rec in joined_cph:
    all_keys.update(rec.keys())
print(f"Filtered to {len(all_keys)} unique features across {len(joined_cph)} records")
print(f"Features present: {sorted(all_keys)}")
# Out:
# Filtered to 12 unique features across 2059045 records
# Features present: ['Adresse', 'CVREnhedsId', 'CVRNummer', 'branche_kode', 'branche_navn', 'navn', 'pNummer', 'produktionsenhedOphoersdato', 'produktionsenhedStartdato', 'tilknyttetVirksomhedsCVRNummer', 'virksomhedOphoersdato', 'virksomhedStartdato']

# %%
# Save joined_cph to disk so we can skip cells 1-18 on future runs
out_path = os.path.join("..", "data", "processed",  "temporal_join_cph.json")
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(joined_cph, f, ensure_ascii=False)
print(f"Saved {len(joined_cph)} records to {out_path}")
# Out:
# Saved 2059045 records to ..\data\processed\temporal_join_cph.json

# %%
# Delete everything no longer needed
for _var in ["joined_cph", "all_keys", "dataset", "eid", "f",
             "merged", "rec", "record"]:
    if _var in dir():
        exec(f"del {_var}")
gc.collect()

# Reload only what downstream cells need
with open(os.path.join("..", "data", "processed", "temporal_join_cph.json"), "r", encoding="utf-8") as f:
    joined_cph = json.load(f)

print(f"RAM cleared & reloaded joined_cph ({len(joined_cph)} records)")
# Out:
# RAM cleared & reloaded joined_cph (2059045 records)

# %%
# group production units by their parent virksomhed CVRNummer
from collections import defaultdict

grouped = defaultdict(lambda: {"virksomhed": {}, "produktionsenheder": []})

for rec in joined_cph:
    cvr_nr = rec.get("CVRNummer") or rec.get("tilknyttetVirksomhedsCVRNummer")
    if cvr_nr is None:
        continue

    # store virksomhed-level fields once
    if not grouped[cvr_nr]["virksomhed"]:
        grouped[cvr_nr]["virksomhed"] = {
            "CVRNummer": cvr_nr,
            "navn": rec.get("navn"),
            "virksomhedStartdato": rec.get("virksomhedStartdato"),
            "virksomhedOphoersdato": rec.get("virksomhedOphoersdato"),
            "branche_kode": rec.get("branche_kode"),
            "branche_navn": rec.get("branche_navn"),
        }

    # append produktionsenhed info if present
    if rec.get("pNummer"):
        grouped[cvr_nr]["produktionsenheder"].append({
            "CVREnhedsId": rec.get("CVREnhedsId"),
            "Adresse": rec.get("Adresse"),
            "pNummer": rec.get("pNummer"),
            "tilknyttetVirksomhedsCVRNummer": rec.get("tilknyttetVirksomhedsCVRNummer"),
            "produktionsenhedStartdato": rec.get("produktionsenhedStartdato"),
            "produktionsenhedOphoersdato": rec.get("produktionsenhedOphoersdato"),
        })

grouped = dict(grouped)
print(f"Grouped into {len(grouped)} unique virksomheder")
# show an example with multiple produktionsenheder
example = next((v for v in grouped.values() if len(v['produktionsenheder']) > 1), None)
if example:
    print(f"\nExample virksomhed: {example['virksomhed']['navn']}")
    print(f"  CVRNummer: {example['virksomhed']['CVRNummer']}")
    print(f"  Produktionsenheder: {len(example['produktionsenheder'])}")
    for pe in example['produktionsenheder'][:3]:
        print(f"    pNummer: {pe['pNummer']}, Adresse: {pe['Adresse']}")
# Out:
# Grouped into 495113 unique virksomheder
#
# Example virksomhed: Købmagergade 53 A/S
#   CVRNummer: 89554012
#   Produktionsenheder: 2
#     pNummer: 1002821486, Adresse: None
#     pNummer: 1002821486, Adresse: None

# %%
# save grouped structure to json
output_path = "../data/processed/cvr/cvr_cph_joined_manual_temporal.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(grouped, f, ensure_ascii=False, indent=2)
print(f"Saved {len(grouped)} virksomheder to {output_path}")
# Out:
# Saved 495113 virksomheder to ../data/processed/cvr/cvr_cph_joined_manual_temporal.json

# %% [markdown]
# ## Get adresses from DAWA API

# %%
# input joined json dataset
with open("../data/processed/cvr/cvr_cph_joined_manual_temporal.json", "r", encoding="utf-8") as f:
    master_data = json.load(f)

print(f"Type: {type(master_data).__name__}, {len(master_data)} virksomheder")

# peek at the first entry
first_key = next(iter(master_data))
print(f"\nFirst CVRNummer: {first_key}")
print(json.dumps(master_data[first_key], indent=2, ensure_ascii=False))
# Out:
# Type: dict, 495113 virksomheder
#
# First CVRNummer: 89554012
# {
#   "virksomhed": {
#     "CVRNummer": 89554012,
#     "navn": "Købmagergade 53 A/S",
#     "virksomhedStartdato": "1979-12-01",
#     "virksomhedOphoersdato": null,
#     "branche_kode": "682040",
#     "branche_navn": "Udlejning af erhvervsejendomme"
#   },
#   "produktionsenheder": [
#     {
#       "CVREnhedsId": "4003245108",
#       "Adresse": null,
#       "pNummer": 1002821486,
#       "tilknyttetVirksomhedsCVRNummer": 89554012,
#       "produktionsenhedStartdato": "1979-12-01",
#       "produktionsenhedOphoersdato": null
#     },
#     {
#       "CVREnhedsId": "4003245108",
#       "Adresse": null,
#       "pNummer": 1002821486,
#       "tilknyttetVirksomhedsCVRNummer": 89554012,
#       "produktionsenhedStartdato": "1979-12-01",
#       "produktionsenhedOphoersdato": null
#     }
#   ]
# }

# %%
import aiohttp
import asyncio
import nest_asyncio
nest_asyncio.apply()
import time
import statistics

# %%
# --- CONFIG ---
MAX_VIRKSOMHEDER = None   # None = process all
CONCURRENCY = 25              # 5 concurrent = ~10 req/s (API limit)
BATCH_SIZE = 500
MAX_RETRIES = 3
TIMEOUT_SEC = 30
SAVE_INTERVAL = 5000         # auto-save progress every N PEs

sem = asyncio.Semaphore(CONCURRENCY)

# --- MONITORING ---
api_times = []
status_codes = {}
retry_count = 0

async def fetch_coordinates(session, adresse_id):
    """Single-step DAWA lookup: /adresser/{id} already returns coordinates."""
    global retry_count
    for attempt in range(MAX_RETRIES):
        try:
            async with sem:
                t_start = time.perf_counter()

                async with session.get(
                    f"https://api.dataforsyningen.dk/adresser/{adresse_id}",
                    timeout=aiohttp.ClientTimeout(total=TIMEOUT_SEC),
                ) as resp:
                    status_codes[resp.status] = status_codes.get(resp.status, 0) + 1
                    if resp.status != 200:
                        api_times.append(time.perf_counter() - t_start)
                        return None, None
                    data = await resp.json()

                koordinater = data.get("adgangsadresse", {}).get("adgangspunkt", {}).get("koordinater", [])
                api_times.append(time.perf_counter() - t_start)
                if len(koordinater) == 2:
                    return koordinater[0], koordinater[1]
                return None, None

        except (aiohttp.ClientError, asyncio.TimeoutError):
            retry_count += 1
            if attempt < MAX_RETRIES - 1:
                await asyncio.sleep(1 * (attempt + 1))
                continue
            return None, None
    return None, None


def save_checkpoint():
    """Save current master_data progress to JSON."""
    path = "../data/processed/cvr/cvr_cph_addresses.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(master_data, f, ensure_ascii=False)
    return path


async def process_all():
    pe_tasks = []
    count = 0
    for cvr_nr, entry in master_data.items():
        if MAX_VIRKSOMHEDER is not None and count >= MAX_VIRKSOMHEDER:
            break
        for pe in entry.get("produktionsenheder", []):
            adresse_id = pe.get("Adresse")
            if adresse_id:
                pe_tasks.append((pe, adresse_id))
        count += 1

    total_pe = len(pe_tasks)
    print(f"Queued {total_pe:,} PEs from {count:,} virksomheder (CONCURRENCY={CONCURRENCY})")
    print(f"Using single-step lookup (1 API call per PE instead of 2)")

    failed = 0
    connector = aiohttp.TCPConnector(limit=CONCURRENCY)
    async with aiohttp.ClientSession(connector=connector) as session:
        for batch_start in range(0, total_pe, BATCH_SIZE):
            batch = pe_tasks[batch_start : batch_start + BATCH_SIZE]
            tasks = [fetch_coordinates(session, aid) for _, aid in batch]
            results = await asyncio.gather(*tasks, return_exceptions=True)

            batch_failed = 0
            for (pe, _), result in zip(batch, results):
                if isinstance(result, Exception) or result == (None, None):
                    pe["longitude"] = None
                    pe["latitude"] = None
                    failed += 1
                    batch_failed += 1
                else:
                    pe["longitude"], pe["latitude"] = result

            done = min(batch_start + BATCH_SIZE, total_pe)
            elapsed_so_far = time.perf_counter() - t0
            avg_ms = statistics.mean(api_times) * 1000 if api_times else 0
            p50_ms = statistics.median(api_times) * 1000 if api_times else 0
            rps = done / elapsed_so_far if elapsed_so_far > 0 else 0
            eta_min = ((total_pe - done) / rps / 60) if rps > 0 else 0
            print(f"  [{done:,}/{total_pe:,}] ok:{len(batch)-batch_failed} fail:{batch_failed} | p50:{p50_ms:.0f}ms avg:{avg_ms:.0f}ms | {rps:.1f} PE/s | retries:{retry_count} | ETA:{eta_min:.1f}min")

            # auto-save checkpoint
            if done % SAVE_INTERVAL < BATCH_SIZE:
                save_checkpoint()
                print(f"    💾 checkpoint saved ({done:,} PEs)")

    return count, total_pe, failed


t0 = time.perf_counter()
count, total_pe, failed = asyncio.get_event_loop().run_until_complete(process_all())
elapsed = time.perf_counter() - t0

# final save
save_checkpoint()

print(f"\nProcessed {count:,} virksomheder, {total_pe:,} produktionsenheder in {elapsed:.1f}s ({elapsed/60:.1f}min)")
print(f"Coordinates found: {total_pe - failed:,}, failed: {failed:,}")

if api_times:
    avg_ms = statistics.mean(api_times) * 1000
    p50_ms = statistics.median(api_times) * 1000
    p95_ms = sorted(api_times)[int(len(api_times) * 0.95)] * 1000
    max_ms = max(api_times) * 1000
    rps = total_pe / elapsed
    print(f"\n--- API Rate Monitor (CONCURRENCY={CONCURRENCY}) ---")
    print(f"  Total lookups:   {len(api_times):,} (1 HTTP call each)")
    print(f"  Wall-clock:      {rps:.1f} PE/sec")
    print(f"  API latency p50: {p50_ms:.0f}ms")
    print(f"  API latency avg: {avg_ms:.0f}ms")
    print(f"  API latency p95: {p95_ms:.0f}ms")
    print(f"  API latency max: {max_ms:.0f}ms")
    print(f"  Retries used:    {retry_count} ({retry_count*100//(total_pe or 1)}% of lookups)")
    print(f"  HTTP status codes: {status_codes}")
    if retry_count > total_pe * 0.05:
        print(f"\n  ⚠ High retry rate — consider lowering CONCURRENCY to {max(3, CONCURRENCY-2)}")
    elif avg_ms < 300:
        print(f"\n  ✓ API latency healthy — could try CONCURRENCY={CONCURRENCY+5}")
# Out:
# Queued 344,579 PEs from 495,113 virksomheder (CONCURRENCY=25)
# Using single-step lookup (1 API call per PE instead of 2)
#   [500/344,579] ok:497 fail:3 | p50:39ms avg:147ms | 87.0 PE/s | retries:0 | ETA:65.9min
#   [1,000/344,579] ok:493 fail:7 | p50:39ms avg:125ms | 90.6 PE/s | retries:0 | ETA:63.2min
#   [1,500/344,579] ok:498 fail:2 | p50:39ms avg:115ms | 90.2 PE/s | retries:0 | ETA:63.4min
#   [2,000/344,579] ok:493 fail:7 | p50:39ms avg:104ms | 88.9 PE/s | retries:0 | ETA:64.2min
#   [2,500/344,579] ok:490 fail:10 | p50:39ms avg:102ms | 90.8 PE/s | retries:0 | ETA:62.8min
#   [3,000/344,579] ok:497 fail:3 | p50:39ms avg:104ms | 91.5 PE/s | retries:0 | ETA:62.2min
#   [3,500/344,579] ok:496 fail:4 | p50:38ms avg:113ms | 72.6 PE/s | retries:0 | ETA:78.3min
#   [4,000/344,579] ok:493 fail:7 | p50:39ms avg:121ms | 74.3 PE/s | retries:0 | ETA:76.4min
#   [4,500/344,579] ok:495 fail:5 | p50:39ms avg:124ms | 75.1 PE/s | retries:0 | ETA:75.5min
#   [5,000/344,579] ok:490 fail:10 | p50:39ms avg:122ms | 76.4 PE/s | retries:0 | ETA:74.0min
#     💾 checkpoint saved (5,000 PEs)
#   [5,500/344,579] ok:495 fail:5 | p50:39ms avg:119ms | 66.7 PE/s | retries:0 | ETA:84.7min
#   [6,000/344,579] ok:491 fail:9 | p50:39ms avg:116ms | 68.2 PE/s | retries:0 | ETA:82.8min
#   [6,500/344,579] ok:495 fail:5 | p50:39ms avg:115ms | 66.3 PE/s | retries:0 | ETA:85.0min
#   [7,000/344,579] ok:496 fail:4 | p50:39ms avg:113ms | 67.6 PE/s | retries:0 | ETA:83.2min
#   [7,500/344,579] ok:497 fail:3 | p50:39ms avg:111ms | 68.9 PE/s | retries:0 | ETA:81.5min
#   [8,000/344,579] ok:495 fail:5 | p50:39ms avg:109ms | 69.7 PE/s | retries:0 | ETA:80.4min
#   [8,500/344,579] ok:495 fail:5 | p50:39ms avg:109ms | 70.9 PE/s | retries:0 | ETA:79.0min
#   [9,000/344,579] ok:496 fail:4 | p50:39ms avg:110ms | 71.5 PE/s | retries:0 | ETA:78.2min
#   [9,500/344,579] ok:500 fail:0 | p50:39ms avg:111ms | 69.6 PE/s | retries:0 | ETA:80.2min
#   [10,000/344,579] ok:496 fail:4 | p50:39ms avg:113ms | 70.6 PE/s | retries:0 | ETA:79.0min
#     💾 checkpoint saved (10,000 PEs)
#   [10,500/344,579] ok:491 fail:9 | p50:39ms avg:116ms | 65.5 PE/s | retries:0 | ETA:85.0min
#   [11,000/344,579] ok:492 fail:8 | p50:39ms avg:119ms | 62.7 PE/s | retries:0 | ETA:88.6min
#   [11,500/344,579] ok:498 fail:2 | p50:39ms avg:119ms | 63.7 PE/s | retries:0 | ETA:87.2min
#   [12,000/344,579] ok:496 fail:4 | p50:39ms avg:119ms | 61.3 PE/s | retries:0 | ETA:90.4min
#   [12,500/344,579] ok:499 fail:1 | p50:39ms avg:117ms | 62.1 PE/s | retries:0 | ETA:89.1min
#   [13,000/344,579] ok:491 fail:9 | p50:39ms avg:117ms | 62.9 PE/s | retries:0 | ETA:87.8min
#   [13,500/344,579] ok:493 fail:7 | p50:39ms avg:116ms | 63.8 PE/s | retries:0 | ETA:86.5min
#   [14,000/344,579] ok:498 fail:2 | p50:39ms avg:116ms | 64.5 PE/s | retries:0 | ETA:85.4min
#   [14,500/344,579] ok:497 fail:3 | p50:39ms avg:116ms | 65.1 PE/s | retries:0 | ETA:84.5min
#   [15,000/344,579] ok:497 fail:3 | p50:39ms avg:116ms | 65.4 PE/s | retries:0 | ETA:84.0min
#     💾 checkpoint saved (15,000 PEs)
#   [15,500/344,579] ok:497 fail:3 | p50:39ms avg:115ms | 62.1 PE/s | retries:0 | ETA:88.3min
#   [16,000/344,579] ok:491 fail:9 | p50:39ms avg:114ms | 62.6 PE/s | retries:0 | ETA:87.5min
#   [16,500/344,579] ok:498 fail:2 | p50:39ms avg:112ms | 63.2 PE/s | retries:0 | ETA:86.6min
#   [17,000/344,579] ok:497 fail:3 | p50:39ms avg:110ms | 64.8 PE/s | retries:0 | ETA:84.2min
#   [17,500/344,579] ok:497 fail:3 | p50:39ms avg:108ms | 66.5 PE/s | retries:0 | ETA:82.0min
#   [18,000/344,579] ok:496 fail:4 | p50:39ms avg:106ms | 68.1 PE/s | retries:0 | ETA:79.9min
#   [18,500/344,579] ok:497 fail:3 | p50:39ms avg:104ms | 69.8 PE/s | retries:0 | ETA:77.9min
#   [19,000/344,579] ok:495 fail:5 | p50:39ms avg:103ms | 71.3 PE/s | retries:0 | ETA:76.1min
#   [19,500/344,579] ok:494 fail:6 | p50:39ms avg:101ms | 73.0 PE/s | retries:0 | ETA:74.2min
#   [20,000/344,579] ok:491 fail:9 | p50:39ms avg:100ms | 74.6 PE/s | retries:0 | ETA:72.5min
#     💾 checkpoint saved (20,000 PEs)
#   [20,500/344,579] ok:494 fail:6 | p50:39ms avg:99ms | 71.4 PE/s | retries:0 | ETA:75.7min
#   [21,000/344,579] ok:492 fail:8 | p50:39ms avg:98ms | 71.8 PE/s | retries:0 | ETA:75.1min
#   [21,500/344,579] ok:494 fail:6 | p50:39ms avg:96ms | 73.3 PE/s | retries:0 | ETA:73.5min
#   [22,000/344,579] ok:499 fail:1 | p50:39ms avg:95ms | 74.8 PE/s | retries:0 | ETA:71.9min
#   [22,500/344,579] ok:496 fail:4 | p50:39ms avg:94ms | 75.2 PE/s | retries:0 | ETA:71.4min
#   [23,000/344,579] ok:497 fail:3 | p50:39ms avg:93ms | 75.5 PE/s | retries:0 | ETA:71.0min
#   [23,500/344,579] ok:493 fail:7 | p50:39ms avg:93ms | 75.8 PE/s | retries:0 | ETA:70.6min
#   [24,000/344,579] ok:493 fail:7 | p50:39ms avg:92ms | 76.2 PE/s | retries:0 | ETA:70.1min
#   [24,500/344,579] ok:488 fail:12 | p50:39ms avg:91ms | 75.3 PE/s | retries:0 | ETA:70.8min
#   [25,000/344,579] ok:498 fail:2 | p50:39ms avg:91ms | 76.4 PE/s | retries:0 | ETA:69.7min
#     💾 checkpoint saved (25,000 PEs)
#   [25,500/344,579] ok:494 fail:6 | p50:39ms avg:91ms | 73.3 PE/s | retries:0 | ETA:72.5min
#   [26,000/344,579] ok:496 fail:4 | p50:39ms avg:90ms | 73.7 PE/s | retries:0 | ETA:72.1min
#   [26,500/344,579] ok:498 fail:2 | p50:39ms avg:89ms | 74.0 PE/s | retries:0 | ETA:71.6min
#   [27,000/344,579] ok:493 fail:7 | p50:39ms avg:89ms | 74.2 PE/s | retries:0 | ETA:71.3min
#   [27,500/344,579] ok:497 fail:3 | p50:39ms avg:88ms | 75.4 PE/s | retries:0 | ETA:70.1min
#   [28,000/344,579] ok:498 fail:2 | p50:39ms avg:87ms | 76.5 PE/s | retries:0 | ETA:68.9min
#   [28,500/344,579] ok:497 fail:3 | p50:39ms avg:87ms | 76.7 PE/s | retries:0 | ETA:68.7min
#   [29,000/344,579] ok:498 fail:2 | p50:39ms avg:86ms | 77.0 PE/s | retries:0 | ETA:68.3min
#   [29,500/344,579] ok:495 fail:5 | p50:39ms avg:86ms | 77.2 PE/s | retries:0 | ETA:68.0min
#   [30,000/344,579] ok:493 fail:7 | p50:39ms avg:85ms | 77.5 PE/s | retries:0 | ETA:67.7min
#     💾 checkpoint saved (30,000 PEs)
#   [30,500/344,579] ok:495 fail:5 | p50:39ms avg:85ms | 75.0 PE/s | retries:0 | ETA:69.8min
#   [31,000/344,579] ok:494 fail:6 | p50:39ms avg:85ms | 75.3 PE/s | retries:0 | ETA:69.4min
#   [31,500/344,579] ok:494 fail:6 | p50:39ms avg:84ms | 75.5 PE/s | retries:0 | ETA:69.1min
#   [32,000/344,579] ok:495 fail:5 | p50:39ms avg:84ms | 75.7 PE/s | retries:0 | ETA:68.8min
#   [32,500/344,579] ok:499 fail:1 | p50:39ms avg:84ms | 76.0 PE/s | retries:0 | ETA:68.5min
#   [33,000/344,579] ok:494 fail:6 | p50:39ms avg:83ms | 76.2 PE/s | retries:0 | ETA:68.1min
#   [33,500/344,579] ok:497 fail:3 | p50:39ms avg:83ms | 76.5 PE/s | retries:0 | ETA:67.8min
#   [34,000/344,579] ok:496 fail:4 | p50:39ms avg:83ms | 76.7 PE/s | retries:0 | ETA:67.5min
#   [34,500/344,579] ok:498 fail:2 | p50:39ms avg:82ms | 76.9 PE/s | retries:0 | ETA:67.2min
#   [35,000/344,579] ok:493 fail:7 | p50:39ms avg:82ms | 77.1 PE/s | retries:0 | ETA:66.9min
#     💾 checkpoint saved (35,000 PEs)
#   [35,500/344,579] ok:495 fail:5 | p50:39ms avg:81ms | 75.9 PE/s | retries:0 | ETA:67.9min
#   [36,000/344,579] ok:496 fail:4 | p50:39ms avg:81ms | 76.8 PE/s | retries:0 | ETA:67.0min
#   [36,500/344,579] ok:493 fail:7 | p50:39ms avg:80ms | 77.7 PE/s | retries:0 | ETA:66.1min
#   [37,000/344,579] ok:494 fail:6 | p50:39ms avg:80ms | 78.6 PE/s | retries:0 | ETA:65.2min
#   [37,500/344,579] ok:493 fail:7 | p50:39ms avg:79ms | 78.8 PE/s | retries:0 | ETA:65.0min
#   [38,000/344,579] ok:500 fail:0 | p50:39ms avg:79ms | 79.0 PE/s | retries:0 | ETA:64.7min
#   [38,500/344,579] ok:496 fail:4 | p50:39ms avg:79ms | 79.1 PE/s | retries:0 | ETA:64.5min
#   [39,000/344,579] ok:497 fail:3 | p50:39ms avg:78ms | 79.3 PE/s | retries:0 | ETA:64.2min
#   [39,500/344,579] ok:495 fail:5 | p50:39ms avg:78ms | 79.5 PE/s | retries:0 | ETA:64.0min
#   [40,000/344,579] ok:495 fail:5 | p50:39ms avg:78ms | 79.7 PE/s | retries:0 | ETA:63.7min
#     💾 checkpoint saved (40,000 PEs)
#   [40,500/344,579] ok:489 fail:11 | p50:39ms avg:77ms | 78.2 PE/s | retries:0 | ETA:64.8min
#   [41,000/344,579] ok:497 fail:3 | p50:39ms avg:77ms | 79.0 PE/s | retries:0 | ETA:64.1min
#   [41,500/344,579] ok:492 fail:8 | p50:39ms avg:76ms | 79.8 PE/s | retries:0 | ETA:63.3min
#   [42,000/344,579] ok:496 fail:4 | p50:39ms avg:76ms | 80.6 PE/s | retries:0 | ETA:62.5min
#   [42,500/344,579] ok:498 fail:2 | p50:39ms avg:76ms | 81.5 PE/s | retries:0 | ETA:61.8min
#   [43,000/344,579] ok:496 fail:4 | p50:39ms avg:75ms | 82.2 PE/s | retries:0 | ETA:61.1min
#   [43,500/344,579] ok:499 fail:1 | p50:39ms avg:75ms | 83.0 PE/s | retries:0 | ETA:60.4min
#   [44,000/344,579] ok:498 fail:2 | p50:39ms avg:75ms | 83.8 PE/s | retries:0 | ETA:59.8min
#   [44,500/344,579] ok:494 fail:6 | p50:39ms avg:74ms | 83.9 PE/s | retries:0 | ETA:59.6min
#   [45,000/344,579] ok:497 fail:3 | p50:39ms avg:74ms | 84.0 PE/s | retries:0 | ETA:59.4min
#     💾 checkpoint saved (45,000 PEs)
#   [45,500/344,579] ok:496 fail:4 | p50:39ms avg:74ms | 82.4 PE/s | retries:0 | ETA:60.5min
#   [46,000/344,579] ok:495 fail:5 | p50:39ms avg:74ms | 83.1 PE/s | retries:0 | ETA:59.9min
#   [46,500/344,579] ok:488 fail:12 | p50:39ms avg:74ms | 83.8 PE/s | retries:0 | ETA:59.3min
#   [47,000/344,579] ok:497 fail:3 | p50:39ms avg:74ms | 84.6 PE/s | retries:0 | ETA:58.6min
#   [47,500/344,579] ok:496 fail:4 | p50:39ms avg:73ms | 85.4 PE/s | retries:0 | ETA:58.0min
#   [48,000/344,579] ok:492 fail:8 | p50:39ms avg:73ms | 86.1 PE/s | retries:0 | ETA:57.4min
#   [48,500/344,579] ok:496 fail:4 | p50:39ms avg:73ms | 86.9 PE/s | retries:0 | ETA:56.8min
#   [49,000/344,579] ok:497 fail:3 | p50:39ms avg:72ms | 87.6 PE/s | retries:0 | ETA:56.2min
#   [49,500/344,579] ok:497 fail:3 | p50:39ms avg:72ms | 88.4 PE/s | retries:0 | ETA:55.6min
#   [50,000/344,579] ok:495 fail:5 | p50:39ms avg:72ms | 89.1 PE/s | retries:0 | ETA:55.1min
#     💾 checkpoint saved (50,000 PEs)
#   [50,500/344,579] ok:497 fail:3 | p50:39ms avg:71ms | 87.8 PE/s | retries:0 | ETA:55.8min
#   [51,000/344,579] ok:493 fail:7 | p50:39ms avg:71ms | 88.5 PE/s | retries:0 | ETA:55.3min
#   [51,500/344,579] ok:496 fail:4 | p50:39ms avg:71ms | 89.2 PE/s | retries:0 | ETA:54.7min
#   [52,000/344,579] ok:498 fail:2 | p50:39ms avg:71ms | 90.0 PE/s | retries:0 | ETA:54.2min
#   [52,500/344,579] ok:497 fail:3 | p50:39ms avg:70ms | 90.7 PE/s | retries:0 | ETA:53.7min
#   [53,000/344,579] ok:498 fail:2 | p50:39ms avg:70ms | 91.4 PE/s | retries:0 | ETA:53.2min
#   [53,500/344,579] ok:496 fail:4 | p50:39ms avg:70ms | 92.2 PE/s | retries:0 | ETA:52.6min
#   [54,000/344,579] ok:493 fail:7 | p50:39ms avg:69ms | 92.9 PE/s | retries:0 | ETA:52.1min
#   [54,500/344,579] ok:497 fail:3 | p50:39ms avg:69ms | 93.6 PE/s | retries:0 | ETA:51.7min
#   [55,000/344,579] ok:496 fail:4 | p50:39ms avg:69ms | 94.3 PE/s | retries:0 | ETA:51.2min
#     💾 checkpoint saved (55,000 PEs)
#   [55,500/344,579] ok:496 fail:4 | p50:39ms avg:69ms | 92.8 PE/s | retries:0 | ETA:51.9min
#   [56,000/344,579] ok:496 fail:4 | p50:39ms avg:69ms | 93.5 PE/s | retries:0 | ETA:51.5min
#   [56,500/344,579] ok:497 fail:3 | p50:39ms avg:68ms | 94.2 PE/s | retries:0 | ETA:51.0min
#   [57,000/344,579] ok:493 fail:7 | p50:39ms avg:68ms | 94.9 PE/s | retries:0 | ETA:50.5min
#   [57,500/344,579] ok:492 fail:8 | p50:39ms avg:68ms | 95.6 PE/s | retries:0 | ETA:50.1min
#   [58,000/344,579] ok:494 fail:6 | p50:39ms avg:68ms | 96.2 PE/s | retries:0 | ETA:49.6min
#   [58,500/344,579] ok:499 fail:1 | p50:39ms avg:67ms | 96.9 PE/s | retries:0 | ETA:49.2min
#   [59,000/344,579] ok:497 fail:3 | p50:39ms avg:67ms | 97.6 PE/s | retries:0 | ETA:48.8min
#   [59,500/344,579] ok:492 fail:8 | p50:39ms avg:67ms | 98.3 PE/s | retries:0 | ETA:48.4min
#   [60,000/344,579] ok:496 fail:4 | p50:39ms avg:67ms | 98.9 PE/s | retries:0 | ETA:47.9min
#     💾 checkpoint saved (60,000 PEs)
#   [60,500/344,579] ok:494 fail:6 | p50:39ms avg:66ms | 97.4 PE/s | retries:0 | ETA:48.6min
#   [61,000/344,579] ok:497 fail:3 | p50:39ms avg:66ms | 98.1 PE/s | retries:0 | ETA:48.2min
#   [61,500/344,579] ok:496 fail:4 | p50:39ms avg:66ms | 98.7 PE/s | retries:0 | ETA:47.8min
#   [62,000/344,579] ok:496 fail:4 | p50:39ms avg:66ms | 99.4 PE/s | retries:0 | ETA:47.4min
#   [62,500/344,579] ok:490 fail:10 | p50:39ms avg:66ms | 100.1 PE/s | retries:0 | ETA:47.0min
#   [63,000/344,579] ok:496 fail:4 | p50:39ms avg:66ms | 100.7 PE/s | retries:0 | ETA:46.6min
#   [63,500/344,579] ok:497 fail:3 | p50:39ms avg:65ms | 101.4 PE/s | retries:0 | ETA:46.2min
#   [64,000/344,579] ok:496 fail:4 | p50:39ms avg:65ms | 102.0 PE/s | retries:0 | ETA:45.8min
#   [64,500/344,579] ok:498 fail:2 | p50:39ms avg:65ms | 102.6 PE/s | retries:0 | ETA:45.5min
#   [65,000/344,579] ok:491 fail:9 | p50:39ms avg:65ms | 103.2 PE/s | retries:0 | ETA:45.1min
#     💾 checkpoint saved (65,000 PEs)
#   [65,500/344,579] ok:498 fail:2 | p50:39ms avg:65ms | 101.5 PE/s | retries:0 | ETA:45.8min
#   [66,000/344,579] ok:497 fail:3 | p50:39ms avg:65ms | 102.2 PE/s | retries:0 | ETA:45.4min
#   [66,500/344,579] ok:496 fail:4 | p50:39ms avg:65ms | 102.8 PE/s | retries:0 | ETA:45.1min
#   [67,000/344,579] ok:497 fail:3 | p50:39ms avg:65ms | 103.3 PE/s | retries:0 | ETA:44.8min
#   [67,500/344,579] ok:490 fail:10 | p50:39ms avg:65ms | 103.9 PE/s | retries:0 | ETA:44.4min
#   [68,000/344,579] ok:491 fail:9 | p50:39ms avg:64ms | 104.6 PE/s | retries:0 | ETA:44.1min
#   [68,500/344,579] ok:497 fail:3 | p50:39ms avg:64ms | 105.2 PE/s | retries:0 | ETA:43.7min
#   [69,000/344,579] ok:493 fail:7 | p50:39ms avg:64ms | 105.8 PE/s | retries:0 | ETA:43.4min
#   [69,500/344,579] ok:489 fail:11 | p50:39ms avg:64ms | 106.4 PE/s | retries:0 | ETA:43.1min
#   [70,000/344,579] ok:496 fail:4 | p50:39ms avg:64ms | 107.1 PE/s | retries:0 | ETA:42.7min
#     💾 checkpoint saved (70,000 PEs)
#   [70,500/344,579] ok:497 fail:3 | p50:39ms avg:64ms | 105.5 PE/s | retries:0 | ETA:43.3min
#   [71,000/344,579] ok:496 fail:4 | p50:39ms avg:63ms | 106.1 PE/s | retries:0 | ETA:43.0min
#   [71,500/344,579] ok:496 fail:4 | p50:39ms avg:63ms | 106.7 PE/s | retries:0 | ETA:42.7min
#   [72,000/344,579] ok:489 fail:11 | p50:39ms avg:63ms | 107.2 PE/s | retries:0 | ETA:42.4min
#   [72,500/344,579] ok:496 fail:4 | p50:39ms avg:63ms | 107.8 PE/s | retries:0 | ETA:42.1min
#   [73,000/344,579] ok:485 fail:15 | p50:39ms avg:63ms | 108.4 PE/s | retries:0 | ETA:41.8min
#   [73,500/344,579] ok:497 fail:3 | p50:39ms avg:63ms | 109.0 PE/s | retries:0 | ETA:41.5min
#   [74,000/344,579] ok:496 fail:4 | p50:39ms avg:62ms | 109.6 PE/s | retries:0 | ETA:41.1min
#   [74,500/344,579] ok:494 fail:6 | p50:39ms avg:62ms | 110.2 PE/s | retries:0 | ETA:40.8min
#   [75,000/344,579] ok:497 fail:3 | p50:39ms avg:62ms | 110.8 PE/s | retries:0 | ETA:40.6min
#     💾 checkpoint saved (75,000 PEs)
#   [75,500/344,579] ok:496 fail:4 | p50:39ms avg:62ms | 109.1 PE/s | retries:0 | ETA:41.1min
#   [76,000/344,579] ok:497 fail:3 | p50:39ms avg:62ms | 109.7 PE/s | retries:0 | ETA:40.8min
#   [76,500/344,579] ok:496 fail:4 | p50:39ms avg:62ms | 110.3 PE/s | retries:0 | ETA:40.5min
#   [77,000/344,579] ok:493 fail:7 | p50:39ms avg:62ms | 110.8 PE/s | retries:0 | ETA:40.2min
#   [77,500/344,579] ok:497 fail:3 | p50:39ms avg:61ms | 111.4 PE/s | retries:0 | ETA:40.0min
#   [78,000/344,579] ok:498 fail:2 | p50:39ms avg:61ms | 112.0 PE/s | retries:0 | ETA:39.7min
#   [78,500/344,579] ok:498 fail:2 | p50:39ms avg:61ms | 112.6 PE/s | retries:0 | ETA:39.4min
#   [79,000/344,579] ok:490 fail:10 | p50:39ms avg:61ms | 113.1 PE/s | retries:0 | ETA:39.1min
#   [79,500/344,579] ok:497 fail:3 | p50:39ms avg:61ms | 113.7 PE/s | retries:0 | ETA:38.9min
#   [80,000/344,579] ok:494 fail:6 | p50:39ms avg:61ms | 114.3 PE/s | retries:0 | ETA:38.6min
#     💾 checkpoint saved (80,000 PEs)
#   [80,500/344,579] ok:498 fail:2 | p50:39ms avg:61ms | 112.6 PE/s | retries:0 | ETA:39.1min
#   [81,000/344,579] ok:498 fail:2 | p50:39ms avg:60ms | 113.2 PE/s | retries:0 | ETA:38.8min
#   [81,500/344,579] ok:497 fail:3 | p50:39ms avg:60ms | 113.8 PE/s | retries:0 | ETA:38.5min
#   [82,000/344,579] ok:493 fail:7 | p50:39ms avg:60ms | 114.3 PE/s | retries:0 | ETA:38.3min
#   [82,500/344,579] ok:495 fail:5 | p50:39ms avg:60ms | 114.9 PE/s | retries:0 | ETA:38.0min
#   [83,000/344,579] ok:496 fail:4 | p50:39ms avg:60ms | 115.4 PE/s | retries:0 | ETA:37.8min
#   [83,500/344,579] ok:496 fail:4 | p50:39ms avg:60ms | 116.0 PE/s | retries:0 | ETA:37.5min
#   [84,000/344,579] ok:495 fail:5 | p50:39ms avg:60ms | 116.5 PE/s | retries:0 | ETA:37.3min
#   [84,500/344,579] ok:496 fail:4 | p50:39ms avg:60ms | 117.0 PE/s | retries:0 | ETA:37.0min
#   [85,000/344,579] ok:493 fail:7 | p50:39ms avg:60ms | 117.6 PE/s | retries:0 | ETA:36.8min
#     💾 checkpoint saved (85,000 PEs)
#   [85,500/344,579] ok:497 fail:3 | p50:39ms avg:59ms | 115.8 PE/s | retries:0 | ETA:37.3min
#   [86,000/344,579] ok:490 fail:10 | p50:39ms avg:59ms | 116.4 PE/s | retries:0 | ETA:37.0min
#   [86,500/344,579] ok:496 fail:4 | p50:39ms avg:59ms | 116.9 PE/s | retries:0 | ETA:36.8min
#   [87,000/344,579] ok:494 fail:6 | p50:39ms avg:59ms | 117.4 PE/s | retries:0 | ETA:36.6min
#   [87,500/344,579] ok:497 fail:3 | p50:39ms avg:59ms | 117.9 PE/s | retries:0 | ETA:36.3min
#   [88,000/344,579] ok:499 fail:1 | p50:39ms avg:59ms | 118.4 PE/s | retries:0 | ETA:36.1min
#   [88,500/344,579] ok:490 fail:10 | p50:39ms avg:59ms | 118.8 PE/s | retries:0 | ETA:35.9min
#   [89,000/344,579] ok:497 fail:3 | p50:39ms avg:59ms | 119.3 PE/s | retries:0 | ETA:35.7min
#   [89,500/344,579] ok:497 fail:3 | p50:39ms avg:59ms | 119.8 PE/s | retries:0 | ETA:35.5min
#   [90,000/344,579] ok:493 fail:7 | p50:39ms avg:59ms | 120.2 PE/s | retries:0 | ETA:35.3min
#     💾 checkpoint saved (90,000 PEs)
#   [90,500/344,579] ok:497 fail:3 | p50:39ms avg:59ms | 118.6 PE/s | retries:0 | ETA:35.7min
#   [91,000/344,579] ok:500 fail:0 | p50:39ms avg:59ms | 119.1 PE/s | retries:0 | ETA:35.5min
#   [91,500/344,579] ok:495 fail:5 | p50:39ms avg:58ms | 119.6 PE/s | retries:0 | ETA:35.3min
#   [92,000/344,579] ok:496 fail:4 | p50:39ms avg:58ms | 120.1 PE/s | retries:0 | ETA:35.0min
#   [92,500/344,579] ok:495 fail:5 | p50:39ms avg:58ms | 120.6 PE/s | retries:0 | ETA:34.8min
#   [93,000/344,579] ok:490 fail:10 | p50:39ms avg:58ms | 121.1 PE/s | retries:0 | ETA:34.6min
#   [93,500/344,579] ok:496 fail:4 | p50:39ms avg:58ms | 121.6 PE/s | retries:0 | ETA:34.4min
#   [94,000/344,579] ok:496 fail:4 | p50:39ms avg:58ms | 122.1 PE/s | retries:0 | ETA:34.2min
#   [94,500/344,579] ok:493 fail:7 | p50:39ms avg:58ms | 122.6 PE/s | retries:0 | ETA:34.0min
#   [95,000/344,579] ok:496 fail:4 | p50:39ms avg:58ms | 123.2 PE/s | retries:0 | ETA:33.8min
#     💾 checkpoint saved (95,000 PEs)
#   [95,500/344,579] ok:495 fail:5 | p50:39ms avg:58ms | 121.2 PE/s | retries:0 | ETA:34.2min
#   [96,000/344,579] ok:496 fail:4 | p50:39ms avg:58ms | 121.7 PE/s | retries:0 | ETA:34.0min
#   [96,500/344,579] ok:493 fail:7 | p50:39ms avg:58ms | 122.2 PE/s | retries:0 | ETA:33.8min
#   [97,000/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 122.7 PE/s | retries:0 | ETA:33.6min
#   [97,500/344,579] ok:493 fail:7 | p50:39ms avg:57ms | 123.2 PE/s | retries:0 | ETA:33.4min
#   [98,000/344,579] ok:498 fail:2 | p50:39ms avg:57ms | 123.7 PE/s | retries:0 | ETA:33.2min
#   [98,500/344,579] ok:491 fail:9 | p50:39ms avg:57ms | 124.2 PE/s | retries:0 | ETA:33.0min
#   [99,000/344,579] ok:497 fail:3 | p50:39ms avg:57ms | 124.6 PE/s | retries:0 | ETA:32.8min
#   [99,500/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 125.1 PE/s | retries:0 | ETA:32.6min
#   [100,000/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 125.6 PE/s | retries:0 | ETA:32.4min
#     💾 checkpoint saved (100,000 PEs)
#   [100,500/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 123.7 PE/s | retries:0 | ETA:32.9min
#   [101,000/344,579] ok:498 fail:2 | p50:39ms avg:57ms | 124.1 PE/s | retries:0 | ETA:32.7min
#   [101,500/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 124.6 PE/s | retries:0 | ETA:32.5min
#   [102,000/344,579] ok:491 fail:9 | p50:39ms avg:57ms | 125.1 PE/s | retries:0 | ETA:32.3min
#   [102,500/344,579] ok:494 fail:6 | p50:39ms avg:57ms | 125.5 PE/s | retries:0 | ETA:32.1min
#   [103,000/344,579] ok:500 fail:0 | p50:39ms avg:57ms | 125.9 PE/s | retries:0 | ETA:32.0min
#   [103,500/344,579] ok:499 fail:1 | p50:39ms avg:56ms | 126.4 PE/s | retries:0 | ETA:31.8min
#   [104,000/344,579] ok:497 fail:3 | p50:39ms avg:56ms | 126.9 PE/s | retries:0 | ETA:31.6min
#   [104,500/344,579] ok:498 fail:2 | p50:39ms avg:56ms | 127.3 PE/s | retries:0 | ETA:31.4min
#   [105,000/344,579] ok:494 fail:6 | p50:39ms avg:56ms | 127.8 PE/s | retries:0 | ETA:31.2min
#     💾 checkpoint saved (105,000 PEs)
#   [105,500/344,579] ok:489 fail:11 | p50:39ms avg:56ms | 125.8 PE/s | retries:0 | ETA:31.7min
#   [106,000/344,579] ok:494 fail:6 | p50:39ms avg:56ms | 126.3 PE/s | retries:0 | ETA:31.5min
#   [106,500/344,579] ok:495 fail:5 | p50:39ms avg:56ms | 126.8 PE/s | retries:0 | ETA:31.3min
#   [107,000/344,579] ok:497 fail:3 | p50:39ms avg:56ms | 127.2 PE/s | retries:0 | ETA:31.1min
#   [107,500/344,579] ok:493 fail:7 | p50:39ms avg:56ms | 127.7 PE/s | retries:0 | ETA:31.0min
#   [108,000/344,579] ok:495 fail:5 | p50:39ms avg:56ms | 128.1 PE/s | retries:0 | ETA:30.8min
#   [108,500/344,579] ok:490 fail:10 | p50:39ms avg:56ms | 128.5 PE/s | retries:0 | ETA:30.6min
#   [109,000/344,579] ok:497 fail:3 | p50:39ms avg:56ms | 129.0 PE/s | retries:0 | ETA:30.4min
#   [109,500/344,579] ok:494 fail:6 | p50:39ms avg:56ms | 129.5 PE/s | retries:0 | ETA:30.3min
#   [110,000/344,579] ok:492 fail:8 | p50:39ms avg:56ms | 129.9 PE/s | retries:0 | ETA:30.1min
#     💾 checkpoint saved (110,000 PEs)
#   [110,500/344,579] ok:497 fail:3 | p50:39ms avg:56ms | 128.1 PE/s | retries:0 | ETA:30.5min
#   [111,000/344,579] ok:498 fail:2 | p50:39ms avg:55ms | 128.4 PE/s | retries:0 | ETA:30.3min
#   [111,500/344,579] ok:493 fail:7 | p50:39ms avg:55ms | 128.9 PE/s | retries:0 | ETA:30.1min
#   [112,000/344,579] ok:499 fail:1 | p50:39ms avg:55ms | 129.3 PE/s | retries:0 | ETA:30.0min
#   [112,500/344,579] ok:495 fail:5 | p50:39ms avg:55ms | 129.8 PE/s | retries:0 | ETA:29.8min
#   [113,000/344,579] ok:494 fail:6 | p50:39ms avg:55ms | 130.2 PE/s | retries:0 | ETA:29.6min
#   [113,500/344,579] ok:492 fail:8 | p50:39ms avg:55ms | 130.6 PE/s | retries:0 | ETA:29.5min
#   [114,000/344,579] ok:496 fail:4 | p50:39ms avg:55ms | 131.0 PE/s | retries:0 | ETA:29.3min
#   [114,500/344,579] ok:492 fail:8 | p50:39ms avg:55ms | 131.5 PE/s | retries:0 | ETA:29.2min
#   [115,000/344,579] ok:495 fail:5 | p50:39ms avg:55ms | 131.9 PE/s | retries:0 | ETA:29.0min
#     💾 checkpoint saved (115,000 PEs)
#   [115,500/344,579] ok:497 fail:3 | p50:39ms avg:55ms | 130.2 PE/s | retries:0 | ETA:29.3min
#   [116,000/344,579] ok:494 fail:6 | p50:39ms avg:55ms | 130.6 PE/s | retries:0 | ETA:29.2min
#   [116,500/344,579] ok:497 fail:3 | p50:39ms avg:55ms | 131.1 PE/s | retries:0 | ETA:29.0min
#   [117,000/344,579] ok:497 fail:3 | p50:39ms avg:55ms | 131.5 PE/s | retries:0 | ETA:28.8min
#   [117,500/344,579] ok:494 fail:6 | p50:39ms avg:55ms | 131.9 PE/s | retries:0 | ETA:28.7min
#   [118,000/344,579] ok:497 fail:3 | p50:39ms avg:54ms | 132.3 PE/s | retries:0 | ETA:28.5min
#   [118,500/344,579] ok:494 fail:6 | p50:39ms avg:54ms | 132.8 PE/s | retries:0 | ETA:28.4min
#   [119,000/344,579] ok:494 fail:6 | p50:39ms avg:54ms | 133.2 PE/s | retries:0 | ETA:28.2min
#   [119,500/344,579] ok:498 fail:2 | p50:39ms avg:54ms | 133.6 PE/s | retries:0 | ETA:28.1min
#   [120,000/344,579] ok:495 fail:5 | p50:39ms avg:54ms | 134.1 PE/s | retries:0 | ETA:27.9min
#     💾 checkpoint saved (120,000 PEs)
#   [120,500/344,579] ok:497 fail:3 | p50:39ms avg:54ms | 132.2 PE/s | retries:0 | ETA:28.2min
#   [121,000/344,579] ok:487 fail:13 | p50:39ms avg:54ms | 132.6 PE/s | retries:0 | ETA:28.1min
#   [121,500/344,579] ok:495 fail:5 | p50:39ms avg:54ms | 132.8 PE/s | retries:0 | ETA:28.0min
#   [122,000/344,579] ok:492 fail:8 | p50:39ms avg:54ms | 133.3 PE/s | retries:0 | ETA:27.8min
#   [122,500/344,579] ok:497 fail:3 | p50:39ms avg:54ms | 133.7 PE/s | retries:0 | ETA:27.7min
#   [123,000/344,579] ok:496 fail:4 | p50:39ms avg:54ms | 134.1 PE/s | retries:0 | ETA:27.5min
#   [123,500/344,579] ok:497 fail:3 | p50:39ms avg:54ms | 134.5 PE/s | retries:0 | ETA:27.4min
#   [124,000/344,579] ok:491 fail:9 | p50:39ms avg:54ms | 134.9 PE/s | retries:0 | ETA:27.2min
#   [124,500/344,579] ok:500 fail:0 | p50:39ms avg:54ms | 135.3 PE/s | retries:0 | ETA:27.1min
#   [125,000/344,579] ok:495 fail:5 | p50:39ms avg:54ms | 135.7 PE/s | retries:0 | ETA:27.0min
#     💾 checkpoint saved (125,000 PEs)
#   [125,500/344,579] ok:494 fail:6 | p50:39ms avg:54ms | 134.3 PE/s | retries:0 | ETA:27.2min
#   [126,000/344,579] ok:496 fail:4 | p50:39ms avg:54ms | 134.6 PE/s | retries:0 | ETA:27.1min
#   [126,500/344,579] ok:496 fail:4 | p50:39ms avg:54ms | 135.0 PE/s | retries:0 | ETA:26.9min
#   [127,000/344,579] ok:498 fail:2 | p50:39ms avg:53ms | 135.4 PE/s | retries:0 | ETA:26.8min
#   [127,500/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 135.8 PE/s | retries:0 | ETA:26.6min
#   [128,000/344,579] ok:496 fail:4 | p50:39ms avg:53ms | 136.2 PE/s | retries:0 | ETA:26.5min
#   [128,500/344,579] ok:492 fail:8 | p50:39ms avg:53ms | 136.7 PE/s | retries:0 | ETA:26.4min
#   [129,000/344,579] ok:495 fail:5 | p50:39ms avg:53ms | 137.1 PE/s | retries:0 | ETA:26.2min
#   [129,500/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 137.4 PE/s | retries:0 | ETA:26.1min
#   [130,000/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 137.8 PE/s | retries:0 | ETA:26.0min
#     💾 checkpoint saved (130,000 PEs)
#   [130,500/344,579] ok:496 fail:4 | p50:39ms avg:53ms | 135.7 PE/s | retries:0 | ETA:26.3min
#   [131,000/344,579] ok:498 fail:2 | p50:39ms avg:53ms | 136.0 PE/s | retries:0 | ETA:26.2min
#   [131,500/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 136.4 PE/s | retries:0 | ETA:26.0min
#   [132,000/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 136.8 PE/s | retries:0 | ETA:25.9min
#   [132,500/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 137.1 PE/s | retries:0 | ETA:25.8min
#   [133,000/344,579] ok:495 fail:5 | p50:39ms avg:53ms | 137.5 PE/s | retries:0 | ETA:25.6min
#   [133,500/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 137.9 PE/s | retries:0 | ETA:25.5min
#   [134,000/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 138.2 PE/s | retries:0 | ETA:25.4min
#   [134,500/344,579] ok:498 fail:2 | p50:39ms avg:53ms | 138.5 PE/s | retries:0 | ETA:25.3min
#   [135,000/344,579] ok:494 fail:6 | p50:39ms avg:53ms | 138.9 PE/s | retries:0 | ETA:25.1min
#     💾 checkpoint saved (135,000 PEs)
#   [135,500/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 135.2 PE/s | retries:0 | ETA:25.8min
#   [136,000/344,579] ok:491 fail:9 | p50:39ms avg:53ms | 135.4 PE/s | retries:0 | ETA:25.7min
#   [136,500/344,579] ok:495 fail:5 | p50:39ms avg:53ms | 135.7 PE/s | retries:0 | ETA:25.5min
#   [137,000/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 136.1 PE/s | retries:0 | ETA:25.4min
#   [137,500/344,579] ok:497 fail:3 | p50:39ms avg:53ms | 136.4 PE/s | retries:0 | ETA:25.3min
#   [138,000/344,579] ok:493 fail:7 | p50:39ms avg:53ms | 136.8 PE/s | retries:0 | ETA:25.2min
#   [138,500/344,579] ok:498 fail:2 | p50:39ms avg:53ms | 137.2 PE/s | retries:0 | ETA:25.0min
#   [139,000/344,579] ok:494 fail:6 | p50:39ms avg:53ms | 137.5 PE/s | retries:0 | ETA:24.9min
#   [139,500/344,579] ok:496 fail:4 | p50:39ms avg:53ms | 137.8 PE/s | retries:0 | ETA:24.8min
#   [140,000/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 138.2 PE/s | retries:0 | ETA:24.7min
#     💾 checkpoint saved (140,000 PEs)
#   [140,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 134.7 PE/s | retries:0 | ETA:25.2min
#   [141,000/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 135.1 PE/s | retries:0 | ETA:25.1min
#   [141,500/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 135.4 PE/s | retries:0 | ETA:25.0min
#   [142,000/344,579] ok:490 fail:10 | p50:39ms avg:52ms | 135.8 PE/s | retries:0 | ETA:24.9min
#   [142,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 136.1 PE/s | retries:0 | ETA:24.7min
#   [143,000/344,579] ok:490 fail:10 | p50:39ms avg:52ms | 136.4 PE/s | retries:0 | ETA:24.6min
#   [143,500/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 136.8 PE/s | retries:0 | ETA:24.5min
#   [144,000/344,579] ok:495 fail:5 | p50:39ms avg:52ms | 137.1 PE/s | retries:0 | ETA:24.4min
#   [144,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 137.5 PE/s | retries:0 | ETA:24.3min
#   [145,000/344,579] ok:498 fail:2 | p50:39ms avg:52ms | 137.8 PE/s | retries:0 | ETA:24.1min
#     💾 checkpoint saved (145,000 PEs)
#   [145,500/344,579] ok:495 fail:5 | p50:39ms avg:52ms | 134.5 PE/s | retries:0 | ETA:24.7min
#   [146,000/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 134.9 PE/s | retries:0 | ETA:24.5min
#   [146,500/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 135.2 PE/s | retries:0 | ETA:24.4min
#   [147,000/344,579] ok:497 fail:3 | p50:39ms avg:52ms | 135.5 PE/s | retries:0 | ETA:24.3min
#   [147,500/344,579] ok:488 fail:12 | p50:39ms avg:52ms | 135.8 PE/s | retries:0 | ETA:24.2min
#   [148,000/344,579] ok:492 fail:8 | p50:39ms avg:52ms | 136.1 PE/s | retries:0 | ETA:24.1min
#   [148,500/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 136.5 PE/s | retries:0 | ETA:23.9min
#   [149,000/344,579] ok:493 fail:7 | p50:39ms avg:52ms | 136.8 PE/s | retries:0 | ETA:23.8min
#   [149,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 137.1 PE/s | retries:0 | ETA:23.7min
#   [150,000/344,579] ok:493 fail:7 | p50:39ms avg:52ms | 137.5 PE/s | retries:0 | ETA:23.6min
#     💾 checkpoint saved (150,000 PEs)
#   [150,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 134.2 PE/s | retries:0 | ETA:24.1min
#   [151,000/344,579] ok:492 fail:8 | p50:39ms avg:52ms | 134.5 PE/s | retries:0 | ETA:24.0min
#   [151,500/344,579] ok:491 fail:9 | p50:39ms avg:52ms | 134.8 PE/s | retries:0 | ETA:23.9min
#   [152,000/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 135.1 PE/s | retries:0 | ETA:23.8min
#   [152,500/344,579] ok:493 fail:7 | p50:39ms avg:52ms | 135.4 PE/s | retries:0 | ETA:23.6min
#   [153,000/344,579] ok:494 fail:6 | p50:39ms avg:52ms | 135.8 PE/s | retries:0 | ETA:23.5min
#   [153,500/344,579] ok:496 fail:4 | p50:39ms avg:52ms | 136.1 PE/s | retries:0 | ETA:23.4min
#   [154,000/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 136.4 PE/s | retries:0 | ETA:23.3min
#   [154,500/344,579] ok:496 fail:4 | p50:39ms avg:51ms | 136.6 PE/s | retries:0 | ETA:23.2min
#   [155,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 137.0 PE/s | retries:0 | ETA:23.1min
#     💾 checkpoint saved (155,000 PEs)
#   [155,500/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 133.7 PE/s | retries:0 | ETA:23.6min
#   [156,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 134.0 PE/s | retries:0 | ETA:23.5min
#   [156,500/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 134.3 PE/s | retries:0 | ETA:23.3min
#   [157,000/344,579] ok:490 fail:10 | p50:39ms avg:51ms | 134.6 PE/s | retries:0 | ETA:23.2min
#   [157,500/344,579] ok:497 fail:3 | p50:39ms avg:51ms | 134.9 PE/s | retries:0 | ETA:23.1min
#   [158,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 135.2 PE/s | retries:0 | ETA:23.0min
#   [158,500/344,579] ok:498 fail:2 | p50:39ms avg:51ms | 135.5 PE/s | retries:0 | ETA:22.9min
#   [159,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 135.8 PE/s | retries:0 | ETA:22.8min
#   [159,500/344,579] ok:491 fail:9 | p50:39ms avg:51ms | 136.0 PE/s | retries:0 | ETA:22.7min
#   [160,000/344,579] ok:489 fail:11 | p50:39ms avg:51ms | 136.3 PE/s | retries:0 | ETA:22.6min
#     💾 checkpoint saved (160,000 PEs)
#   [160,500/344,579] ok:495 fail:5 | p50:39ms avg:51ms | 133.4 PE/s | retries:0 | ETA:23.0min
#   [161,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 133.7 PE/s | retries:0 | ETA:22.9min
#   [161,500/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 134.0 PE/s | retries:0 | ETA:22.8min
#   [162,000/344,579] ok:496 fail:4 | p50:39ms avg:51ms | 134.3 PE/s | retries:0 | ETA:22.7min
#   [162,500/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 134.6 PE/s | retries:0 | ETA:22.6min
#   [163,000/344,579] ok:489 fail:11 | p50:39ms avg:51ms | 134.8 PE/s | retries:0 | ETA:22.4min
#   [163,500/344,579] ok:491 fail:9 | p50:39ms avg:51ms | 135.1 PE/s | retries:0 | ETA:22.3min
#   [164,000/344,579] ok:498 fail:2 | p50:39ms avg:51ms | 135.4 PE/s | retries:0 | ETA:22.2min
#   [164,500/344,579] ok:495 fail:5 | p50:39ms avg:51ms | 135.7 PE/s | retries:0 | ETA:22.1min
#   [165,000/344,579] ok:496 fail:4 | p50:39ms avg:51ms | 136.0 PE/s | retries:0 | ETA:22.0min
#     💾 checkpoint saved (165,000 PEs)
#   [165,500/344,579] ok:497 fail:3 | p50:39ms avg:51ms | 133.1 PE/s | retries:0 | ETA:22.4min
#   [166,000/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 133.4 PE/s | retries:0 | ETA:22.3min
#   [166,500/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 133.6 PE/s | retries:0 | ETA:22.2min
#   [167,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 133.9 PE/s | retries:0 | ETA:22.1min
#   [167,500/344,579] ok:488 fail:12 | p50:39ms avg:51ms | 134.2 PE/s | retries:0 | ETA:22.0min
#   [168,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 134.5 PE/s | retries:0 | ETA:21.9min
#   [168,500/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 134.8 PE/s | retries:0 | ETA:21.8min
#   [169,000/344,579] ok:491 fail:9 | p50:39ms avg:51ms | 135.0 PE/s | retries:0 | ETA:21.7min
#   [169,500/344,579] ok:496 fail:4 | p50:39ms avg:51ms | 135.3 PE/s | retries:0 | ETA:21.6min
#   [170,000/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 135.6 PE/s | retries:0 | ETA:21.5min
#     💾 checkpoint saved (170,000 PEs)
#   [170,500/344,579] ok:495 fail:5 | p50:39ms avg:51ms | 132.8 PE/s | retries:0 | ETA:21.8min
#   [171,000/344,579] ok:490 fail:10 | p50:39ms avg:51ms | 133.1 PE/s | retries:0 | ETA:21.7min
#   [171,500/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 133.3 PE/s | retries:0 | ETA:21.6min
#   [172,000/344,579] ok:492 fail:8 | p50:39ms avg:51ms | 133.6 PE/s | retries:0 | ETA:21.5min
#   [172,500/344,579] ok:496 fail:4 | p50:39ms avg:51ms | 133.9 PE/s | retries:0 | ETA:21.4min
#   [173,000/344,579] ok:498 fail:2 | p50:39ms avg:51ms | 134.2 PE/s | retries:0 | ETA:21.3min
#   [173,500/344,579] ok:491 fail:9 | p50:39ms avg:51ms | 134.4 PE/s | retries:0 | ETA:21.2min
#   [174,000/344,579] ok:492 fail:8 | p50:39ms avg:50ms | 134.7 PE/s | retries:0 | ETA:21.1min
#   [174,500/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 134.9 PE/s | retries:0 | ETA:21.0min
#   [175,000/344,579] ok:498 fail:2 | p50:39ms avg:51ms | 135.1 PE/s | retries:0 | ETA:20.9min
#     💾 checkpoint saved (175,000 PEs)
#   [175,500/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 132.4 PE/s | retries:0 | ETA:21.3min
#   [176,000/344,579] ok:494 fail:6 | p50:39ms avg:51ms | 132.7 PE/s | retries:0 | ETA:21.2min
#   [176,500/344,579] ok:491 fail:9 | p50:39ms avg:51ms | 133.0 PE/s | retries:0 | ETA:21.1min
#   [177,000/344,579] ok:489 fail:11 | p50:39ms avg:51ms | 133.2 PE/s | retries:0 | ETA:21.0min
#   [177,500/344,579] ok:497 fail:3 | p50:39ms avg:51ms | 133.5 PE/s | retries:0 | ETA:20.9min
#   [178,000/344,579] ok:493 fail:7 | p50:39ms avg:51ms | 133.8 PE/s | retries:0 | ETA:20.8min
#   [178,500/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 134.0 PE/s | retries:0 | ETA:20.7min
#   [179,000/344,579] ok:493 fail:7 | p50:39ms avg:50ms | 134.3 PE/s | retries:0 | ETA:20.5min
#   [179,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 134.6 PE/s | retries:0 | ETA:20.4min
#   [180,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 134.8 PE/s | retries:0 | ETA:20.4min
#     💾 checkpoint saved (180,000 PEs)
#   [180,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 132.2 PE/s | retries:0 | ETA:20.7min
#   [181,000/344,579] ok:491 fail:9 | p50:39ms avg:50ms | 132.4 PE/s | retries:0 | ETA:20.6min
#   [181,500/344,579] ok:490 fail:10 | p50:39ms avg:50ms | 132.7 PE/s | retries:0 | ETA:20.5min
#   [182,000/344,579] ok:490 fail:10 | p50:39ms avg:50ms | 133.0 PE/s | retries:0 | ETA:20.4min
#   [182,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 133.2 PE/s | retries:0 | ETA:20.3min
#   [183,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 133.5 PE/s | retries:0 | ETA:20.2min
#   [183,500/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 133.7 PE/s | retries:0 | ETA:20.1min
#   [184,000/344,579] ok:493 fail:7 | p50:39ms avg:50ms | 133.9 PE/s | retries:0 | ETA:20.0min
#   [184,500/344,579] ok:495 fail:5 | p50:39ms avg:50ms | 134.1 PE/s | retries:0 | ETA:19.9min
#   [185,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 134.4 PE/s | retries:0 | ETA:19.8min
#     💾 checkpoint saved (185,000 PEs)
#   [185,500/344,579] ok:492 fail:8 | p50:39ms avg:50ms | 131.9 PE/s | retries:0 | ETA:20.1min
#   [186,000/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 132.1 PE/s | retries:0 | ETA:20.0min
#   [186,500/344,579] ok:497 fail:3 | p50:39ms avg:50ms | 132.4 PE/s | retries:0 | ETA:19.9min
#   [187,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 132.6 PE/s | retries:0 | ETA:19.8min
#   [187,500/344,579] ok:488 fail:12 | p50:39ms avg:50ms | 132.9 PE/s | retries:0 | ETA:19.7min
#   [188,000/344,579] ok:498 fail:2 | p50:39ms avg:50ms | 133.1 PE/s | retries:0 | ETA:19.6min
#   [188,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 133.4 PE/s | retries:0 | ETA:19.5min
#   [189,000/344,579] ok:492 fail:8 | p50:39ms avg:50ms | 133.6 PE/s | retries:0 | ETA:19.4min
#   [189,500/344,579] ok:498 fail:2 | p50:39ms avg:50ms | 133.9 PE/s | retries:0 | ETA:19.3min
#   [190,000/344,579] ok:493 fail:7 | p50:39ms avg:50ms | 134.1 PE/s | retries:0 | ETA:19.2min
#     💾 checkpoint saved (190,000 PEs)
#   [190,500/344,579] ok:497 fail:3 | p50:39ms avg:50ms | 132.3 PE/s | retries:0 | ETA:19.4min
#   [191,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 132.6 PE/s | retries:0 | ETA:19.3min
#   [191,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 132.8 PE/s | retries:0 | ETA:19.2min
#   [192,000/344,579] ok:497 fail:3 | p50:39ms avg:50ms | 133.0 PE/s | retries:0 | ETA:19.1min
#   [192,500/344,579] ok:493 fail:7 | p50:39ms avg:50ms | 133.3 PE/s | retries:0 | ETA:19.0min
#   [193,000/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 133.5 PE/s | retries:0 | ETA:18.9min
#   [193,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 133.7 PE/s | retries:0 | ETA:18.8min
#   [194,000/344,579] ok:497 fail:3 | p50:39ms avg:50ms | 134.0 PE/s | retries:0 | ETA:18.7min
#   [194,500/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 134.2 PE/s | retries:0 | ETA:18.6min
#   [195,000/344,579] ok:498 fail:2 | p50:39ms avg:50ms | 134.4 PE/s | retries:0 | ETA:18.5min
#     💾 checkpoint saved (195,000 PEs)
#   [195,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 132.9 PE/s | retries:0 | ETA:18.7min
#   [196,000/344,579] ok:497 fail:3 | p50:39ms avg:50ms | 133.1 PE/s | retries:0 | ETA:18.6min
#   [196,500/344,579] ok:496 fail:4 | p50:39ms avg:50ms | 133.4 PE/s | retries:0 | ETA:18.5min
#   [197,000/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 133.6 PE/s | retries:0 | ETA:18.4min
#   [197,500/344,579] ok:491 fail:9 | p50:39ms avg:50ms | 133.9 PE/s | retries:0 | ETA:18.3min
#   [198,000/344,579] ok:490 fail:10 | p50:39ms avg:50ms | 134.1 PE/s | retries:0 | ETA:18.2min
#   [198,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 134.3 PE/s | retries:0 | ETA:18.1min
#   [199,000/344,579] ok:491 fail:9 | p50:39ms avg:50ms | 134.6 PE/s | retries:0 | ETA:18.0min
#   [199,500/344,579] ok:495 fail:5 | p50:39ms avg:50ms | 134.8 PE/s | retries:0 | ETA:17.9min
#   [200,000/344,579] ok:498 fail:2 | p50:39ms avg:50ms | 135.1 PE/s | retries:0 | ETA:17.8min
#     💾 checkpoint saved (200,000 PEs)
#   [200,500/344,579] ok:490 fail:10 | p50:39ms avg:50ms | 134.3 PE/s | retries:0 | ETA:17.9min
#   [201,000/344,579] ok:499 fail:1 | p50:39ms avg:50ms | 134.5 PE/s | retries:0 | ETA:17.8min
#   [201,500/344,579] ok:495 fail:5 | p50:39ms avg:50ms | 134.7 PE/s | retries:0 | ETA:17.7min
#   [202,000/344,579] ok:498 fail:2 | p50:39ms avg:50ms | 135.0 PE/s | retries:0 | ETA:17.6min
#   [202,500/344,579] ok:490 fail:10 | p50:39ms avg:50ms | 135.2 PE/s | retries:0 | ETA:17.5min
#   [203,000/344,579] ok:495 fail:5 | p50:39ms avg:50ms | 135.5 PE/s | retries:0 | ETA:17.4min
#   [203,500/344,579] ok:494 fail:6 | p50:39ms avg:50ms | 135.7 PE/s | retries:0 | ETA:17.3min
#   [204,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 136.0 PE/s | retries:0 | ETA:17.2min
#   [204,500/344,579] ok:493 fail:7 | p50:39ms avg:49ms | 136.2 PE/s | retries:0 | ETA:17.1min
#   [205,000/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 136.5 PE/s | retries:0 | ETA:17.0min
#     💾 checkpoint saved (205,000 PEs)
#   [205,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 135.6 PE/s | retries:0 | ETA:17.1min
#   [206,000/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 135.8 PE/s | retries:0 | ETA:17.0min
#   [206,500/344,579] ok:492 fail:8 | p50:39ms avg:49ms | 136.1 PE/s | retries:0 | ETA:16.9min
#   [207,000/344,579] ok:488 fail:12 | p50:39ms avg:49ms | 136.3 PE/s | retries:0 | ETA:16.8min
#   [207,500/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 136.5 PE/s | retries:0 | ETA:16.7min
#   [208,000/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 136.8 PE/s | retries:0 | ETA:16.6min
#   [208,500/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 137.0 PE/s | retries:0 | ETA:16.6min
#   [209,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 137.3 PE/s | retries:0 | ETA:16.5min
#   [209,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 137.5 PE/s | retries:0 | ETA:16.4min
#   [210,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 137.7 PE/s | retries:0 | ETA:16.3min
#     💾 checkpoint saved (210,000 PEs)
#   [210,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 136.7 PE/s | retries:0 | ETA:16.3min
#   [211,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 136.9 PE/s | retries:0 | ETA:16.3min
#   [211,500/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 137.2 PE/s | retries:0 | ETA:16.2min
#   [212,000/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 137.4 PE/s | retries:0 | ETA:16.1min
#   [212,500/344,579] ok:492 fail:8 | p50:39ms avg:49ms | 137.6 PE/s | retries:0 | ETA:16.0min
#   [213,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 137.9 PE/s | retries:0 | ETA:15.9min
#   [213,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 138.0 PE/s | retries:0 | ETA:15.8min
#   [214,000/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 138.2 PE/s | retries:0 | ETA:15.7min
#   [214,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 138.5 PE/s | retries:0 | ETA:15.7min
#   [215,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 138.7 PE/s | retries:0 | ETA:15.6min
#     💾 checkpoint saved (215,000 PEs)
#   [215,500/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 137.8 PE/s | retries:0 | ETA:15.6min
#   [216,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 138.0 PE/s | retries:0 | ETA:15.5min
#   [216,500/344,579] ok:493 fail:7 | p50:39ms avg:49ms | 138.3 PE/s | retries:0 | ETA:15.4min
#   [217,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 138.5 PE/s | retries:0 | ETA:15.4min
#   [217,500/344,579] ok:499 fail:1 | p50:39ms avg:49ms | 138.7 PE/s | retries:0 | ETA:15.3min
#   [218,000/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 138.9 PE/s | retries:0 | ETA:15.2min
#   [218,500/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 139.1 PE/s | retries:0 | ETA:15.1min
#   [219,000/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.4 PE/s | retries:0 | ETA:15.0min
#   [219,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 139.6 PE/s | retries:0 | ETA:14.9min
#   [220,000/344,579] ok:499 fail:1 | p50:39ms avg:49ms | 139.8 PE/s | retries:0 | ETA:14.8min
#     💾 checkpoint saved (220,000 PEs)
#   [220,500/344,579] ok:499 fail:1 | p50:39ms avg:49ms | 138.8 PE/s | retries:0 | ETA:14.9min
#   [221,000/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 139.0 PE/s | retries:0 | ETA:14.8min
#   [221,500/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 139.2 PE/s | retries:0 | ETA:14.7min
#   [222,000/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.5 PE/s | retries:0 | ETA:14.6min
#   [222,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.7 PE/s | retries:0 | ETA:14.6min
#   [223,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 139.9 PE/s | retries:0 | ETA:14.5min
#   [223,500/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 140.1 PE/s | retries:0 | ETA:14.4min
#   [224,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 140.4 PE/s | retries:0 | ETA:14.3min
#   [224,500/344,579] ok:493 fail:7 | p50:39ms avg:49ms | 140.6 PE/s | retries:0 | ETA:14.2min
#   [225,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 140.8 PE/s | retries:0 | ETA:14.2min
#     💾 checkpoint saved (225,000 PEs)
#   [225,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 138.7 PE/s | retries:0 | ETA:14.3min
#   [226,000/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 138.9 PE/s | retries:0 | ETA:14.2min
#   [226,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 139.0 PE/s | retries:0 | ETA:14.2min
#   [227,000/344,579] ok:494 fail:6 | p50:39ms avg:49ms | 139.2 PE/s | retries:0 | ETA:14.1min
#   [227,500/344,579] ok:492 fail:8 | p50:39ms avg:49ms | 139.4 PE/s | retries:0 | ETA:14.0min
#   [228,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 139.6 PE/s | retries:0 | ETA:13.9min
#   [228,500/344,579] ok:500 fail:0 | p50:39ms avg:49ms | 139.8 PE/s | retries:0 | ETA:13.8min
#   [229,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 140.0 PE/s | retries:0 | ETA:13.8min
#   [229,500/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 140.2 PE/s | retries:0 | ETA:13.7min
#   [230,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 140.4 PE/s | retries:0 | ETA:13.6min
#     💾 checkpoint saved (230,000 PEs)
#   [230,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 138.1 PE/s | retries:0 | ETA:13.8min
#   [231,000/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 138.3 PE/s | retries:0 | ETA:13.7min
#   [231,500/344,579] ok:499 fail:1 | p50:39ms avg:49ms | 138.5 PE/s | retries:0 | ETA:13.6min
#   [232,000/344,579] ok:496 fail:4 | p50:39ms avg:49ms | 138.7 PE/s | retries:0 | ETA:13.5min
#   [232,500/344,579] ok:497 fail:3 | p50:39ms avg:49ms | 138.9 PE/s | retries:0 | ETA:13.4min
#   [233,000/344,579] ok:495 fail:5 | p50:39ms avg:49ms | 139.1 PE/s | retries:0 | ETA:13.4min
#   [233,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.3 PE/s | retries:0 | ETA:13.3min
#   [234,000/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.5 PE/s | retries:0 | ETA:13.2min
#   [234,500/344,579] ok:498 fail:2 | p50:39ms avg:49ms | 139.7 PE/s | retries:0 | ETA:13.1min
#   [235,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 139.9 PE/s | retries:0 | ETA:13.1min
#     💾 checkpoint saved (235,000 PEs)
#   [235,500/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 137.6 PE/s | retries:0 | ETA:13.2min
#   [236,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 137.8 PE/s | retries:0 | ETA:13.1min
#   [236,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 138.0 PE/s | retries:0 | ETA:13.1min
#   [237,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 138.2 PE/s | retries:0 | ETA:13.0min
#   [237,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 138.4 PE/s | retries:0 | ETA:12.9min
#   [238,000/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 138.6 PE/s | retries:0 | ETA:12.8min
#   [238,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 138.8 PE/s | retries:0 | ETA:12.7min
#   [239,000/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 139.0 PE/s | retries:0 | ETA:12.7min
#   [239,500/344,579] ok:494 fail:6 | p50:39ms avg:48ms | 139.2 PE/s | retries:0 | ETA:12.6min
#   [240,000/344,579] ok:492 fail:8 | p50:39ms avg:48ms | 139.4 PE/s | retries:0 | ETA:12.5min
#     💾 checkpoint saved (240,000 PEs)
#   [240,500/344,579] ok:494 fail:6 | p50:39ms avg:48ms | 137.2 PE/s | retries:0 | ETA:12.6min
#   [241,000/344,579] ok:494 fail:6 | p50:39ms avg:48ms | 137.4 PE/s | retries:0 | ETA:12.6min
#   [241,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 137.5 PE/s | retries:0 | ETA:12.5min
#   [242,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 137.7 PE/s | retries:0 | ETA:12.4min
#   [242,500/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 137.9 PE/s | retries:0 | ETA:12.3min
#   [243,000/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 138.1 PE/s | retries:0 | ETA:12.3min
#   [243,500/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 138.3 PE/s | retries:0 | ETA:12.2min
#   [244,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 138.5 PE/s | retries:0 | ETA:12.1min
#   [244,500/344,579] ok:494 fail:6 | p50:39ms avg:48ms | 138.7 PE/s | retries:0 | ETA:12.0min
#   [245,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 138.8 PE/s | retries:0 | ETA:12.0min
#     💾 checkpoint saved (245,000 PEs)
#   [245,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 136.8 PE/s | retries:0 | ETA:12.1min
#   [246,000/344,579] ok:493 fail:7 | p50:39ms avg:48ms | 136.9 PE/s | retries:0 | ETA:12.0min
#   [246,500/344,579] ok:491 fail:9 | p50:39ms avg:48ms | 137.1 PE/s | retries:0 | ETA:11.9min
#   [247,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 137.3 PE/s | retries:0 | ETA:11.8min
#   [247,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 137.5 PE/s | retries:0 | ETA:11.8min
#   [248,000/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 137.7 PE/s | retries:0 | ETA:11.7min
#   [248,500/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 137.9 PE/s | retries:0 | ETA:11.6min
#   [249,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 138.1 PE/s | retries:0 | ETA:11.5min
# ...
#   [264,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 136.6 PE/s | retries:0 | ETA:9.8min
#   [265,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 136.8 PE/s | retries:0 | ETA:9.7min
#     💾 checkpoint saved (265,000 PEs)
#   [265,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 135.0 PE/s | retries:0 | ETA:9.8min
#   [266,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.2 PE/s | retries:0 | ETA:9.7min
#   [266,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.3 PE/s | retries:0 | ETA:9.6min
#   [267,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 135.5 PE/s | retries:0 | ETA:9.5min
#   [267,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.7 PE/s | retries:0 | ETA:9.5min
#   [268,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.8 PE/s | retries:0 | ETA:9.4min
#   [268,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 136.0 PE/s | retries:0 | ETA:9.3min
#   [269,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 136.1 PE/s | retries:0 | ETA:9.3min
#   [269,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 136.2 PE/s | retries:0 | ETA:9.2min
#   [270,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 136.3 PE/s | retries:0 | ETA:9.1min
#     💾 checkpoint saved (270,000 PEs)
#   [270,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.4 PE/s | retries:0 | ETA:9.2min
#   [271,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.5 PE/s | retries:0 | ETA:9.1min
#   [271,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.7 PE/s | retries:0 | ETA:9.0min
#   [272,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.9 PE/s | retries:0 | ETA:9.0min
#   [272,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.0 PE/s | retries:0 | ETA:8.9min
#   [273,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.2 PE/s | retries:0 | ETA:8.8min
#   [273,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 135.4 PE/s | retries:0 | ETA:8.8min
#   [274,000/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 135.5 PE/s | retries:0 | ETA:8.7min
#   [274,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.7 PE/s | retries:0 | ETA:8.6min
#   [275,000/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 135.8 PE/s | retries:0 | ETA:8.5min
#     💾 checkpoint saved (275,000 PEs)
#   [275,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.0 PE/s | retries:0 | ETA:8.6min
#   [276,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.2 PE/s | retries:0 | ETA:8.5min
#   [276,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.3 PE/s | retries:0 | ETA:8.4min
#   [277,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.5 PE/s | retries:0 | ETA:8.4min
#   [277,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.7 PE/s | retries:0 | ETA:8.3min
#   [278,000/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 134.8 PE/s | retries:0 | ETA:8.2min
#   [278,500/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 135.0 PE/s | retries:0 | ETA:8.2min
#   [279,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 135.2 PE/s | retries:0 | ETA:8.1min
#   [279,500/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 135.3 PE/s | retries:0 | ETA:8.0min
#   [280,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.4 PE/s | retries:0 | ETA:7.9min
#     💾 checkpoint saved (280,000 PEs)
#   [280,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 133.6 PE/s | retries:0 | ETA:8.0min
#   [281,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 133.7 PE/s | retries:0 | ETA:7.9min
#   [281,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 133.9 PE/s | retries:0 | ETA:7.9min
#   [282,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.1 PE/s | retries:0 | ETA:7.8min
#   [282,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.2 PE/s | retries:0 | ETA:7.7min
#   [283,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 134.4 PE/s | retries:0 | ETA:7.6min
#   [283,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.5 PE/s | retries:0 | ETA:7.6min
#   [284,000/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 134.6 PE/s | retries:0 | ETA:7.5min
#   [284,500/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 134.8 PE/s | retries:0 | ETA:7.4min
#   [285,000/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 134.9 PE/s | retries:0 | ETA:7.4min
#     💾 checkpoint saved (285,000 PEs)
#   [285,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.0 PE/s | retries:0 | ETA:7.3min
#   [286,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.2 PE/s | retries:0 | ETA:7.3min
#   [286,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 134.3 PE/s | retries:0 | ETA:7.2min
#   [287,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.5 PE/s | retries:0 | ETA:7.1min
#   [287,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.7 PE/s | retries:0 | ETA:7.1min
#   [288,000/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 134.8 PE/s | retries:0 | ETA:7.0min
#   [288,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.0 PE/s | retries:0 | ETA:6.9min
#   [289,000/344,579] ok:495 fail:5 | p50:39ms avg:48ms | 135.2 PE/s | retries:0 | ETA:6.9min
#   [289,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.3 PE/s | retries:0 | ETA:6.8min
#   [290,000/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 135.5 PE/s | retries:0 | ETA:6.7min
#     💾 checkpoint saved (290,000 PEs)
#   [290,500/344,579] ok:497 fail:3 | p50:39ms avg:48ms | 134.9 PE/s | retries:0 | ETA:6.7min
#   [291,000/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 135.0 PE/s | retries:0 | ETA:6.6min
#   [291,500/344,579] ok:496 fail:4 | p50:39ms avg:48ms | 135.2 PE/s | retries:0 | ETA:6.5min
#   [292,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.3 PE/s | retries:0 | ETA:6.5min
#   [292,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 135.5 PE/s | retries:0 | ETA:6.4min
#   [293,000/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 135.7 PE/s | retries:0 | ETA:6.3min
#   [293,500/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 135.8 PE/s | retries:0 | ETA:6.3min
#   [294,000/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 136.0 PE/s | retries:0 | ETA:6.2min
#   [294,500/344,579] ok:500 fail:0 | p50:39ms avg:48ms | 136.1 PE/s | retries:0 | ETA:6.1min
#   [295,000/344,579] ok:499 fail:1 | p50:39ms avg:48ms | 136.3 PE/s | retries:0 | ETA:6.1min
#     💾 checkpoint saved (295,000 PEs)
#   [295,500/344,579] ok:498 fail:2 | p50:39ms avg:48ms | 134.5 PE/s | retries:0 | ETA:6.1min
#   [296,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.7 PE/s | retries:0 | ETA:6.0min
#   [296,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.8 PE/s | retries:0 | ETA:5.9min
#   [297,000/344,579] ok:496 fail:4 | p50:39ms avg:47ms | 135.0 PE/s | retries:0 | ETA:5.9min
#   [297,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 135.1 PE/s | retries:0 | ETA:5.8min
#   [298,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 135.3 PE/s | retries:0 | ETA:5.7min
#   [298,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 135.4 PE/s | retries:0 | ETA:5.7min
#   [299,000/344,579] ok:497 fail:3 | p50:39ms avg:47ms | 135.6 PE/s | retries:0 | ETA:5.6min
#   [299,500/344,579] ok:496 fail:4 | p50:39ms avg:47ms | 135.7 PE/s | retries:0 | ETA:5.5min
#   [300,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 135.8 PE/s | retries:0 | ETA:5.5min
#     💾 checkpoint saved (300,000 PEs)
#   [300,500/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.1 PE/s | retries:0 | ETA:5.5min
#   [301,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.3 PE/s | retries:0 | ETA:5.4min
#   [301,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.4 PE/s | retries:0 | ETA:5.3min
#   [302,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.5 PE/s | retries:0 | ETA:5.3min
#   [302,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 134.7 PE/s | retries:0 | ETA:5.2min
#   [303,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.8 PE/s | retries:0 | ETA:5.1min
#   [303,500/344,579] ok:497 fail:3 | p50:39ms avg:47ms | 135.0 PE/s | retries:0 | ETA:5.1min
#   [304,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 135.1 PE/s | retries:0 | ETA:5.0min
#   [304,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 135.2 PE/s | retries:0 | ETA:4.9min
#   [305,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 135.4 PE/s | retries:0 | ETA:4.9min
#     💾 checkpoint saved (305,000 PEs)
#   [305,500/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 133.7 PE/s | retries:0 | ETA:4.9min
#   [306,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.9 PE/s | retries:0 | ETA:4.8min
#   [306,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.0 PE/s | retries:0 | ETA:4.7min
#   [307,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.2 PE/s | retries:0 | ETA:4.7min
#   [307,500/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 134.3 PE/s | retries:0 | ETA:4.6min
#   [308,000/344,579] ok:495 fail:5 | p50:39ms avg:47ms | 134.4 PE/s | retries:0 | ETA:4.5min
#   [308,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 134.6 PE/s | retries:0 | ETA:4.5min
#   [309,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 134.7 PE/s | retries:0 | ETA:4.4min
#   [309,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.9 PE/s | retries:0 | ETA:4.3min
#   [310,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 135.0 PE/s | retries:0 | ETA:4.3min
#     💾 checkpoint saved (310,000 PEs)
#   [310,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.4 PE/s | retries:0 | ETA:4.3min
#   [311,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.5 PE/s | retries:0 | ETA:4.2min
#   [311,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.6 PE/s | retries:0 | ETA:4.1min
#   [312,000/344,579] ok:497 fail:3 | p50:39ms avg:47ms | 133.8 PE/s | retries:0 | ETA:4.1min
#   [312,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.9 PE/s | retries:0 | ETA:4.0min
#   [313,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 134.0 PE/s | retries:0 | ETA:3.9min
#   [313,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.2 PE/s | retries:0 | ETA:3.9min
#   [314,000/344,579] ok:497 fail:3 | p50:39ms avg:47ms | 134.3 PE/s | retries:0 | ETA:3.8min
#   [314,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.5 PE/s | retries:0 | ETA:3.7min
#   [315,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 134.6 PE/s | retries:0 | ETA:3.7min
#     💾 checkpoint saved (315,000 PEs)
#   [315,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.0 PE/s | retries:0 | ETA:3.6min
#   [316,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.1 PE/s | retries:0 | ETA:3.6min
#   [316,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.2 PE/s | retries:0 | ETA:3.5min
#   [317,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.4 PE/s | retries:0 | ETA:3.4min
#   [317,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.5 PE/s | retries:0 | ETA:3.4min
#   [318,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.6 PE/s | retries:0 | ETA:3.3min
#   [318,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.8 PE/s | retries:0 | ETA:3.2min
#   [319,000/344,579] ok:497 fail:3 | p50:39ms avg:47ms | 133.9 PE/s | retries:0 | ETA:3.2min
#   [319,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.1 PE/s | retries:0 | ETA:3.1min
#   [320,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 134.2 PE/s | retries:0 | ETA:3.1min
#     💾 checkpoint saved (320,000 PEs)
#   [320,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.6 PE/s | retries:0 | ETA:3.0min
#   [321,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 132.7 PE/s | retries:0 | ETA:3.0min
#   [321,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 132.9 PE/s | retries:0 | ETA:2.9min
#   [322,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.0 PE/s | retries:0 | ETA:2.8min
#   [322,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.1 PE/s | retries:0 | ETA:2.8min
#   [323,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.3 PE/s | retries:0 | ETA:2.7min
#   [323,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.4 PE/s | retries:0 | ETA:2.6min
#   [324,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.6 PE/s | retries:0 | ETA:2.6min
#   [324,500/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.7 PE/s | retries:0 | ETA:2.5min
#   [325,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.9 PE/s | retries:0 | ETA:2.4min
#     💾 checkpoint saved (325,000 PEs)
#   [325,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.3 PE/s | retries:0 | ETA:2.4min
#   [326,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 132.5 PE/s | retries:0 | ETA:2.3min
#   [326,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.6 PE/s | retries:0 | ETA:2.3min
#   [327,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.7 PE/s | retries:0 | ETA:2.2min
#   [327,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.8 PE/s | retries:0 | ETA:2.1min
#   [328,000/344,579] ok:499 fail:1 | p50:39ms avg:47ms | 133.0 PE/s | retries:0 | ETA:2.1min
#   [328,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.1 PE/s | retries:0 | ETA:2.0min
#   [329,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.2 PE/s | retries:0 | ETA:1.9min
#   [329,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.4 PE/s | retries:0 | ETA:1.9min
#   [330,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.5 PE/s | retries:0 | ETA:1.8min
#     💾 checkpoint saved (330,000 PEs)
#   [330,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.0 PE/s | retries:0 | ETA:1.8min
#   [331,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.1 PE/s | retries:0 | ETA:1.7min
#   [331,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.3 PE/s | retries:0 | ETA:1.6min
#   [332,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.4 PE/s | retries:0 | ETA:1.6min
#   [332,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.5 PE/s | retries:0 | ETA:1.5min
#   [333,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.6 PE/s | retries:0 | ETA:1.5min
#   [333,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.7 PE/s | retries:0 | ETA:1.4min
#   [334,000/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 132.8 PE/s | retries:0 | ETA:1.3min
#   [334,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.9 PE/s | retries:0 | ETA:1.3min
#   [335,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 133.1 PE/s | retries:0 | ETA:1.2min
#     💾 checkpoint saved (335,000 PEs)
#   [335,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.6 PE/s | retries:0 | ETA:1.1min
#   [336,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.7 PE/s | retries:0 | ETA:1.1min
#   [336,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.9 PE/s | retries:0 | ETA:1.0min
#   [337,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.0 PE/s | retries:0 | ETA:1.0min
#   [337,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.1 PE/s | retries:0 | ETA:0.9min
#   [338,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.3 PE/s | retries:0 | ETA:0.8min
#   [338,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.4 PE/s | retries:0 | ETA:0.8min
#   [339,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.5 PE/s | retries:0 | ETA:0.7min
#   [339,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.6 PE/s | retries:0 | ETA:0.6min
#   [340,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.8 PE/s | retries:0 | ETA:0.6min
#     💾 checkpoint saved (340,000 PEs)
#   [340,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.3 PE/s | retries:0 | ETA:0.5min
#   [341,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.4 PE/s | retries:0 | ETA:0.5min
#   [341,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.6 PE/s | retries:0 | ETA:0.4min
#   [342,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.7 PE/s | retries:0 | ETA:0.3min
#   [342,500/344,579] ok:498 fail:2 | p50:39ms avg:47ms | 131.8 PE/s | retries:0 | ETA:0.3min
#   [343,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 131.9 PE/s | retries:0 | ETA:0.2min
#   [343,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.0 PE/s | retries:0 | ETA:0.1min
#   [344,000/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.2 PE/s | retries:0 | ETA:0.1min
#   [344,500/344,579] ok:500 fail:0 | p50:39ms avg:47ms | 132.3 PE/s | retries:0 | ETA:0.0min
#   [344,579/344,579] ok:78 fail:1 | p50:39ms avg:47ms | 132.3 PE/s | retries:0 | ETA:0.0min
#
# Processed 495,113 virksomheder, 344,579 produktionsenheder in 2605.7s (43.4min)
# Coordinates found: 341,781, failed: 2,798
#
# --- API Rate Monitor (CONCURRENCY=25) ---
#   Total lookups:   344,579 (1 HTTP call each)
#   Wall-clock:      132.2 PE/sec
#   API latency p50: 39ms
#   API latency avg: 47ms
#   API latency p95: 56ms
#   API latency max: 15018ms
#   Retries used:    0 (0% of lookups)
#   HTTP status codes: {200: 341781, 404: 2764, 502: 34}
#
#   ✓ API latency healthy — could try CONCURRENCY=30

# %%
# flatten to one feature per produktionsenhed and save as GeoJSON
features = []
for cvr_nr, entry in master_data.items():
    virk = entry.get("virksomhed", {})
    for pe in entry.get("produktionsenheder", []):
        lon = pe.get("longitude")
        lat = pe.get("latitude")
        if lon is None or lat is None:
            continue
        features.append({
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [lon, lat]},
            "properties": {
                **virk,
                "CVREnhedsId": pe.get("CVREnhedsId"),
                "Adresse": pe.get("Adresse"),
                "pNummer": pe.get("pNummer"),
                "tilknyttetVirksomhedsCVRNummer": pe.get("tilknyttetVirksomhedsCVRNummer"),
                "produktionsenhedStartdato": pe.get("produktionsenhedStartdato"),
                "produktionsenhedOphoersdato": pe.get("produktionsenhedOphoersdato"),
            },
        })

geojson = {"type": "FeatureCollection", "features": features}

output_path = "../data/processed/cvr/CVR_geo_temporal.geojson"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)
print(f"Saved {len(features)} produktionsenheder as GeoJSON to {output_path}")
# Out:
# Saved 341781 produktionsenheder as GeoJSON to ../data/processed/cvr/CVR_geo_temporal.geojson
