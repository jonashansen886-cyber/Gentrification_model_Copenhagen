# %% [markdown]
# # Notebook 9: Manual CVR data processing for the current cvr data
#
# Made as a test to figure out the structure of the data and how to use the DAWA api to get adresses

# %% [markdown]
# This notebook handles CVR data processing manually with data form https://datafordeler.dk/ if API solution is limited due to quota limitations

# %%
#pakages
import os
import json
import pandas as pd

# %% [markdown]
# Import JSON files

# %%
with open("../data/raw/cvr_raw/cvr_current/CVR_V1_Adressering_TotalDownload_json_Current_317.json", "r", encoding="utf-8") as f:
    cvr_adress = json.load(f)
# Access records directly
print(len(cvr_adress))           # number of records
print(cvr_adress[0].keys())      # keys in each record
print(cvr_adress[0])             # first record
# Out:
# 2776903
# dict_keys(['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn', 'CVRAdresse_adresseFritekst', 'CVRAdresse_landekode', 'CVRAdresse_postboks', 'coNavn', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:03.594888Z', 'AdresseringAnvendelse': 'beliggenhedsadresse', 'CVREnhedsId': '1000568', 'Adresse': '0a3f50ad-b109-32b8-e044-0003ba298018', 'CVRAdresse_vejkode': '965', 'CVRAdresse_husnummerFra': '120', 'CVRAdresse_etagebetegnelse': None, 'CVRAdresse_doerbetegnelse': None, 'CVRAdresse_kommunekode': '326', 'CVRAdresse_kommunenavn': 'KALUNDBORG', 'CVRAdresse_postdistrikt': 'Kalundborg', 'CVRAdresse_vejnavn': 'Kystvejen', 'CVRAdresse_husnummerTil': None, 'CVRAdresse_postnummer': '4400', 'CVRAdresse_supplerendeBynavn': None, 'CVRAdresse_adresseFritekst': None, 'CVRAdresse_landekode': 'DK', 'CVRAdresse_postboks': None, 'coNavn': None, 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '2023-12-28', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_current/CVR_V1_Branche_TotalDownload_json_Current_310.json", "r", encoding="utf-8") as f:
    cvr_branche = json.load(f)
# Access records directly
print(len(cvr_branche))           # number of records
print(cvr_branche[0].keys())      # keys in each record
print(cvr_branche[0])             # first record
# Out:
# 2048619
# dict_keys(['datafordelerOpdateringstid', 'sekvens', 'CVREnhedsId', 'vaerdi', 'vaerdiTekst', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:36:16.675427Z', 'sekvens': 0, 'CVREnhedsId': '1000568', 'vaerdi': '691000', 'vaerdiTekst': 'Juridiske aktiviteter', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '2025-01-01', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_current/CVR_V1_Navn_TotalDownload_json_Current_317.json", "r", encoding="utf-8") as f:
    cvr_navn = json.load(f)
# Access records directly
print(len(cvr_navn))           # number of records
print(cvr_navn[0].keys())      # keys in each record
print(cvr_navn[0])             # first record
# Out:
# 2949685
# dict_keys(['datafordelerOpdateringstid', 'CVREnhedsId', 'sekvens', 'vaerdi', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:07.259526Z', 'CVREnhedsId': '1000568', 'sekvens': 0, 'vaerdi': 'C. K. LUND. KALUNDBORG/ASNÆS ApS', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '2023-12-28', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_current/CVR_V1_Produktionsenhed_TotalDownload_json_Current_317.json", "r", encoding="utf-8") as f:
    cvr_produktionsenhed = json.load(f)
# Access records directly
print(len(cvr_produktionsenhed))           # number of records
print(cvr_produktionsenhed[0].keys())      # keys in each record
print(cvr_produktionsenhed[0])             # first record
# Out:
# 950117
# dict_keys(['datafordelerOpdateringstid', 'id', 'pNummer', 'tilknyttetVirksomhedsCVRNummer', 'produktionsenhedStartdato', 'produktionsenhedOphoersdato', 'tilknyttetTilVirksomhedStartdato', 'tilknyttetTilVirksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2026-01-14T09:48:02.395821Z', 'id': '1002173', 'pNummer': 1003223258, 'tilknyttetVirksomhedsCVRNummer': 89224918, 'produktionsenhedStartdato': '1982-01-01', 'produktionsenhedOphoersdato': None, 'tilknyttetTilVirksomhedStartdato': '1982-01-01', 'tilknyttetTilVirksomhedOphoersdato': None, 'registreringFra': '2026-01-14T09:45:38Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1982-01-01', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_current/CVR_V1_Virksomhed_TotalDownload_json_Current_317.json", "r", encoding="utf-8") as f:
    cvr_virksomhed = json.load(f)
# Access records directly
print(len(cvr_virksomhed))           # number of records
print(cvr_virksomhed[0].keys())      # keys in each record
print(cvr_virksomhed[0])             # first record
# Out:
# 865485
# dict_keys(['datafordelerOpdateringstid', 'id', 'CVRNummer', 'virksomhedStartdato', 'virksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:00.989831Z', 'id': '1000568', 'CVRNummer': 16079944, 'virksomhedStartdato': '1992-01-03', 'virksomhedOphoersdato': None, 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %% [markdown]
# ### filter for ID's in Copenhagen with kommunekode = 101

# %%
cvr_adress_cph = [r for r in cvr_adress if r.get("CVRAdresse_kommunekode") == "101"]
print(f"Filtered: {len(cvr_adress_cph)} / {len(cvr_adress)} records with kommunekode 101")
# Out:
# Filtered: 327542 / 2776903 records with kommunekode 101

# %% [markdown]
# ### join json on cvr_adress_cph

# %%
# change "id" to "CVREnhedsId" in all datasets for easier merging later
for dataset in [cvr_adress_cph, cvr_branche, cvr_navn, cvr_produktionsenhed, cvr_virksomhed]:
    for record in dataset:
        if "id" in record:
            record["CVREnhedsId"] = record.pop("id")

# %%
# change names in datasets to not overlap

for record in cvr_navn:
    if "vaerdi" in record:
        record["navn"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdi" in record:
        record["branche_kode"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdiTekst" in record:
        record["branche_navn"] = record.pop("vaerdiTekst")

# %%
# join the datasets on "CVREnhedsId" to create a master dataset for Copenhagen
# Build lookup dicts keyed by CVREnhedsId
def to_lookup(dataset):
    lookup = {}
    for r in dataset:
        eid = r.get("CVREnhedsId")
        if eid is not None:
            lookup[eid] = {k: v for k, v in r.items() if k != "CVREnhedsId"}
    return lookup

branche_lkp = to_lookup(cvr_branche)
navn_lkp = to_lookup(cvr_navn)
prod_lkp = to_lookup(cvr_produktionsenhed)
virk_lkp = to_lookup(cvr_virksomhed)

# Start from cvr_adress_cph and left-join the others
joined_cph = []
for rec in cvr_adress_cph:
    eid = rec.get("CVREnhedsId")
    merged = dict(rec)  # copy address fields
    merged.update(branche_lkp.get(eid, {}))
    merged.update(navn_lkp.get(eid, {}))
    merged.update(prod_lkp.get(eid, {}))
    merged.update(virk_lkp.get(eid, {}))
    joined_cph.append(merged)

print(f"joined_cph: {len(joined_cph)} records, {len(joined_cph[0].keys())} columns")
print(f"Sample keys: {list(joined_cph[0].keys())[:15]}")
# Out:
# joined_cph: 327542 records, 34 columns
# Sample keys: ['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn']

# %%
# filter objects to only include certain feautures for easier handling later
features_to_keep = [
    "CVREnhedsId",
    "Adresse",
    "branche_kode",
    "branche_navn",
    "navn",
    "CVRNummer",
    "virksomhedStartdato",
    "virksomhedOphoersdato",
    "pNummer",
    "tilknyttetVirksomhedsCVRNummer",
    "produktionsenhedStartdato",
    "produktionsenhedOphoersdato",
]

# %%
# filter joined_cph to only include features in features_to_keep
joined_cph = [
    {k: v for k, v in rec.items() if k in features_to_keep}
    for rec in joined_cph
]

# count how many unique keys appear across all records
all_keys = set()
for rec in joined_cph:
    all_keys.update(rec.keys())
print(f"Filtered to {len(all_keys)} unique features across {len(joined_cph)} records")
print(f"Features present: {sorted(all_keys)}")
# Out:
# Filtered to 12 unique features across 327542 records
# Features present: ['Adresse', 'CVREnhedsId', 'CVRNummer', 'branche_kode', 'branche_navn', 'navn', 'pNummer', 'produktionsenhedOphoersdato', 'produktionsenhedStartdato', 'tilknyttetVirksomhedsCVRNummer', 'virksomhedOphoersdato', 'virksomhedStartdato']

# %%
# group production units by their parent virksomhed CVRNummer
from collections import defaultdict

grouped = defaultdict(lambda: {"virksomhed": {}, "produktionsenheder": []})

for rec in joined_cph:
    cvr_nr = rec.get("CVRNummer") or rec.get("tilknyttetVirksomhedsCVRNummer")
    if cvr_nr is None:
        continue

    # store virksomhed-level fields once
    if not grouped[cvr_nr]["virksomhed"]:
        grouped[cvr_nr]["virksomhed"] = {
            "CVRNummer": cvr_nr,
            "navn": rec.get("navn"),
            "virksomhedStartdato": rec.get("virksomhedStartdato"),
            "virksomhedOphoersdato": rec.get("virksomhedOphoersdato"),
            "branche_kode": rec.get("branche_kode"),
            "branche_navn": rec.get("branche_navn"),
        }

    # append produktionsenhed info if present
    if rec.get("pNummer"):
        grouped[cvr_nr]["produktionsenheder"].append({
            "CVREnhedsId": rec.get("CVREnhedsId"),
            "Adresse": rec.get("Adresse"),
            "pNummer": rec.get("pNummer"),
            "tilknyttetVirksomhedsCVRNummer": rec.get("tilknyttetVirksomhedsCVRNummer"),
            "produktionsenhedStartdato": rec.get("produktionsenhedStartdato"),
            "produktionsenhedOphoersdato": rec.get("produktionsenhedOphoersdato"),
        })

grouped = dict(grouped)
print(f"Grouped into {len(grouped)} unique virksomheder")
# show an example with multiple produktionsenheder
example = next((v for v in grouped.values() if len(v['produktionsenheder']) > 1), None)
if example:
    print(f"\nExample virksomhed: {example['virksomhed']['navn']}")
    print(f"  CVRNummer: {example['virksomhed']['CVRNummer']}")
    print(f"  Produktionsenheder: {len(example['produktionsenheder'])}")
    for pe in example['produktionsenheder'][:3]:
        print(f"    pNummer: {pe['pNummer']}, Adresse: {pe['Adresse']}")
# Out:
# Grouped into 124695 unique virksomheder
#
# Example virksomhed: EJENDOMS- OG FINANCIERINGSSELSKABET PETANET A/S
#   CVRNummer: 89517214
#   Produktionsenheder: 2
#     pNummer: 1002820454, Adresse: 39c36a3e-2a81-4cc5-a7a3-b5948998641b
#     pNummer: 1020246037, Adresse: 62b5f7f1-5649-46a6-9730-fb1d6779ff0c

# %%
# save grouped structure to json
output_path = "../data/processed/cvr/cvr_cph_joined_manual.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(grouped, f, ensure_ascii=False, indent=2)
print(f"Saved {len(grouped)} virksomheder to {output_path}")
# Out:
# Saved 124695 virksomheder to ../data/processed/cvr/cvr_cph_joined_manual.json

# %% [markdown]
# ## Get adresses from DAWA API

# %%
# input joined json dataset
with open("../data/processed/cvr/cvr_cph_joined_manual.json", "r", encoding="utf-8") as f:
    master_data = json.load(f)

print(f"Type: {type(master_data).__name__}, {len(master_data)} virksomheder")

# peek at the first entry
first_key = next(iter(master_data))
print(f"\nFirst CVRNummer: {first_key}")
print(json.dumps(master_data[first_key], indent=2, ensure_ascii=False))
# Out:
# Type: dict, 124695 virksomheder
#
# First CVRNummer: 76160716
# {
#   "virksomhed": {
#     "CVRNummer": 76160716,
#     "navn": "B4B ApS",
#     "virksomhedStartdato": "1985-01-01",
#     "virksomhedOphoersdato": null,
#     "branche_kode": "692000",
#     "branche_navn": "Bogføring og revision; skatterådgivning"
#   },
#   "produktionsenheder": [
#     {
#       "CVREnhedsId": "4002230747",
#       "Adresse": "f1af7c59-b49a-4056-b843-198618a4a137",
#       "pNummer": 1002482534,
#       "tilknyttetVirksomhedsCVRNummer": 76160716,
#       "produktionsenhedStartdato": "1985-01-01",
#       "produktionsenhedOphoersdato": null
#     }
#   ]
# }

# %%
import aiohttp
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
id = "f1af7c59-b49a-4056-b843-198618a4a137"
url = f"https://api.dataforsyningen.dk/adresser/{id}"

response = requests.get(url)
data = response.json()
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "id": "f1af7c59-b49a-4056-b843-198618a4a137",
#   "kvhx": "01010090__24__2__th",
#   "status": 1,
#   "darstatus": 3,
#   "href": "https://api.dataforsyningen.dk/adresser/f1af7c59-b49a-4056-b843-198618a4a137",
#   "historik": {
#     "oprettet": "2015-01-29T09:05:50.997",
#     "ændret": "2015-08-11T13:40:55.423",
#     "ikrafttrædelse": "2015-08-11T13:40:55.423",
#     "nedlagt": null
#   },
#   "etage": "2",
#   "dør": "th",
#   "adressebetegnelse": "Alliancevej 24, 2. th, 2450 København SV",
#   "adgangsadresse": {
#     "href": "https://api.dataforsyningen.dk/adgangsadresser/e5c4bc08-5967-4e3f-bdf0-ce048f3c8679",
#     "id": "e5c4bc08-5967-4e3f-bdf0-ce048f3c8679",
#     "adressebetegnelse": "Alliancevej 24, 2450 København SV",
#     "kvh": "01010090__24",
#     "status": 1,
#     "darstatus": 3,
#     "vejstykke": {
#       "href": "https://api.dataforsyningen.dk/vejstykker/101/90",
#       "navn": "Alliancevej",
#       "adresseringsnavn": "Alliancevej",
#       "kode": "0090"
#     },
#     "husnr": "24",
#     "navngivenvej": {
#       "href": "https://api.dataforsyningen.dk/navngivneveje/b97b98b8-a53c-45a2-b55c-86605a5a8155",
#       "id": "b97b98b8-a53c-45a2-b55c-86605a5a8155"
#     },
#     "supplerendebynavn": null,
#     "supplerendebynavn2": null,
#     "postnummer": {
#       "href": "https://api.dataforsyningen.dk/postnumre/2450",
#       "nr": "2450",
#       "navn": "København SV"
#     },
#     "stormodtagerpostnummer": null,
#     "kommune": {
#       "href": "https://api.dataforsyningen.dk/kommuner/0101",
#       "kode": "0101",
#       "navn": "København"
#     },
#     "ejerlav": {
#       "kode": 2000161,
#       "navn": "Kongens Enghave, København"
#     },
#     "esrejendomsnr": "0",
#     "matrikelnr": "387g",
#     "historik": {
#       "oprettet": "2015-01-29T08:53:19.670",
#       "ændret": "2021-06-18T08:34:37.800",
#       "ikrafttrædelse": "2015-08-11T13:39:57.600",
#       "nedlagt": null
#     },
#     "adgangspunkt": {
#       "id": "dfe0af04-8b09-4c41-8a5f-6408cd5b938c",
#       "koordinater": [
#         12.55240765,
#         55.6477728
#       ],
#       "højde": 2.1,
#       "nøjagtighed": "A",
#       "kilde": 5,
#       "tekniskstandard": "TD",
#       "tekstretning": 232.59,
#       "ændret": "2017-11-22T00:00:00.000"
#     },
#     "vejpunkt": {
#       "id": "20e2fea7-af45-11e7-847e-066cff24d637",
#       "kilde": "Adressemyn",
#       "nøjagtighed": "A",
#       "tekniskstandard": "V0",
#       "koordinater": [
#         12.55307622,
#         55.64822647
#       ],
#       "ændret": "2021-06-18T08:34:37.800145"
#     },
#     "DDKN": {
#       "m100": "100m_61726_7235",
#       "km1": "1km_6172_723",
#       "km10": "10km_617_72"
#     },
#     "sogn": {
#       "href": "https://api.dataforsyningen.dk/sogne/9165",
#       "kode": "9165",
#       "navn": "Sydhavn"
#     },
#     "region": {
#       "href": "https://api.dataforsyningen.dk/regioner/1084",
#       "kode": "1084",
#       "navn": "Region Hovedstaden"
#     },
#     "landsdel": {
#       "href": "https://api.dataforsyningen.dk/landsdele/DK011",
#       "nuts3": "DK011",
#       "navn": "Byen København"
#     },
#     "retskreds": {
#       "href": "https://api.dataforsyningen.dk/retskredse/1102",
#       "kode": "1102",
#       "navn": "Retten på Frederiksberg"
#     },
#     "politikreds": {
#       "href": "https://api.dataforsyningen.dk/politikredse/1470",
#       "kode": "1470",
#       "navn": "Københavns Politi"
#     },
#     "opstillingskreds": {
#       "href": "https://api.dataforsyningen.dk/opstillingskredse/0009",
#       "kode": "0009",
#       "navn": "Vesterbro"
#     },
#     "afstemningsområde": {
#       "href": "https://api.dataforsyningen.dk/afstemningsomraader/101/55",
#       "nummer": "55",
#       "navn": "9. Sydhavn"
#     },
#     "storkreds": {
#       "href": "https://api.dataforsyningen.dk/storkredse/1",
#       "nummer": "1",
#       "navn": "København"
#     },
#     "valglandsdel": {
#       "href": "https://api.dataforsyningen.dk/valglandsdele/A",
#       "bogstav": "A",
#       "navn": "Hovedstaden"
#     },
#     "zone": "Udfaset",
#     "jordstykke": {
#       "href": "https://api.dataforsyningen.dk/jordstykker/2000161/387g",
#       "ejerlav": {
#         "kode": 2000161,
#         "navn": "Kongens Enghave, København",
#         "href": "https://api.dataforsyningen.dk/ejerlav/2000161"
#       },
#       "matrikelnr": "387g",
#       "esrejendomsnr": "0"
#     },
#     "bebyggelser": [
#       {
#         "id": "12337669-d993-6b98-e053-d480220a5a3f",
#         "kode": null,
#         "type": "bydel",
#         "navn": "Kongens Enghave",
#         "href": "https://api.dataforsyningen.dk/bebyggelser/12337669-d993-6b98-e053-d480220a5a3f"
#       },
#       {
#         "id": "12337669-e134-6b98-e053-d480220a5a3f",
#         "kode": null,
#         "type": "bydel",
#         "navn": "Sydhavn",
#         "href": "https://api.dataforsyningen.dk/bebyggelser/12337669-e134-6b98-e053-d480220a5a3f"
#       },
#       {
#         "id": "290f85b8-8c7a-6fd1-e053-d480220af996",
#         "kode": 18368,
#         "type": "by",
#         "navn": "København",
#         "href": "https://api.dataforsyningen.dk/bebyggelser/290f85b8-8c7a-6fd1-e053-d480220af996"
#       }
#     ],
#     "brofast": true
#   }
# }

# %%
id = "e5c4bc08-5967-4e3f-bdf0-ce048f3c8679"
url = f"https://api.dataforsyningen.dk/adgangsadresser/{id}"

response = requests.get(url)
data = response.json()
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "href": "https://api.dataforsyningen.dk/adgangsadresser/e5c4bc08-5967-4e3f-bdf0-ce048f3c8679",
#   "id": "e5c4bc08-5967-4e3f-bdf0-ce048f3c8679",
#   "adressebetegnelse": "Alliancevej 24, 2450 København SV",
#   "kvh": "01010090__24",
#   "status": 1,
#   "darstatus": 3,
#   "vejstykke": {
#     "href": "https://api.dataforsyningen.dk/vejstykker/101/90",
#     "navn": "Alliancevej",
#     "adresseringsnavn": "Alliancevej",
#     "kode": "0090"
#   },
#   "husnr": "24",
#   "navngivenvej": {
#     "href": "https://api.dataforsyningen.dk/navngivneveje/b97b98b8-a53c-45a2-b55c-86605a5a8155",
#     "id": "b97b98b8-a53c-45a2-b55c-86605a5a8155"
#   },
#   "supplerendebynavn": null,
#   "supplerendebynavn2": null,
#   "postnummer": {
#     "href": "https://api.dataforsyningen.dk/postnumre/2450",
#     "nr": "2450",
#     "navn": "København SV"
#   },
#   "stormodtagerpostnummer": null,
#   "kommune": {
#     "href": "https://api.dataforsyningen.dk/kommuner/0101",
#     "kode": "0101",
#     "navn": "København"
#   },
#   "ejerlav": {
#     "kode": 2000161,
#     "navn": "Kongens Enghave, København"
#   },
#   "esrejendomsnr": "0",
#   "matrikelnr": "387g",
#   "historik": {
#     "oprettet": "2015-01-29T08:53:19.670",
#     "ændret": "2021-06-18T08:34:37.800",
#     "ikrafttrædelse": "2015-08-11T13:39:57.600",
#     "nedlagt": null
#   },
#   "adgangspunkt": {
#     "id": "dfe0af04-8b09-4c41-8a5f-6408cd5b938c",
#     "koordinater": [
#       12.55240765,
#       55.6477728
#     ],
#     "højde": 2.1,
#     "nøjagtighed": "A",
#     "kilde": 5,
#     "tekniskstandard": "TD",
#     "tekstretning": 232.59,
#     "ændret": "2017-11-22T00:00:00.000"
#   },
#   "vejpunkt": {
#     "id": "20e2fea7-af45-11e7-847e-066cff24d637",
#     "kilde": "Adressemyn",
#     "nøjagtighed": "A",
#     "tekniskstandard": "V0",
#     "koordinater": [
#       12.55307622,
#       55.64822647
#     ],
#     "ændret": "2021-06-18T08:34:37.800145"
#   },
#   "DDKN": {
#     "m100": "100m_61726_7235",
#     "km1": "1km_6172_723",
#     "km10": "10km_617_72"
#   },
#   "sogn": {
#     "href": "https://api.dataforsyningen.dk/sogne/9165",
#     "kode": "9165",
#     "navn": "Sydhavn"
#   },
#   "region": {
#     "href": "https://api.dataforsyningen.dk/regioner/1084",
#     "kode": "1084",
#     "navn": "Region Hovedstaden"
#   },
#   "landsdel": {
#     "href": "https://api.dataforsyningen.dk/landsdele/DK011",
#     "nuts3": "DK011",
#     "navn": "Byen København"
#   },
#   "retskreds": {
#     "href": "https://api.dataforsyningen.dk/retskredse/1102",
#     "kode": "1102",
#     "navn": "Retten på Frederiksberg"
#   },
#   "politikreds": {
#     "href": "https://api.dataforsyningen.dk/politikredse/1470",
#     "kode": "1470",
#     "navn": "Københavns Politi"
#   },
#   "opstillingskreds": {
#     "href": "https://api.dataforsyningen.dk/opstillingskredse/0009",
#     "kode": "0009",
#     "navn": "Vesterbro"
#   },
#   "afstemningsområde": {
#     "href": "https://api.dataforsyningen.dk/afstemningsomraader/101/55",
#     "nummer": "55",
#     "navn": "9. Sydhavn"
#   },
#   "storkreds": {
#     "href": "https://api.dataforsyningen.dk/storkredse/1",
#     "nummer": "1",
#     "navn": "København"
#   },
#   "valglandsdel": {
#     "href": "https://api.dataforsyningen.dk/valglandsdele/A",
#     "bogstav": "A",
#     "navn": "Hovedstaden"
#   },
#   "zone": "Udfaset",
#   "jordstykke": {
#     "href": "https://api.dataforsyningen.dk/jordstykker/2000161/387g",
#     "ejerlav": {
#       "kode": 2000161,
#       "navn": "Kongens Enghave, København",
#       "href": "https://api.dataforsyningen.dk/ejerlav/2000161"
#     },
#     "matrikelnr": "387g",
#     "esrejendomsnr": "0"
#   },
#   "bebyggelser": [
#     {
#       "id": "12337669-d993-6b98-e053-d480220a5a3f",
#       "kode": null,
#       "type": "bydel",
#       "navn": "Kongens Enghave",
#       "href": "https://api.dataforsyningen.dk/bebyggelser/12337669-d993-6b98-e053-d480220a5a3f"
#     },
#     {
#       "id": "12337669-e134-6b98-e053-d480220a5a3f",
#       "kode": null,
#       "type": "bydel",
#       "navn": "Sydhavn",
#       "href": "https://api.dataforsyningen.dk/bebyggelser/12337669-e134-6b98-e053-d480220a5a3f"
#     },
#     {
#       "id": "290f85b8-8c7a-6fd1-e053-d480220af996",
#       "kode": 18368,
#       "type": "by",
#       "navn": "København",
#       "href": "https://api.dataforsyningen.dk/bebyggelser/290f85b8-8c7a-6fd1-e053-d480220af996"
#     }
#   ],
#   "brofast": true
# }

# %%
# extract koordinater from "adgangspunkt" from adgangsadresse
adgangspunkt = data.get("adgangspunkt", {})
koordinater = adgangspunkt.get("koordinater", [])
print(koordinater)
# Out:
# [12.55240765, 55.6477728]

# %%
import time
import statistics

# --- CONFIG ---
MAX_VIRKSOMHEDER = 10000    # None = process all
CONCURRENCY = 25              # 5 concurrent = ~10 req/s (API limit)
BATCH_SIZE = 500
MAX_RETRIES = 3
TIMEOUT_SEC = 30
SAVE_INTERVAL = 5000         # auto-save progress every N PEs

sem = asyncio.Semaphore(CONCURRENCY)

# --- MONITORING ---
api_times = []
status_codes = {}
retry_count = 0

async def fetch_coordinates(session, adresse_id):
    """Single-step DAWA lookup: /adresser/{id} already returns coordinates."""
    global retry_count
    for attempt in range(MAX_RETRIES):
        try:
            async with sem:
                t_start = time.perf_counter()

                async with session.get(
                    f"https://api.dataforsyningen.dk/adresser/{adresse_id}",
                    timeout=aiohttp.ClientTimeout(total=TIMEOUT_SEC),
                ) as resp:
                    status_codes[resp.status] = status_codes.get(resp.status, 0) + 1
                    if resp.status != 200:
                        api_times.append(time.perf_counter() - t_start)
                        return None, None
                    data = await resp.json()

                koordinater = data.get("adgangsadresse", {}).get("adgangspunkt", {}).get("koordinater", [])
                api_times.append(time.perf_counter() - t_start)
                if len(koordinater) == 2:
                    return koordinater[0], koordinater[1]
                return None, None

        except (aiohttp.ClientError, asyncio.TimeoutError):
            retry_count += 1
            if attempt < MAX_RETRIES - 1:
                await asyncio.sleep(1 * (attempt + 1))
                continue
            return None, None
    return None, None


def save_checkpoint():
    """Save current master_data progress to JSON."""
    path = "../data/processed/cvr/cvr_cph_addresses.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(master_data, f, ensure_ascii=False)
    return path


async def process_all():
    pe_tasks = []
    count = 0
    for cvr_nr, entry in master_data.items():
        if MAX_VIRKSOMHEDER is not None and count >= MAX_VIRKSOMHEDER:
            break
        for pe in entry.get("produktionsenheder", []):
            adresse_id = pe.get("Adresse")
            if adresse_id:
                pe_tasks.append((pe, adresse_id))
        count += 1

    total_pe = len(pe_tasks)
    print(f"Queued {total_pe:,} PEs from {count:,} virksomheder (CONCURRENCY={CONCURRENCY})")
    print(f"Using single-step lookup (1 API call per PE instead of 2)")

    failed = 0
    connector = aiohttp.TCPConnector(limit=CONCURRENCY)
    async with aiohttp.ClientSession(connector=connector) as session:
        for batch_start in range(0, total_pe, BATCH_SIZE):
            batch = pe_tasks[batch_start : batch_start + BATCH_SIZE]
            tasks = [fetch_coordinates(session, aid) for _, aid in batch]
            results = await asyncio.gather(*tasks, return_exceptions=True)

            batch_failed = 0
            for (pe, _), result in zip(batch, results):
                if isinstance(result, Exception) or result == (None, None):
                    pe["longitude"] = None
                    pe["latitude"] = None
                    failed += 1
                    batch_failed += 1
                else:
                    pe["longitude"], pe["latitude"] = result

            done = min(batch_start + BATCH_SIZE, total_pe)
            elapsed_so_far = time.perf_counter() - t0
            avg_ms = statistics.mean(api_times) * 1000 if api_times else 0
            p50_ms = statistics.median(api_times) * 1000 if api_times else 0
            rps = done / elapsed_so_far if elapsed_so_far > 0 else 0
            eta_min = ((total_pe - done) / rps / 60) if rps > 0 else 0
            print(f"  [{done:,}/{total_pe:,}] ok:{len(batch)-batch_failed} fail:{batch_failed} | p50:{p50_ms:.0f}ms avg:{avg_ms:.0f}ms | {rps:.1f} PE/s | retries:{retry_count} | ETA:{eta_min:.1f}min")

            # auto-save checkpoint
            if done % SAVE_INTERVAL < BATCH_SIZE:
                save_checkpoint()
                print(f"    💾 checkpoint saved ({done:,} PEs)")

    return count, total_pe, failed


t0 = time.perf_counter()
count, total_pe, failed = asyncio.get_event_loop().run_until_complete(process_all())
elapsed = time.perf_counter() - t0

# final save
save_checkpoint()

print(f"\nProcessed {count:,} virksomheder, {total_pe:,} produktionsenheder in {elapsed:.1f}s ({elapsed/60:.1f}min)")
print(f"Coordinates found: {total_pe - failed:,}, failed: {failed:,}")

if api_times:
    avg_ms = statistics.mean(api_times) * 1000
    p50_ms = statistics.median(api_times) * 1000
    p95_ms = sorted(api_times)[int(len(api_times) * 0.95)] * 1000
    max_ms = max(api_times) * 1000
    rps = total_pe / elapsed
    print(f"\n--- API Rate Monitor (CONCURRENCY={CONCURRENCY}) ---")
    print(f"  Total lookups:   {len(api_times):,} (1 HTTP call each)")
    print(f"  Wall-clock:      {rps:.1f} PE/sec")
    print(f"  API latency p50: {p50_ms:.0f}ms")
    print(f"  API latency avg: {avg_ms:.0f}ms")
    print(f"  API latency p95: {p95_ms:.0f}ms")
    print(f"  API latency max: {max_ms:.0f}ms")
    print(f"  Retries used:    {retry_count} ({retry_count*100//(total_pe or 1)}% of lookups)")
    print(f"  HTTP status codes: {status_codes}")
    if retry_count > total_pe * 0.05:
        print(f"\n  ⚠ High retry rate — consider lowering CONCURRENCY to {max(3, CONCURRENCY-2)}")
    elif avg_ms < 300:
        print(f"\n  ✓ API latency healthy — could try CONCURRENCY={CONCURRENCY+5}")
# Out:
# Queued 11,576 PEs from 10,000 virksomheder (CONCURRENCY=25)
# Using single-step lookup (1 API call per PE instead of 2)
#   [500/11,576] ok:499 fail:1 | p50:44ms avg:50ms | 482.1 PE/s | retries:0 | ETA:0.4min
#   [1,000/11,576] ok:496 fail:4 | p50:43ms avg:47ms | 512.3 PE/s | retries:0 | ETA:0.3min
#   [1,500/11,576] ok:498 fail:2 | p50:43ms avg:46ms | 526.4 PE/s | retries:0 | ETA:0.3min
#   [2,000/11,576] ok:497 fail:3 | p50:43ms avg:45ms | 536.1 PE/s | retries:0 | ETA:0.3min
#   [2,500/11,576] ok:500 fail:0 | p50:43ms avg:45ms | 536.1 PE/s | retries:0 | ETA:0.3min
#   [3,000/11,576] ok:497 fail:3 | p50:43ms avg:44ms | 540.5 PE/s | retries:0 | ETA:0.3min
#   [3,500/11,576] ok:500 fail:0 | p50:43ms avg:44ms | 543.6 PE/s | retries:0 | ETA:0.2min
#   [4,000/11,576] ok:499 fail:1 | p50:42ms avg:44ms | 545.6 PE/s | retries:0 | ETA:0.2min
#   [4,500/11,576] ok:499 fail:1 | p50:42ms avg:44ms | 547.3 PE/s | retries:0 | ETA:0.2min
#   [5,000/11,576] ok:496 fail:4 | p50:43ms avg:44ms | 548.2 PE/s | retries:0 | ETA:0.2min
#     💾 checkpoint saved (5,000 PEs)
#   [5,500/11,576] ok:499 fail:1 | p50:43ms avg:44ms | 450.3 PE/s | retries:0 | ETA:0.2min
#   [6,000/11,576] ok:496 fail:4 | p50:43ms avg:44ms | 456.5 PE/s | retries:0 | ETA:0.2min
#   [6,500/11,576] ok:498 fail:2 | p50:43ms avg:44ms | 463.0 PE/s | retries:0 | ETA:0.2min
#   [7,000/11,576] ok:499 fail:1 | p50:43ms avg:44ms | 444.1 PE/s | retries:0 | ETA:0.2min
#   [7,500/11,576] ok:500 fail:0 | p50:43ms avg:44ms | 450.2 PE/s | retries:0 | ETA:0.2min
#   [8,000/11,576] ok:498 fail:2 | p50:43ms avg:44ms | 455.8 PE/s | retries:0 | ETA:0.1min
#   [8,500/11,576] ok:497 fail:3 | p50:43ms avg:44ms | 460.5 PE/s | retries:0 | ETA:0.1min
#   [9,000/11,576] ok:499 fail:1 | p50:43ms avg:44ms | 464.7 PE/s | retries:0 | ETA:0.1min
#   [9,500/11,576] ok:498 fail:2 | p50:43ms avg:44ms | 469.4 PE/s | retries:0 | ETA:0.1min
#   [10,000/11,576] ok:499 fail:1 | p50:43ms avg:44ms | 471.5 PE/s | retries:0 | ETA:0.1min
#     💾 checkpoint saved (10,000 PEs)
#   [10,500/11,576] ok:500 fail:0 | p50:43ms avg:44ms | 433.5 PE/s | retries:0 | ETA:0.0min
#   [11,000/11,576] ok:497 fail:3 | p50:43ms avg:44ms | 438.0 PE/s | retries:0 | ETA:0.0min
#   [11,500/11,576] ok:499 fail:1 | p50:43ms avg:44ms | 441.8 PE/s | retries:0 | ETA:0.0min
#   [11,576/11,576] ok:76 fail:0 | p50:43ms avg:44ms | 441.8 PE/s | retries:0 | ETA:0.0min
#
# Processed 10,000 virksomheder, 11,576 produktionsenheder in 26.2s (0.4min)
# Coordinates found: 11,536, failed: 40
#
# --- API Rate Monitor (CONCURRENCY=25) ---
#   Total lookups:   11,576 (1 HTTP call each)
#   Wall-clock:      441.6 PE/sec
#   API latency p50: 43ms
#   API latency avg: 44ms
#   API latency p95: 56ms
#   API latency max: 606ms
#   Retries used:    0 (0% of lookups)
#   HTTP status codes: {404: 40, 200: 11536}
#
#   ✓ API latency healthy — could try CONCURRENCY=30

# %%
# flatten to one feature per produktionsenhed and save as GeoJSON
features = []
for cvr_nr, entry in master_data.items():
    virk = entry.get("virksomhed", {})
    for pe in entry.get("produktionsenheder", []):
        lon = pe.get("longitude")
        lat = pe.get("latitude")
        if lon is None or lat is None:
            continue
        features.append({
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [lon, lat]},
            "properties": {
                **virk,
                "CVREnhedsId": pe.get("CVREnhedsId"),
                "Adresse": pe.get("Adresse"),
                "pNummer": pe.get("pNummer"),
                "tilknyttetVirksomhedsCVRNummer": pe.get("tilknyttetVirksomhedsCVRNummer"),
                "produktionsenhedStartdato": pe.get("produktionsenhedStartdato"),
                "produktionsenhedOphoersdato": pe.get("produktionsenhedOphoersdato"),
            },
        })

geojson = {"type": "FeatureCollection", "features": features}

output_path = "../data/processed/cvr/CVR_geo.geojson"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)
print(f"Saved {len(features)} produktionsenheder as GeoJSON to {output_path}")
# Out:
# Saved 11536 produktionsenheder as GeoJSON to ../data/processed/cvr/CVR_geo.geojson
