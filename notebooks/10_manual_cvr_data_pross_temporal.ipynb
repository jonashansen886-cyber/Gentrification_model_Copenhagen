# %% [markdown]
# # Notebook 10: Manual CVR data processing for the temporal data
#
# This notebook uses the structure from notebook 9 to process the temporal data from datafordeleren and look up adresses

# %% [markdown]
# This notebook handles CVR data processing manually with data form https://datafordeler.dk/ if API solution is limited due to quota limitations. It still uses DAWA API because there is no limitation on requests

# %%
#pakages
import os
import json
import pandas as pd
import gc

# %% [markdown]
# Import JSON files

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Adressering_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_adress = json.load(f)
# Access records directly
print(len(cvr_adress))           # number of records
print(cvr_adress[0].keys())      # keys in each record
print(cvr_adress[0])             # first record
# Out:
# 12192264
# dict_keys(['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn', 'CVRAdresse_adresseFritekst', 'CVRAdresse_landekode', 'CVRAdresse_postboks', 'coNavn', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:03.593359Z', 'AdresseringAnvendelse': 'beliggenhedsadresse', 'CVREnhedsId': '1000568', 'Adresse': None, 'CVRAdresse_vejkode': '3920', 'CVRAdresse_husnummerFra': '42', 'CVRAdresse_etagebetegnelse': None, 'CVRAdresse_doerbetegnelse': None, 'CVRAdresse_kommunekode': '323', 'CVRAdresse_kommunenavn': 'KALUNDBORG', 'CVRAdresse_postdistrikt': 'Kalundborg', 'CVRAdresse_vejnavn': 'Kordilgade', 'CVRAdresse_husnummerTil': None, 'CVRAdresse_postnummer': '4400', 'CVRAdresse_supplerendeBynavn': None, 'CVRAdresse_adresseFritekst': None, 'CVRAdresse_landekode': 'DK', 'CVRAdresse_postboks': None, 'coNavn': None, 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': '2004-02-01', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Branche_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_branche = json.load(f)
# Access records directly
print(len(cvr_branche))           # number of records
print(cvr_branche[0].keys())      # keys in each record
print(cvr_branche[0])             # first record
# Out:
# 10469872
# dict_keys(['datafordelerOpdateringstid', 'sekvens', 'CVREnhedsId', 'vaerdi', 'vaerdiTekst', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:36:16.674664Z', 'sekvens': 0, 'CVREnhedsId': '1000568', 'vaerdi': '741100', 'vaerdiTekst': 'Advokatvirksomhed', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': '2007-12-31', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Navn_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_navn = json.load(f)
# Access records directly
print(len(cvr_navn))           # number of records
print(cvr_navn[0].keys())      # keys in each record
print(cvr_navn[0])             # first record
# Out:
# 7927267
# dict_keys(['datafordelerOpdateringstid', 'CVREnhedsId', 'sekvens', 'vaerdi', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:07.258824Z', 'CVREnhedsId': '1000568', 'sekvens': 0, 'vaerdi': 'ADVOKATSELSKABET C. K. LUND. KALUNDBORG/ASNÆS ApS', 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1996-12-06', 'virkningTil': '2023-12-27', 'virkningsaktoer': 'ERST', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Produktionsenhed_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_produktionsenhed = json.load(f)
# Access records directly
print(len(cvr_produktionsenhed))           # number of records
print(cvr_produktionsenhed[0].keys())      # keys in each record
print(cvr_produktionsenhed[0])             # first record
# Out:
# 2876876
# dict_keys(['datafordelerOpdateringstid', 'id', 'pNummer', 'tilknyttetVirksomhedsCVRNummer', 'produktionsenhedStartdato', 'produktionsenhedOphoersdato', 'tilknyttetTilVirksomhedStartdato', 'tilknyttetTilVirksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2026-01-14T09:48:02.395821Z', 'id': '1002173', 'pNummer': 1003223258, 'tilknyttetVirksomhedsCVRNummer': 89224918, 'produktionsenhedStartdato': '1982-01-01', 'produktionsenhedOphoersdato': None, 'tilknyttetTilVirksomhedStartdato': '1982-01-01', 'tilknyttetTilVirksomhedOphoersdato': None, 'registreringFra': '2026-01-14T09:45:38Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1982-01-01', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %%
with open("../data/raw/cvr_raw/cvr_temporal/CVR_V1_Virksomhed_TotalDownload_json_Temporal_324.json", "r", encoding="utf-8") as f:
    cvr_virksomhed = json.load(f)
# Access records directly
print(len(cvr_virksomhed))           # number of records
print(cvr_virksomhed[0].keys())      # keys in each record
print(cvr_virksomhed[0])             # first record
# Out:
# 2449807
# dict_keys(['datafordelerOpdateringstid', 'id', 'CVRNummer', 'virksomhedStartdato', 'virksomhedOphoersdato', 'registreringFra', 'registreringTil', 'registreringsaktoer', 'virkningFra', 'virkningTil', 'virkningsaktoer', 'status', 'feltliste'])
# {'datafordelerOpdateringstid': '2024-12-29T15:35:00.989831Z', 'id': '1000568', 'CVRNummer': 16079944, 'virksomhedStartdato': '1992-01-03', 'virksomhedOphoersdato': None, 'registreringFra': '2024-12-29T15:24:57Z', 'registreringTil': None, 'registreringsaktoer': 'ERST', 'virkningFra': '1992-01-03', 'virkningTil': None, 'virkningsaktoer': 'ERST', 'status': 'aktiv', 'feltliste': 'Aendret'}

# %% [markdown]
# ### filter for ID's in Copenhagen with kommunekode = 101

# %%
cvr_adress_cph = [r for r in cvr_adress if r.get("CVRAdresse_kommunekode") == "101"]
print(f"Filtered: {len(cvr_adress_cph)} / {len(cvr_adress)} records with kommunekode 101")
# Out:
# Filtered: 1795709 / 12192264 records with kommunekode 101

# %% [markdown]
# ### join json on cvr_adress_cph

# %%
# change "id" to "CVREnhedsId" in all datasets for easier merging later
for dataset in [cvr_adress_cph, cvr_branche, cvr_navn, cvr_produktionsenhed, cvr_virksomhed]:
    for record in dataset:
        if "id" in record:
            record["CVREnhedsId"] = record.pop("id")

# %%
# change names in datasets to not overlap

for record in cvr_navn:
    if "vaerdi" in record:
        record["navn"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdi" in record:
        record["branche_kode"] = record.pop("vaerdi")

for record in cvr_branche:
    if "vaerdiTekst" in record:
        record["branche_navn"] = record.pop("vaerdiTekst")

# %%
# Free the unfiltered address list – only cvr_adress_cph is needed from here on
del cvr_adress
gc.collect()
print("Freed cvr_adress from memory")
# Out:
# Freed cvr_adress from memory

# %%
# join the datasets on "CVREnhedsId" to create a master dataset for Copenhagen
# Memory-efficient: build each lookup and free the source list immediately



def to_lookup(dataset):
    lookup = {}
    for r in dataset:
        eid = r.get("CVREnhedsId")
        if eid is not None:
            lookup[eid] = {k: v for k, v in r.items() if k != "CVREnhedsId"}
    return lookup

# Build lookups one at a time, freeing each source list after
branche_lkp = to_lookup(cvr_branche)
del cvr_branche; gc.collect()

navn_lkp = to_lookup(cvr_navn)
del cvr_navn; gc.collect()

prod_lkp = to_lookup(cvr_produktionsenhed)
del cvr_produktionsenhed; gc.collect()

virk_lkp = to_lookup(cvr_virksomhed)
del cvr_virksomhed; gc.collect()

print("Lookups built, source lists freed")

# Start from cvr_adress_cph and left-join the others
joined_cph = []
for rec in cvr_adress_cph:
    eid = rec.get("CVREnhedsId")
    merged = dict(rec)
    merged.update(branche_lkp.get(eid, {}))
    merged.update(navn_lkp.get(eid, {}))
    merged.update(prod_lkp.get(eid, {}))
    merged.update(virk_lkp.get(eid, {}))
    joined_cph.append(merged)

# Free lookups and the address list now that join is done
del branche_lkp, navn_lkp, prod_lkp, virk_lkp, cvr_adress_cph
gc.collect()

print(f"joined_cph: {len(joined_cph)} records, {len(joined_cph[0].keys())} columns")
print(f"Sample keys: {list(joined_cph[0].keys())[:15]}")
# Out:
# Lookups built, source lists freed
# joined_cph: 1795709 records, 34 columns
# Sample keys: ['datafordelerOpdateringstid', 'AdresseringAnvendelse', 'CVREnhedsId', 'Adresse', 'CVRAdresse_vejkode', 'CVRAdresse_husnummerFra', 'CVRAdresse_etagebetegnelse', 'CVRAdresse_doerbetegnelse', 'CVRAdresse_kommunekode', 'CVRAdresse_kommunenavn', 'CVRAdresse_postdistrikt', 'CVRAdresse_vejnavn', 'CVRAdresse_husnummerTil', 'CVRAdresse_postnummer', 'CVRAdresse_supplerendeBynavn']

# %%
# filter objects to only include certain feautures for easier handling later
features_to_keep = [
    "CVREnhedsId",
    "Adresse",
    "branche_kode",
    "branche_navn",
    "navn",
    "CVRNummer",
    "virksomhedStartdato",
    "virksomhedOphoersdato",
    "pNummer",
    "tilknyttetVirksomhedsCVRNummer",
    "produktionsenhedStartdato",
    "produktionsenhedOphoersdato",
]

# %%
# filter joined_cph to only include features in features_to_keep
joined_cph = [
    {k: v for k, v in rec.items() if k in features_to_keep}
    for rec in joined_cph
]

# count how many unique keys appear across all records
all_keys = set()
for rec in joined_cph:
    all_keys.update(rec.keys())
print(f"Filtered to {len(all_keys)} unique features across {len(joined_cph)} records")
print(f"Features present: {sorted(all_keys)}")
# Out:
# Filtered to 12 unique features across 1795709 records
# Features present: ['Adresse', 'CVREnhedsId', 'CVRNummer', 'branche_kode', 'branche_navn', 'navn', 'pNummer', 'produktionsenhedOphoersdato', 'produktionsenhedStartdato', 'tilknyttetVirksomhedsCVRNummer', 'virksomhedOphoersdato', 'virksomhedStartdato']

# %%
# Save joined_cph to disk so we can skip cells 1-18 on future runs
out_path = os.path.join("..", "data", "processed",  "temporal_join_cph.json")
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(joined_cph, f, ensure_ascii=False)
print(f"Saved {len(joined_cph)} records to {out_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 out_path = os.path.join("..", "data", "processed",  "temporal_join_cph.json")
#       3 with open(out_path, "w", encoding="utf-8") as f:
# ----> 4     json.dump(joined_cph, f, ensure_ascii=False)
#       5 print(f"Saved {len(joined_cph)} records to {out_path}")
#
# NameError: name 'joined_cph' is not defined

# %%
# Delete everything no longer needed
for _var in ["joined_cph", "all_keys", "dataset", "eid", "f",
             "merged", "rec", "record"]:
    if _var in dir():
        exec(f"del {_var}")
gc.collect()

# Reload only what downstream cells need
with open(os.path.join("..", "data", "processed", "temporal_join_cph.json"), "r", encoding="utf-8") as f:
    joined_cph = json.load(f)

print(f"RAM cleared & reloaded joined_cph ({len(joined_cph)} records)")
# Out:
# RAM cleared & reloaded joined_cph (1795709 records)

# %%
# group production units by their parent virksomhed CVRNummer
from collections import defaultdict

grouped = defaultdict(lambda: {"virksomhed": {}, "produktionsenheder": []})

for rec in joined_cph:
    cvr_nr = rec.get("CVRNummer") or rec.get("tilknyttetVirksomhedsCVRNummer")
    if cvr_nr is None:
        continue

    # store virksomhed-level fields once
    if not grouped[cvr_nr]["virksomhed"]:
        grouped[cvr_nr]["virksomhed"] = {
            "CVRNummer": cvr_nr,
            "navn": rec.get("navn"),
            "virksomhedStartdato": rec.get("virksomhedStartdato"),
            "virksomhedOphoersdato": rec.get("virksomhedOphoersdato"),
            "branche_kode": rec.get("branche_kode"),
            "branche_navn": rec.get("branche_navn"),
        }

    # append produktionsenhed info if present
    if rec.get("pNummer"):
        grouped[cvr_nr]["produktionsenheder"].append({
            "CVREnhedsId": rec.get("CVREnhedsId"),
            "Adresse": rec.get("Adresse"),
            "pNummer": rec.get("pNummer"),
            "tilknyttetVirksomhedsCVRNummer": rec.get("tilknyttetVirksomhedsCVRNummer"),
            "produktionsenhedStartdato": rec.get("produktionsenhedStartdato"),
            "produktionsenhedOphoersdato": rec.get("produktionsenhedOphoersdato"),
        })

grouped = dict(grouped)
print(f"Grouped into {len(grouped)} unique virksomheder")
# show an example with multiple produktionsenheder
example = next((v for v in grouped.values() if len(v['produktionsenheder']) > 1), None)
if example:
    print(f"\nExample virksomhed: {example['virksomhed']['navn']}")
    print(f"  CVRNummer: {example['virksomhed']['CVRNummer']}")
    print(f"  Produktionsenheder: {len(example['produktionsenheder'])}")
    for pe in example['produktionsenheder'][:3]:
        print(f"    pNummer: {pe['pNummer']}, Adresse: {pe['Adresse']}")
# Out:
# Grouped into 449914 unique virksomheder
#
# Example virksomhed: Købmagergade 53 A/S
#   CVRNummer: 89554012
#   Produktionsenheder: 2
#     pNummer: 1002821486, Adresse: None
#     pNummer: 1002821486, Adresse: None

# %%
# save grouped structure to json
output_path = "../data/processed/cvr/cvr_cph_joined_manual_temporal.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(grouped, f, ensure_ascii=False, indent=2)
print(f"Saved {len(grouped)} virksomheder to {output_path}")
# Out:
# Saved 449914 virksomheder to ../data/processed/cvr/cvr_cph_joined_manual_temporal.json

# %% [markdown]
# ## Get adresses from DAWA API

# %%
# input joined json dataset
with open("../data/processed/cvr/cvr_cph_joined_manual_temporal.json", "r", encoding="utf-8") as f:
    master_data = json.load(f)

print(f"Type: {type(master_data).__name__}, {len(master_data)} virksomheder")

# peek at the first entry
first_key = next(iter(master_data))
print(f"\nFirst CVRNummer: {first_key}")
print(json.dumps(master_data[first_key], indent=2, ensure_ascii=False))
# Out:
# Type: dict, 449914 virksomheder
#
# First CVRNummer: 89554012
# {
#   "virksomhed": {
#     "CVRNummer": 89554012,
#     "navn": "Købmagergade 53 A/S",
#     "virksomhedStartdato": "1979-12-01",
#     "virksomhedOphoersdato": null,
#     "branche_kode": "682040",
#     "branche_navn": "Udlejning af erhvervsejendomme"
#   },
#   "produktionsenheder": [
#     {
#       "CVREnhedsId": "4003245108",
#       "Adresse": null,
#       "pNummer": 1002821486,
#       "tilknyttetVirksomhedsCVRNummer": 89554012,
#       "produktionsenhedStartdato": "1979-12-01",
#       "produktionsenhedOphoersdato": null
#     },
#     {
#       "CVREnhedsId": "4003245108",
#       "Adresse": null,
#       "pNummer": 1002821486,
#       "tilknyttetVirksomhedsCVRNummer": 89554012,
#       "produktionsenhedStartdato": "1979-12-01",
#       "produktionsenhedOphoersdato": null
#     }
#   ]
# }

# %%
import aiohttp
import asyncio
import nest_asyncio
nest_asyncio.apply()
import time
import statistics

# %%
# --- CONFIG ---
MAX_VIRKSOMHEDER = None   # None = process all
CONCURRENCY = 25              # 5 concurrent = ~10 req/s (API limit)
BATCH_SIZE = 500
MAX_RETRIES = 3
TIMEOUT_SEC = 30
SAVE_INTERVAL = 5000         # auto-save progress every N PEs

sem = asyncio.Semaphore(CONCURRENCY)

# --- MONITORING ---
api_times = []
status_codes = {}
retry_count = 0

async def fetch_coordinates(session, adresse_id):
    """Single-step DAWA lookup: /adresser/{id} already returns coordinates."""
    global retry_count
    for attempt in range(MAX_RETRIES):
        try:
            async with sem:
                t_start = time.perf_counter()

                async with session.get(
                    f"https://api.dataforsyningen.dk/adresser/{adresse_id}",
                    timeout=aiohttp.ClientTimeout(total=TIMEOUT_SEC),
                ) as resp:
                    status_codes[resp.status] = status_codes.get(resp.status, 0) + 1
                    if resp.status != 200:
                        api_times.append(time.perf_counter() - t_start)
                        return None, None
                    data = await resp.json()

                koordinater = data.get("adgangsadresse", {}).get("adgangspunkt", {}).get("koordinater", [])
                api_times.append(time.perf_counter() - t_start)
                if len(koordinater) == 2:
                    return koordinater[0], koordinater[1]
                return None, None

        except (aiohttp.ClientError, asyncio.TimeoutError):
            retry_count += 1
            if attempt < MAX_RETRIES - 1:
                await asyncio.sleep(1 * (attempt + 1))
                continue
            return None, None
    return None, None


def save_checkpoint():
    """Save current master_data progress to JSON."""
    path = "../data/processed/cvr/cvr_cph_addresses.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(master_data, f, ensure_ascii=False)
    return path


async def process_all():
    pe_tasks = []
    count = 0
    for cvr_nr, entry in master_data.items():
        if MAX_VIRKSOMHEDER is not None and count >= MAX_VIRKSOMHEDER:
            break
        for pe in entry.get("produktionsenheder", []):
            adresse_id = pe.get("Adresse")
            if adresse_id:
                pe_tasks.append((pe, adresse_id))
        count += 1

    total_pe = len(pe_tasks)
    print(f"Queued {total_pe:,} PEs from {count:,} virksomheder (CONCURRENCY={CONCURRENCY})")
    print(f"Using single-step lookup (1 API call per PE instead of 2)")

    failed = 0
    connector = aiohttp.TCPConnector(limit=CONCURRENCY)
    async with aiohttp.ClientSession(connector=connector) as session:
        for batch_start in range(0, total_pe, BATCH_SIZE):
            batch = pe_tasks[batch_start : batch_start + BATCH_SIZE]
            tasks = [fetch_coordinates(session, aid) for _, aid in batch]
            results = await asyncio.gather(*tasks, return_exceptions=True)

            batch_failed = 0
            for (pe, _), result in zip(batch, results):
                if isinstance(result, Exception) or result == (None, None):
                    pe["longitude"] = None
                    pe["latitude"] = None
                    failed += 1
                    batch_failed += 1
                else:
                    pe["longitude"], pe["latitude"] = result

            done = min(batch_start + BATCH_SIZE, total_pe)
            elapsed_so_far = time.perf_counter() - t0
            avg_ms = statistics.mean(api_times) * 1000 if api_times else 0
            p50_ms = statistics.median(api_times) * 1000 if api_times else 0
            rps = done / elapsed_so_far if elapsed_so_far > 0 else 0
            eta_min = ((total_pe - done) / rps / 60) if rps > 0 else 0
            print(f"  [{done:,}/{total_pe:,}] ok:{len(batch)-batch_failed} fail:{batch_failed} | p50:{p50_ms:.0f}ms avg:{avg_ms:.0f}ms | {rps:.1f} PE/s | retries:{retry_count} | ETA:{eta_min:.1f}min")

            # auto-save checkpoint
            if done % SAVE_INTERVAL < BATCH_SIZE:
                save_checkpoint()
                print(f"    💾 checkpoint saved ({done:,} PEs)")

    return count, total_pe, failed


t0 = time.perf_counter()
count, total_pe, failed = asyncio.get_event_loop().run_until_complete(process_all())
elapsed = time.perf_counter() - t0

# final save
save_checkpoint()

print(f"\nProcessed {count:,} virksomheder, {total_pe:,} produktionsenheder in {elapsed:.1f}s ({elapsed/60:.1f}min)")
print(f"Coordinates found: {total_pe - failed:,}, failed: {failed:,}")

if api_times:
    avg_ms = statistics.mean(api_times) * 1000
    p50_ms = statistics.median(api_times) * 1000
    p95_ms = sorted(api_times)[int(len(api_times) * 0.95)] * 1000
    max_ms = max(api_times) * 1000
    rps = total_pe / elapsed
    print(f"\n--- API Rate Monitor (CONCURRENCY={CONCURRENCY}) ---")
    print(f"  Total lookups:   {len(api_times):,} (1 HTTP call each)")
    print(f"  Wall-clock:      {rps:.1f} PE/sec")
    print(f"  API latency p50: {p50_ms:.0f}ms")
    print(f"  API latency avg: {avg_ms:.0f}ms")
    print(f"  API latency p95: {p95_ms:.0f}ms")
    print(f"  API latency max: {max_ms:.0f}ms")
    print(f"  Retries used:    {retry_count} ({retry_count*100//(total_pe or 1)}% of lookups)")
    print(f"  HTTP status codes: {status_codes}")
    if retry_count > total_pe * 0.05:
        print(f"\n  ⚠ High retry rate — consider lowering CONCURRENCY to {max(3, CONCURRENCY-2)}")
    elif avg_ms < 300:
        print(f"\n  ✓ API latency healthy — could try CONCURRENCY={CONCURRENCY+5}")
# Out:
# Queued 300,765 PEs from 449,914 virksomheder (CONCURRENCY=25)
# Using single-step lookup (1 API call per PE instead of 2)
#   [500/300,765] ok:496 fail:4 | p50:44ms avg:60ms | 259.3 PE/s | retries:0 | ETA:19.3min
#   [1,000/300,765] ok:493 fail:7 | p50:43ms avg:52ms | 353.0 PE/s | retries:0 | ETA:14.2min
#   [1,500/300,765] ok:498 fail:2 | p50:43ms avg:51ms | 344.0 PE/s | retries:0 | ETA:14.5min
#   [2,000/300,765] ok:485 fail:15 | p50:43ms avg:49ms | 379.5 PE/s | retries:0 | ETA:13.1min
#   [2,500/300,765] ok:497 fail:3 | p50:43ms avg:49ms | 399.4 PE/s | retries:0 | ETA:12.4min
#   [3,000/300,765] ok:497 fail:3 | p50:43ms avg:48ms | 412.7 PE/s | retries:0 | ETA:12.0min
#   [3,500/300,765] ok:491 fail:9 | p50:43ms avg:49ms | 401.1 PE/s | retries:0 | ETA:12.4min
#   [4,000/300,765] ok:494 fail:6 | p50:43ms avg:48ms | 416.4 PE/s | retries:0 | ETA:11.9min
#   [4,500/300,765] ok:491 fail:9 | p50:43ms avg:48ms | 427.5 PE/s | retries:0 | ETA:11.6min
#   [5,000/300,765] ok:494 fail:6 | p50:43ms avg:48ms | 435.4 PE/s | retries:0 | ETA:11.3min
#     💾 checkpoint saved (5,000 PEs)
#   [5,500/300,765] ok:496 fail:4 | p50:43ms avg:48ms | 241.0 PE/s | retries:0 | ETA:20.4min
#   [6,000/300,765] ok:493 fail:7 | p50:43ms avg:48ms | 252.5 PE/s | retries:0 | ETA:19.5min
#   [6,500/300,765] ok:498 fail:2 | p50:43ms avg:48ms | 262.1 PE/s | retries:0 | ETA:18.7min
#   [7,000/300,765] ok:494 fail:6 | p50:43ms avg:48ms | 271.7 PE/s | retries:0 | ETA:18.0min
#   [7,500/300,765] ok:495 fail:5 | p50:43ms avg:48ms | 280.8 PE/s | retries:0 | ETA:17.4min
#   [8,000/300,765] ok:497 fail:3 | p50:44ms avg:48ms | 287.5 PE/s | retries:0 | ETA:17.0min
#   [8,500/300,765] ok:499 fail:1 | p50:44ms avg:49ms | 289.4 PE/s | retries:0 | ETA:16.8min
#   [9,000/300,765] ok:494 fail:6 | p50:44ms avg:49ms | 296.3 PE/s | retries:0 | ETA:16.4min
#   [9,500/300,765] ok:491 fail:9 | p50:44ms avg:49ms | 303.6 PE/s | retries:0 | ETA:16.0min
#   [10,000/300,765] ok:494 fail:6 | p50:44ms avg:49ms | 310.6 PE/s | retries:0 | ETA:15.6min
#     💾 checkpoint saved (10,000 PEs)
#   [10,500/300,765] ok:498 fail:2 | p50:44ms avg:49ms | 237.8 PE/s | retries:0 | ETA:20.3min
#   [11,000/300,765] ok:499 fail:1 | p50:44ms avg:48ms | 244.0 PE/s | retries:0 | ETA:19.8min
#   [11,500/300,765] ok:491 fail:9 | p50:44ms avg:48ms | 250.0 PE/s | retries:0 | ETA:19.3min
#   [12,000/300,765] ok:492 fail:8 | p50:44ms avg:48ms | 255.8 PE/s | retries:0 | ETA:18.8min
#   [12,500/300,765] ok:497 fail:3 | p50:44ms avg:48ms | 261.2 PE/s | retries:0 | ETA:18.4min
#   [13,000/300,765] ok:497 fail:3 | p50:44ms avg:48ms | 266.2 PE/s | retries:0 | ETA:18.0min
#   [13,500/300,765] ok:498 fail:2 | p50:44ms avg:48ms | 270.9 PE/s | retries:0 | ETA:17.7min
#   [14,000/300,765] ok:491 fail:9 | p50:44ms avg:48ms | 275.5 PE/s | retries:0 | ETA:17.3min
#   [14,500/300,765] ok:497 fail:3 | p50:44ms avg:48ms | 279.7 PE/s | retries:0 | ETA:17.1min
#   [15,000/300,765] ok:496 fail:4 | p50:44ms avg:48ms | 284.0 PE/s | retries:0 | ETA:16.8min
#     💾 checkpoint saved (15,000 PEs)
#   [15,500/300,765] ok:498 fail:2 | p50:44ms avg:48ms | 239.1 PE/s | retries:0 | ETA:19.9min
#   [16,000/300,765] ok:495 fail:5 | p50:44ms avg:48ms | 243.2 PE/s | retries:0 | ETA:19.5min
#   [16,500/300,765] ok:495 fail:5 | p50:44ms avg:48ms | 246.8 PE/s | retries:0 | ETA:19.2min
#   [17,000/300,765] ok:495 fail:5 | p50:44ms avg:48ms | 250.8 PE/s | retries:0 | ETA:18.9min
#   [17,500/300,765] ok:491 fail:9 | p50:44ms avg:48ms | 254.1 PE/s | retries:0 | ETA:18.6min
#   [18,000/300,765] ok:490 fail:10 | p50:44ms avg:48ms | 257.2 PE/s | retries:0 | ETA:18.3min
#   [18,500/300,765] ok:492 fail:8 | p50:44ms avg:48ms | 260.7 PE/s | retries:0 | ETA:18.0min
#   [19,000/300,765] ok:498 fail:2 | p50:44ms avg:48ms | 264.2 PE/s | retries:0 | ETA:17.8min
#   [19,500/300,765] ok:499 fail:1 | p50:44ms avg:48ms | 267.7 PE/s | retries:0 | ETA:17.5min
#   [20,000/300,765] ok:493 fail:7 | p50:44ms avg:48ms | 270.7 PE/s | retries:0 | ETA:17.3min
#     💾 checkpoint saved (20,000 PEs)
#   [20,500/300,765] ok:494 fail:6 | p50:44ms avg:48ms | 238.3 PE/s | retries:0 | ETA:19.6min
#   [21,000/300,765] ok:490 fail:10 | p50:44ms avg:48ms | 240.8 PE/s | retries:0 | ETA:19.4min
#   [21,500/300,765] ok:490 fail:10 | p50:45ms avg:48ms | 243.6 PE/s | retries:0 | ETA:19.1min
#   [22,000/300,765] ok:496 fail:4 | p50:45ms avg:48ms | 246.6 PE/s | retries:0 | ETA:18.8min
#   [22,500/300,765] ok:493 fail:7 | p50:45ms avg:48ms | 249.4 PE/s | retries:0 | ETA:18.6min
#   [23,000/300,765] ok:496 fail:4 | p50:45ms avg:48ms | 251.5 PE/s | retries:0 | ETA:18.4min
#   [23,500/300,765] ok:492 fail:8 | p50:45ms avg:48ms | 254.2 PE/s | retries:0 | ETA:18.2min
#   [24,000/300,765] ok:497 fail:3 | p50:45ms avg:48ms | 256.9 PE/s | retries:0 | ETA:18.0min
#   [24,500/300,765] ok:497 fail:3 | p50:45ms avg:48ms | 259.6 PE/s | retries:0 | ETA:17.7min
#   [25,000/300,765] ok:497 fail:3 | p50:45ms avg:48ms | 262.4 PE/s | retries:0 | ETA:17.5min
#     💾 checkpoint saved (25,000 PEs)
#   [25,500/300,765] ok:496 fail:4 | p50:44ms avg:48ms | 238.0 PE/s | retries:0 | ETA:19.3min
#   [26,000/300,765] ok:493 fail:7 | p50:44ms avg:48ms | 240.5 PE/s | retries:0 | ETA:19.0min
#   [26,500/300,765] ok:495 fail:5 | p50:45ms avg:48ms | 242.6 PE/s | retries:0 | ETA:18.8min
#   [27,000/300,765] ok:491 fail:9 | p50:45ms avg:48ms | 244.8 PE/s | retries:0 | ETA:18.6min
#   [27,500/300,765] ok:496 fail:4 | p50:45ms avg:48ms | 247.1 PE/s | retries:0 | ETA:18.4min
#   [28,000/300,765] ok:495 fail:5 | p50:45ms avg:48ms | 249.1 PE/s | retries:0 | ETA:18.2min
#   [28,500/300,765] ok:496 fail:4 | p50:45ms avg:48ms | 251.3 PE/s | retries:0 | ETA:18.1min
#   [29,000/300,765] ok:495 fail:5 | p50:45ms avg:48ms | 253.3 PE/s | retries:0 | ETA:17.9min
#   [29,500/300,765] ok:496 fail:4 | p50:45ms avg:48ms | 255.6 PE/s | retries:0 | ETA:17.7min
#   [30,000/300,765] ok:495 fail:5 | p50:45ms avg:48ms | 257.6 PE/s | retries:0 | ETA:17.5min
#     💾 checkpoint saved (30,000 PEs)
#   [30,500/300,765] ok:494 fail:6 | p50:45ms avg:48ms | 226.5 PE/s | retries:0 | ETA:19.9min
#   [31,000/300,765] ok:496 fail:4 | p50:45ms avg:49ms | 226.6 PE/s | retries:0 | ETA:19.8min
#   [31,500/300,765] ok:492 fail:8 | p50:45ms avg:50ms | 224.6 PE/s | retries:0 | ETA:20.0min
#   [32,000/300,765] ok:493 fail:7 | p50:45ms avg:51ms | 223.7 PE/s | retries:0 | ETA:20.0min
#   [32,500/300,765] ok:494 fail:6 | p50:45ms avg:51ms | 224.4 PE/s | retries:0 | ETA:19.9min
#   [33,000/300,765] ok:500 fail:0 | p50:46ms avg:52ms | 225.2 PE/s | retries:0 | ETA:19.8min
#   [33,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 226.9 PE/s | retries:0 | ETA:19.6min
#   [34,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 228.6 PE/s | retries:0 | ETA:19.4min
#   [34,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 229.5 PE/s | retries:0 | ETA:19.3min
#   [35,000/300,765] ok:489 fail:11 | p50:46ms avg:52ms | 231.1 PE/s | retries:0 | ETA:19.2min
#     💾 checkpoint saved (35,000 PEs)
#   [35,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 195.9 PE/s | retries:0 | ETA:22.6min
#   [36,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 197.5 PE/s | retries:0 | ETA:22.3min
#   [36,500/300,765] ok:499 fail:1 | p50:46ms avg:52ms | 199.0 PE/s | retries:0 | ETA:22.1min
#   [37,000/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 200.6 PE/s | retries:0 | ETA:21.9min
#   [37,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 202.2 PE/s | retries:0 | ETA:21.7min
#   [38,000/300,765] ok:499 fail:1 | p50:46ms avg:52ms | 203.7 PE/s | retries:0 | ETA:21.5min
#   [38,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 205.3 PE/s | retries:0 | ETA:21.3min
#   [39,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 206.8 PE/s | retries:0 | ETA:21.1min
#   [39,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 208.4 PE/s | retries:0 | ETA:20.9min
#   [40,000/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 209.9 PE/s | retries:0 | ETA:20.7min
#     💾 checkpoint saved (40,000 PEs)
#   [40,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 184.9 PE/s | retries:0 | ETA:23.5min
#   [41,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 186.3 PE/s | retries:0 | ETA:23.2min
#   [41,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 187.7 PE/s | retries:0 | ETA:23.0min
#   [42,000/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 189.0 PE/s | retries:0 | ETA:22.8min
#   [42,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 190.3 PE/s | retries:0 | ETA:22.6min
#   [43,000/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 191.5 PE/s | retries:0 | ETA:22.4min
#   [43,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 192.8 PE/s | retries:0 | ETA:22.2min
#   [44,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 194.0 PE/s | retries:0 | ETA:22.1min
#   [44,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 195.3 PE/s | retries:0 | ETA:21.9min
#   [45,000/300,765] ok:499 fail:1 | p50:46ms avg:51ms | 196.5 PE/s | retries:0 | ETA:21.7min
#     💾 checkpoint saved (45,000 PEs)
#   [45,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 175.6 PE/s | retries:0 | ETA:24.2min
#   [46,000/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 176.6 PE/s | retries:0 | ETA:24.0min
#   [46,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 177.7 PE/s | retries:0 | ETA:23.8min
#   [47,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 178.8 PE/s | retries:0 | ETA:23.7min
#   [47,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 179.9 PE/s | retries:0 | ETA:23.5min
#   [48,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 181.0 PE/s | retries:0 | ETA:23.3min
#   [48,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 182.1 PE/s | retries:0 | ETA:23.1min
#   [49,000/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 183.3 PE/s | retries:0 | ETA:22.9min
#   [49,500/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 184.4 PE/s | retries:0 | ETA:22.7min
#   [50,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 185.3 PE/s | retries:0 | ETA:22.6min
#     💾 checkpoint saved (50,000 PEs)
#   [50,500/300,765] ok:499 fail:1 | p50:46ms avg:52ms | 168.4 PE/s | retries:0 | ETA:24.8min
#   [51,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 169.4 PE/s | retries:0 | ETA:24.6min
#   [51,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 170.4 PE/s | retries:0 | ETA:24.4min
#   [52,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 171.3 PE/s | retries:0 | ETA:24.2min
#   [52,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 172.4 PE/s | retries:0 | ETA:24.0min
#   [53,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 173.4 PE/s | retries:0 | ETA:23.8min
#   [53,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.4 PE/s | retries:0 | ETA:23.6min
#   [54,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 175.4 PE/s | retries:0 | ETA:23.4min
#   [54,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 176.4 PE/s | retries:0 | ETA:23.3min
#   [55,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.4 PE/s | retries:0 | ETA:23.1min
#     💾 checkpoint saved (55,000 PEs)
#   [55,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 165.5 PE/s | retries:0 | ETA:24.7min
#   [56,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 166.4 PE/s | retries:0 | ETA:24.5min
#   [56,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 167.4 PE/s | retries:0 | ETA:24.3min
#   [57,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 168.3 PE/s | retries:0 | ETA:24.1min
#   [57,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 168.7 PE/s | retries:0 | ETA:24.0min
#   [58,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 169.6 PE/s | retries:0 | ETA:23.9min
#   [58,500/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 170.6 PE/s | retries:0 | ETA:23.7min
#   [59,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 171.5 PE/s | retries:0 | ETA:23.5min
#   [59,500/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 172.4 PE/s | retries:0 | ETA:23.3min
#   [60,000/300,765] ok:489 fail:11 | p50:46ms avg:52ms | 173.3 PE/s | retries:0 | ETA:23.2min
#     💾 checkpoint saved (60,000 PEs)
#   [60,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 160.3 PE/s | retries:0 | ETA:25.0min
#   [61,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 160.8 PE/s | retries:0 | ETA:24.9min
#   [61,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 161.6 PE/s | retries:0 | ETA:24.7min
#   [62,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 162.5 PE/s | retries:0 | ETA:24.5min
#   [62,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 163.3 PE/s | retries:0 | ETA:24.3min
#   [63,000/300,765] ok:485 fail:15 | p50:46ms avg:52ms | 164.1 PE/s | retries:0 | ETA:24.1min
#   [63,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 164.9 PE/s | retries:0 | ETA:24.0min
#   [64,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 165.5 PE/s | retries:0 | ETA:23.8min
#   [64,500/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 166.4 PE/s | retries:0 | ETA:23.7min
#   [65,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 167.2 PE/s | retries:0 | ETA:23.5min
#     💾 checkpoint saved (65,000 PEs)
#   [65,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 156.6 PE/s | retries:0 | ETA:25.0min
#   [66,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 157.5 PE/s | retries:0 | ETA:24.8min
#   [66,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 158.3 PE/s | retries:0 | ETA:24.7min
#   [67,000/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 159.1 PE/s | retries:0 | ETA:24.5min
#   [67,500/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 159.9 PE/s | retries:0 | ETA:24.3min
#   [68,000/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 160.6 PE/s | retries:0 | ETA:24.2min
#   [68,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 161.4 PE/s | retries:0 | ETA:24.0min
#   [69,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 162.2 PE/s | retries:0 | ETA:23.8min
#   [69,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 163.0 PE/s | retries:0 | ETA:23.6min
#   [70,000/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 163.8 PE/s | retries:0 | ETA:23.5min
#     💾 checkpoint saved (70,000 PEs)
#   [70,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 160.7 PE/s | retries:0 | ETA:23.9min
#   [71,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 161.4 PE/s | retries:0 | ETA:23.7min
#   [71,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 162.2 PE/s | retries:0 | ETA:23.6min
#   [72,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 163.0 PE/s | retries:0 | ETA:23.4min
#   [72,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 163.7 PE/s | retries:0 | ETA:23.2min
#   [73,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 164.5 PE/s | retries:0 | ETA:23.1min
#   [73,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 165.2 PE/s | retries:0 | ETA:22.9min
#   [74,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 166.0 PE/s | retries:0 | ETA:22.8min
#   [74,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 166.7 PE/s | retries:0 | ETA:22.6min
#   [75,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 167.4 PE/s | retries:0 | ETA:22.5min
#     💾 checkpoint saved (75,000 PEs)
#   [75,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 164.2 PE/s | retries:0 | ETA:22.9min
#   [76,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 164.9 PE/s | retries:0 | ETA:22.7min
#   [76,500/300,765] ok:491 fail:9 | p50:46ms avg:51ms | 165.6 PE/s | retries:0 | ETA:22.6min
#   [77,000/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 166.3 PE/s | retries:0 | ETA:22.4min
#   [77,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 167.0 PE/s | retries:0 | ETA:22.3min
#   [78,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 167.8 PE/s | retries:0 | ETA:22.1min
#   [78,500/300,765] ok:500 fail:0 | p50:46ms avg:51ms | 168.4 PE/s | retries:0 | ETA:22.0min
#   [79,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 169.1 PE/s | retries:0 | ETA:21.9min
#   [79,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 169.8 PE/s | retries:0 | ETA:21.7min
#   [80,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 170.5 PE/s | retries:0 | ETA:21.6min
#     💾 checkpoint saved (80,000 PEs)
#   [80,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 167.4 PE/s | retries:0 | ETA:21.9min
#   [81,000/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 167.9 PE/s | retries:0 | ETA:21.8min
#   [81,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 168.5 PE/s | retries:0 | ETA:21.7min
#   [82,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 169.2 PE/s | retries:0 | ETA:21.5min
#   [82,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 169.9 PE/s | retries:0 | ETA:21.4min
#   [83,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 170.5 PE/s | retries:0 | ETA:21.3min
#   [83,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 171.2 PE/s | retries:0 | ETA:21.1min
#   [84,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 171.9 PE/s | retries:0 | ETA:21.0min
#   [84,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 172.6 PE/s | retries:0 | ETA:20.9min
#   [85,000/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 173.2 PE/s | retries:0 | ETA:20.8min
#     💾 checkpoint saved (85,000 PEs)
#   [85,500/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 170.2 PE/s | retries:0 | ETA:21.1min
#   [86,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 170.9 PE/s | retries:0 | ETA:20.9min
#   [86,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 171.5 PE/s | retries:0 | ETA:20.8min
#   [87,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 172.2 PE/s | retries:0 | ETA:20.7min
#   [87,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 172.7 PE/s | retries:0 | ETA:20.6min
#   [88,000/300,765] ok:491 fail:9 | p50:46ms avg:51ms | 173.3 PE/s | retries:0 | ETA:20.5min
#   [88,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 174.0 PE/s | retries:0 | ETA:20.3min
#   [89,000/300,765] ok:500 fail:0 | p50:46ms avg:51ms | 174.6 PE/s | retries:0 | ETA:20.2min
#   [89,500/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 175.2 PE/s | retries:0 | ETA:20.1min
#   [90,000/300,765] ok:500 fail:0 | p50:46ms avg:51ms | 175.9 PE/s | retries:0 | ETA:20.0min
#     💾 checkpoint saved (90,000 PEs)
#   [90,500/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 172.7 PE/s | retries:0 | ETA:20.3min
#   [91,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 173.2 PE/s | retries:0 | ETA:20.2min
#   [91,500/300,765] ok:489 fail:11 | p50:46ms avg:51ms | 173.8 PE/s | retries:0 | ETA:20.1min
#   [92,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 174.5 PE/s | retries:0 | ETA:19.9min
#   [92,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 175.1 PE/s | retries:0 | ETA:19.8min
#   [93,000/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 175.7 PE/s | retries:0 | ETA:19.7min
#   [93,500/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 176.1 PE/s | retries:0 | ETA:19.6min
#   [94,000/300,765] ok:488 fail:12 | p50:46ms avg:51ms | 176.7 PE/s | retries:0 | ETA:19.5min
#   [94,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 177.3 PE/s | retries:0 | ETA:19.4min
#   [95,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 177.9 PE/s | retries:0 | ETA:19.3min
#     💾 checkpoint saved (95,000 PEs)
#   [95,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 175.0 PE/s | retries:0 | ETA:19.5min
#   [96,000/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 175.6 PE/s | retries:0 | ETA:19.4min
#   [96,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 176.2 PE/s | retries:0 | ETA:19.3min
#   [97,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 176.7 PE/s | retries:0 | ETA:19.2min
#   [97,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 177.3 PE/s | retries:0 | ETA:19.1min
#   [98,000/300,765] ok:490 fail:10 | p50:46ms avg:51ms | 177.9 PE/s | retries:0 | ETA:19.0min
#   [98,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 178.4 PE/s | retries:0 | ETA:18.9min
#   [99,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 178.9 PE/s | retries:0 | ETA:18.8min
#   [99,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 179.5 PE/s | retries:0 | ETA:18.7min
#   [100,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 180.0 PE/s | retries:0 | ETA:18.6min
#     💾 checkpoint saved (100,000 PEs)
#   [100,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 177.0 PE/s | retries:0 | ETA:18.9min
#   [101,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 177.6 PE/s | retries:0 | ETA:18.7min
#   [101,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 178.1 PE/s | retries:0 | ETA:18.6min
#   [102,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 178.6 PE/s | retries:0 | ETA:18.5min
#   [102,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 179.2 PE/s | retries:0 | ETA:18.4min
#   [103,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 179.7 PE/s | retries:0 | ETA:18.3min
#   [103,500/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 180.2 PE/s | retries:0 | ETA:18.2min
#   [104,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 180.7 PE/s | retries:0 | ETA:18.1min
#   [104,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 181.3 PE/s | retries:0 | ETA:18.0min
#   [105,000/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 181.8 PE/s | retries:0 | ETA:18.0min
#     💾 checkpoint saved (105,000 PEs)
#   [105,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 177.3 PE/s | retries:0 | ETA:18.4min
#   [106,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 177.9 PE/s | retries:0 | ETA:18.3min
#   [106,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 178.3 PE/s | retries:0 | ETA:18.2min
#   [107,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 178.8 PE/s | retries:0 | ETA:18.1min
#   [107,500/300,765] ok:491 fail:9 | p50:46ms avg:51ms | 179.2 PE/s | retries:0 | ETA:18.0min
#   [108,000/300,765] ok:500 fail:0 | p50:46ms avg:51ms | 179.6 PE/s | retries:0 | ETA:17.9min
#   [108,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 180.2 PE/s | retries:0 | ETA:17.8min
#   [109,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 180.5 PE/s | retries:0 | ETA:17.7min
#   [109,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 181.0 PE/s | retries:0 | ETA:17.6min
#   [110,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 181.5 PE/s | retries:0 | ETA:17.5min
#     💾 checkpoint saved (110,000 PEs)
#   [110,500/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 177.2 PE/s | retries:0 | ETA:17.9min
#   [111,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 177.6 PE/s | retries:0 | ETA:17.8min
#   [111,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 178.0 PE/s | retries:0 | ETA:17.7min
#   [112,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 178.4 PE/s | retries:0 | ETA:17.6min
#   [112,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 178.9 PE/s | retries:0 | ETA:17.5min
#   [113,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 179.3 PE/s | retries:0 | ETA:17.4min
#   [113,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 179.8 PE/s | retries:0 | ETA:17.4min
#   [114,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 180.2 PE/s | retries:0 | ETA:17.3min
#   [114,500/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 180.7 PE/s | retries:0 | ETA:17.2min
#   [115,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 181.2 PE/s | retries:0 | ETA:17.1min
#     💾 checkpoint saved (115,000 PEs)
#   [115,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 176.9 PE/s | retries:0 | ETA:17.5min
#   [116,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 177.4 PE/s | retries:0 | ETA:17.4min
#   [116,500/300,765] ok:498 fail:2 | p50:46ms avg:51ms | 177.8 PE/s | retries:0 | ETA:17.3min
#   [117,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 178.3 PE/s | retries:0 | ETA:17.2min
#   [117,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 178.7 PE/s | retries:0 | ETA:17.1min
#   [118,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 179.1 PE/s | retries:0 | ETA:17.0min
#   [118,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 179.5 PE/s | retries:0 | ETA:16.9min
#   [119,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 180.0 PE/s | retries:0 | ETA:16.8min
#   [119,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 180.5 PE/s | retries:0 | ETA:16.7min
#   [120,000/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 180.9 PE/s | retries:0 | ETA:16.7min
#     💾 checkpoint saved (120,000 PEs)
#   [120,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 176.9 PE/s | retries:0 | ETA:17.0min
#   [121,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 177.3 PE/s | retries:0 | ETA:16.9min
#   [121,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 177.8 PE/s | retries:0 | ETA:16.8min
#   [122,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 178.1 PE/s | retries:0 | ETA:16.7min
#   [122,500/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 178.5 PE/s | retries:0 | ETA:16.6min
#   [123,000/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 179.0 PE/s | retries:0 | ETA:16.6min
#   [123,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 179.1 PE/s | retries:0 | ETA:16.5min
#   [124,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 179.5 PE/s | retries:0 | ETA:16.4min
#   [124,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 180.0 PE/s | retries:0 | ETA:16.3min
#   [125,000/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 180.4 PE/s | retries:0 | ETA:16.2min
#     💾 checkpoint saved (125,000 PEs)
#   [125,500/300,765] ok:497 fail:3 | p50:46ms avg:51ms | 176.5 PE/s | retries:0 | ETA:16.6min
#   [126,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 176.9 PE/s | retries:0 | ETA:16.5min
#   [126,500/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 177.3 PE/s | retries:0 | ETA:16.4min
#   [127,000/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 177.7 PE/s | retries:0 | ETA:16.3min
#   [127,500/300,765] ok:491 fail:9 | p50:46ms avg:51ms | 178.1 PE/s | retries:0 | ETA:16.2min
#   [128,000/300,765] ok:490 fail:10 | p50:46ms avg:51ms | 178.5 PE/s | retries:0 | ETA:16.1min
#   [128,500/300,765] ok:495 fail:5 | p50:46ms avg:51ms | 178.9 PE/s | retries:0 | ETA:16.0min
#   [129,000/300,765] ok:493 fail:7 | p50:46ms avg:51ms | 179.3 PE/s | retries:0 | ETA:16.0min
#   [129,500/300,765] ok:492 fail:8 | p50:46ms avg:51ms | 179.7 PE/s | retries:0 | ETA:15.9min
#   [130,000/300,765] ok:496 fail:4 | p50:46ms avg:51ms | 180.1 PE/s | retries:0 | ETA:15.8min
#     💾 checkpoint saved (130,000 PEs)
#   [130,500/300,765] ok:494 fail:6 | p50:46ms avg:51ms | 176.5 PE/s | retries:0 | ETA:16.1min
#   [131,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 176.7 PE/s | retries:0 | ETA:16.0min
#   [131,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 177.1 PE/s | retries:0 | ETA:15.9min
#   [132,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 177.5 PE/s | retries:0 | ETA:15.8min
#   [132,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.9 PE/s | retries:0 | ETA:15.8min
#   [133,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 178.2 PE/s | retries:0 | ETA:15.7min
#   [133,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 178.6 PE/s | retries:0 | ETA:15.6min
#   [134,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 179.0 PE/s | retries:0 | ETA:15.5min
#   [134,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 179.3 PE/s | retries:0 | ETA:15.5min
#   [135,000/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 179.7 PE/s | retries:0 | ETA:15.4min
#     💾 checkpoint saved (135,000 PEs)
#   [135,500/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 176.1 PE/s | retries:0 | ETA:15.6min
#   [136,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 176.5 PE/s | retries:0 | ETA:15.6min
#   [136,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 176.8 PE/s | retries:0 | ETA:15.5min
#   [137,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.2 PE/s | retries:0 | ETA:15.4min
#   [137,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.6 PE/s | retries:0 | ETA:15.3min
#   [138,000/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 178.0 PE/s | retries:0 | ETA:15.2min
#   [138,500/300,765] ok:485 fail:15 | p50:46ms avg:52ms | 178.3 PE/s | retries:0 | ETA:15.2min
#   [139,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 178.7 PE/s | retries:0 | ETA:15.1min
#   [139,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 179.0 PE/s | retries:0 | ETA:15.0min
#   [140,000/300,765] ok:489 fail:11 | p50:46ms avg:52ms | 179.4 PE/s | retries:0 | ETA:14.9min
#     💾 checkpoint saved (140,000 PEs)
#   [140,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 175.9 PE/s | retries:0 | ETA:15.2min
#   [141,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 176.3 PE/s | retries:0 | ETA:15.1min
#   [141,500/300,765] ok:487 fail:13 | p50:46ms avg:52ms | 176.6 PE/s | retries:0 | ETA:15.0min
#   [142,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 177.0 PE/s | retries:0 | ETA:15.0min
#   [142,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 177.3 PE/s | retries:0 | ETA:14.9min
#   [143,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.7 PE/s | retries:0 | ETA:14.8min
#   [143,500/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 178.0 PE/s | retries:0 | ETA:14.7min
#   [144,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 178.4 PE/s | retries:0 | ETA:14.6min
#   [144,500/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 178.6 PE/s | retries:0 | ETA:14.6min
#   [145,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 178.9 PE/s | retries:0 | ETA:14.5min
#     💾 checkpoint saved (145,000 PEs)
#   [145,500/300,765] ok:485 fail:15 | p50:46ms avg:52ms | 175.4 PE/s | retries:0 | ETA:14.8min
#   [146,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 175.7 PE/s | retries:0 | ETA:14.7min
#   [146,500/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 176.1 PE/s | retries:0 | ETA:14.6min
#   [147,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 176.5 PE/s | retries:0 | ETA:14.5min
#   [147,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 176.8 PE/s | retries:0 | ETA:14.5min
#   [148,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.2 PE/s | retries:0 | ETA:14.4min
#   [148,500/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 177.5 PE/s | retries:0 | ETA:14.3min
#   [149,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 177.8 PE/s | retries:0 | ETA:14.2min
#   [149,500/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 178.2 PE/s | retries:0 | ETA:14.1min
#   [150,000/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 178.5 PE/s | retries:0 | ETA:14.1min
#     💾 checkpoint saved (150,000 PEs)
#   [150,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 175.1 PE/s | retries:0 | ETA:14.3min
#   [151,000/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 175.4 PE/s | retries:0 | ETA:14.2min
#   [151,500/300,765] ok:493 fail:7 | p50:46ms avg:52ms | 175.8 PE/s | retries:0 | ETA:14.2min
#   [152,000/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 176.1 PE/s | retries:0 | ETA:14.1min
#   [152,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 176.4 PE/s | retries:0 | ETA:14.0min
#   [153,000/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 176.6 PE/s | retries:0 | ETA:13.9min
#   [153,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.0 PE/s | retries:0 | ETA:13.9min
#   [154,000/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 177.3 PE/s | retries:0 | ETA:13.8min
#   [154,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 177.6 PE/s | retries:0 | ETA:13.7min
#   [155,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 178.0 PE/s | retries:0 | ETA:13.7min
#     💾 checkpoint saved (155,000 PEs)
#   [155,500/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 174.6 PE/s | retries:0 | ETA:13.9min
#   [156,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.9 PE/s | retries:0 | ETA:13.8min
#   [156,500/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 175.2 PE/s | retries:0 | ETA:13.7min
#   [157,000/300,765] ok:492 fail:8 | p50:46ms avg:52ms | 175.5 PE/s | retries:0 | ETA:13.7min
#   [157,500/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 175.8 PE/s | retries:0 | ETA:13.6min
#   [158,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 176.1 PE/s | retries:0 | ETA:13.5min
#   [158,500/300,765] ok:490 fail:10 | p50:46ms avg:52ms | 176.3 PE/s | retries:0 | ETA:13.4min
#   [159,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 176.7 PE/s | retries:0 | ETA:13.4min
#   [159,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 176.9 PE/s | retries:0 | ETA:13.3min
#   [160,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 177.2 PE/s | retries:0 | ETA:13.2min
#     💾 checkpoint saved (160,000 PEs)
#   [160,500/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.0 PE/s | retries:0 | ETA:13.4min
#   [161,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.3 PE/s | retries:0 | ETA:13.4min
#   [161,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 174.7 PE/s | retries:0 | ETA:13.3min
#   [162,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 175.0 PE/s | retries:0 | ETA:13.2min
#   [162,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 175.2 PE/s | retries:0 | ETA:13.2min
#   [163,000/300,765] ok:489 fail:11 | p50:46ms avg:52ms | 175.5 PE/s | retries:0 | ETA:13.1min
#   [163,500/300,765] ok:498 fail:2 | p50:46ms avg:52ms | 175.8 PE/s | retries:0 | ETA:13.0min
#   [164,000/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 176.0 PE/s | retries:0 | ETA:12.9min
#   [164,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 176.3 PE/s | retries:0 | ETA:12.9min
#   [165,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 176.7 PE/s | retries:0 | ETA:12.8min
#     💾 checkpoint saved (165,000 PEs)
#   [165,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 173.8 PE/s | retries:0 | ETA:13.0min
#   [166,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.1 PE/s | retries:0 | ETA:12.9min
#   [166,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 174.4 PE/s | retries:0 | ETA:12.8min
#   [167,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 174.7 PE/s | retries:0 | ETA:12.8min
#   [167,500/300,765] ok:496 fail:4 | p50:46ms avg:53ms | 174.9 PE/s | retries:0 | ETA:12.7min
#   [168,000/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 175.3 PE/s | retries:0 | ETA:12.6min
#   [168,500/300,765] ok:494 fail:6 | p50:46ms avg:52ms | 175.6 PE/s | retries:0 | ETA:12.6min
#   [169,000/300,765] ok:496 fail:4 | p50:46ms avg:52ms | 175.9 PE/s | retries:0 | ETA:12.5min
#   [169,500/300,765] ok:497 fail:3 | p50:46ms avg:52ms | 176.2 PE/s | retries:0 | ETA:12.4min
#   [170,000/300,765] ok:495 fail:5 | p50:46ms avg:52ms | 176.5 PE/s | retries:0 | ETA:12.3min
#     💾 checkpoint saved (170,000 PEs)
#   [170,500/300,765] ok:497 fail:3 | p50:46ms avg:53ms | 173.6 PE/s | retries:0 | ETA:12.5min
#   [171,000/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 173.9 PE/s | retries:0 | ETA:12.4min
#   [171,500/300,765] ok:491 fail:9 | p50:46ms avg:52ms | 174.2 PE/s | retries:0 | ETA:12.4min
#   [172,000/300,765] ok:489 fail:11 | p50:46ms avg:53ms | 174.5 PE/s | retries:0 | ETA:12.3min
#   [172,500/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 174.6 PE/s | retries:0 | ETA:12.2min
#   [173,000/300,765] ok:489 fail:11 | p50:46ms avg:53ms | 174.9 PE/s | retries:0 | ETA:12.2min
#   [173,500/300,765] ok:497 fail:3 | p50:46ms avg:53ms | 175.2 PE/s | retries:0 | ETA:12.1min
#   [174,000/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 175.5 PE/s | retries:0 | ETA:12.0min
#   [174,500/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 175.8 PE/s | retries:0 | ETA:12.0min
#   [175,000/300,765] ok:496 fail:4 | p50:46ms avg:53ms | 176.1 PE/s | retries:0 | ETA:11.9min
#     💾 checkpoint saved (175,000 PEs)
#   [175,500/300,765] ok:498 fail:2 | p50:46ms avg:53ms | 172.5 PE/s | retries:0 | ETA:12.1min
#   [176,000/300,765] ok:489 fail:11 | p50:46ms avg:53ms | 172.7 PE/s | retries:0 | ETA:12.0min
#   [176,500/300,765] ok:494 fail:6 | p50:46ms avg:53ms | 172.9 PE/s | retries:0 | ETA:12.0min
#   [177,000/300,765] ok:498 fail:2 | p50:46ms avg:53ms | 173.2 PE/s | retries:0 | ETA:11.9min
#   [177,500/300,765] ok:494 fail:6 | p50:46ms avg:53ms | 173.3 PE/s | retries:0 | ETA:11.9min
#   [178,000/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 173.6 PE/s | retries:0 | ETA:11.8min
#   [178,500/300,765] ok:498 fail:2 | p50:46ms avg:53ms | 173.8 PE/s | retries:0 | ETA:11.7min
#   [179,000/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 174.0 PE/s | retries:0 | ETA:11.7min
#   [179,500/300,765] ok:492 fail:8 | p50:46ms avg:53ms | 174.3 PE/s | retries:0 | ETA:11.6min
#   [180,000/300,765] ok:488 fail:12 | p50:46ms avg:53ms | 174.5 PE/s | retries:0 | ETA:11.5min
#     💾 checkpoint saved (180,000 PEs)
#   [180,500/300,765] ok:498 fail:2 | p50:46ms avg:53ms | 169.5 PE/s | retries:0 | ETA:11.8min
#   [181,000/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 169.7 PE/s | retries:0 | ETA:11.8min
#   [181,500/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 170.0 PE/s | retries:0 | ETA:11.7min
#   [182,000/300,765] ok:497 fail:3 | p50:46ms avg:53ms | 170.2 PE/s | retries:0 | ETA:11.6min
#   [182,500/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 170.4 PE/s | retries:0 | ETA:11.6min
#   [183,000/300,765] ok:496 fail:4 | p50:46ms avg:53ms | 170.6 PE/s | retries:0 | ETA:11.5min
#   [183,500/300,765] ok:496 fail:4 | p50:46ms avg:53ms | 170.9 PE/s | retries:0 | ETA:11.4min
#   [184,000/300,765] ok:491 fail:9 | p50:46ms avg:53ms | 171.1 PE/s | retries:0 | ETA:11.4min
#   [184,500/300,765] ok:498 fail:2 | p50:46ms avg:53ms | 171.3 PE/s | retries:0 | ETA:11.3min
#   [185,000/300,765] ok:492 fail:8 | p50:46ms avg:53ms | 171.5 PE/s | retries:0 | ETA:11.2min
#     💾 checkpoint saved (185,000 PEs)
#   [185,500/300,765] ok:496 fail:4 | p50:46ms avg:53ms | 168.4 PE/s | retries:0 | ETA:11.4min
#   [186,000/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 168.7 PE/s | retries:0 | ETA:11.3min
#   [186,500/300,765] ok:500 fail:0 | p50:46ms avg:53ms | 169.0 PE/s | retries:0 | ETA:11.3min
#   [187,000/300,765] ok:494 fail:6 | p50:46ms avg:53ms | 169.2 PE/s | retries:0 | ETA:11.2min
#   [187,500/300,765] ok:495 fail:5 | p50:46ms avg:53ms | 169.4 PE/s | retries:0 | ETA:11.1min
#   [188,000/300,765] ok:493 fail:7 | p50:46ms avg:53ms | 169.7 PE/s | retries:0 | ETA:11.1min
#   [188,500/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 169.9 PE/s | retries:0 | ETA:11.0min
#   [189,000/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 170.1 PE/s | retries:0 | ETA:10.9min
#   [189,500/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 170.4 PE/s | retries:0 | ETA:10.9min
#   [190,000/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 170.7 PE/s | retries:0 | ETA:10.8min
#     💾 checkpoint saved (190,000 PEs)
#   [190,500/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 168.2 PE/s | retries:0 | ETA:10.9min
#   [191,000/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 168.4 PE/s | retries:0 | ETA:10.9min
#   [191,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 168.7 PE/s | retries:0 | ETA:10.8min
#   [192,000/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 168.9 PE/s | retries:0 | ETA:10.7min
#   [192,500/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 169.2 PE/s | retries:0 | ETA:10.7min
#   [193,000/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 169.4 PE/s | retries:0 | ETA:10.6min
#   [193,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 169.7 PE/s | retries:0 | ETA:10.5min
#   [194,000/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 169.9 PE/s | retries:0 | ETA:10.5min
#   [194,500/300,765] ok:493 fail:7 | p50:47ms avg:53ms | 170.2 PE/s | retries:0 | ETA:10.4min
#   [195,000/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 170.4 PE/s | retries:0 | ETA:10.3min
#     💾 checkpoint saved (195,000 PEs)
#   [195,500/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 168.1 PE/s | retries:0 | ETA:10.4min
#   [196,000/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 168.3 PE/s | retries:0 | ETA:10.4min
#   [196,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 168.6 PE/s | retries:0 | ETA:10.3min
#   [197,000/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 168.8 PE/s | retries:0 | ETA:10.2min
#   [197,500/300,765] ok:494 fail:6 | p50:47ms avg:53ms | 169.0 PE/s | retries:0 | ETA:10.2min
#   [198,000/300,765] ok:492 fail:8 | p50:47ms avg:53ms | 169.2 PE/s | retries:0 | ETA:10.1min
#   [198,500/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 169.5 PE/s | retries:0 | ETA:10.1min
#   [199,000/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 169.7 PE/s | retries:0 | ETA:10.0min
#   [199,500/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 170.0 PE/s | retries:0 | ETA:9.9min
#   [200,000/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 170.2 PE/s | retries:0 | ETA:9.9min
#     💾 checkpoint saved (200,000 PEs)
#   [200,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 166.3 PE/s | retries:0 | ETA:10.0min
#   [201,000/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 166.5 PE/s | retries:0 | ETA:10.0min
#   [201,500/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 166.7 PE/s | retries:0 | ETA:9.9min
#   [202,000/300,765] ok:497 fail:3 | p50:47ms avg:53ms | 166.8 PE/s | retries:0 | ETA:9.9min
#   [202,500/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 167.0 PE/s | retries:0 | ETA:9.8min
#   [203,000/300,765] ok:496 fail:4 | p50:47ms avg:53ms | 167.2 PE/s | retries:0 | ETA:9.7min
#   [203,500/300,765] ok:499 fail:1 | p50:47ms avg:53ms | 167.4 PE/s | retries:0 | ETA:9.7min
#   [204,000/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 167.6 PE/s | retries:0 | ETA:9.6min
#   [204,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 167.8 PE/s | retries:0 | ETA:9.6min
#   [205,000/300,765] ok:495 fail:5 | p50:47ms avg:53ms | 168.0 PE/s | retries:0 | ETA:9.5min
#     💾 checkpoint saved (205,000 PEs)
#   [205,500/300,765] ok:498 fail:2 | p50:47ms avg:53ms | 165.0 PE/s | retries:0 | ETA:9.6min
#   [206,000/300,765] ok:500 fail:0 | p50:47ms avg:53ms | 165.2 PE/s | retries:0 | ETA:9.6min
#   [206,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:9.5min
#   [207,000/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:9.4min
#   [207,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:9.4min
#   [208,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 165.9 PE/s | retries:0 | ETA:9.3min
#   [208,500/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 166.2 PE/s | retries:0 | ETA:9.3min
#   [209,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 166.4 PE/s | retries:0 | ETA:9.2min
#   [209,500/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 166.6 PE/s | retries:0 | ETA:9.1min
#   [210,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 166.9 PE/s | retries:0 | ETA:9.1min
#     💾 checkpoint saved (210,000 PEs)
#   [210,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:9.1min
#   [211,000/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:9.1min
#   [211,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:9.0min
#   [212,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:8.9min
#   [212,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:8.9min
#   [213,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 165.9 PE/s | retries:0 | ETA:8.8min
#   [213,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 166.2 PE/s | retries:0 | ETA:8.8min
#   [214,000/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 166.3 PE/s | retries:0 | ETA:8.7min
#   [214,500/300,765] ok:492 fail:8 | p50:47ms avg:54ms | 166.5 PE/s | retries:0 | ETA:8.6min
#   [215,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 166.7 PE/s | retries:0 | ETA:8.6min
#     💾 checkpoint saved (215,000 PEs)
#   [215,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:8.6min
#   [216,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:8.6min
#   [216,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:8.5min
#   [217,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.4 PE/s | retries:0 | ETA:8.4min
#   [217,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:8.4min
#   [218,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.8 PE/s | retries:0 | ETA:8.3min
#   [218,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 166.0 PE/s | retries:0 | ETA:8.3min
#   [219,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 166.2 PE/s | retries:0 | ETA:8.2min
#   [219,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 166.4 PE/s | retries:0 | ETA:8.1min
#   [220,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 166.6 PE/s | retries:0 | ETA:8.1min
#     💾 checkpoint saved (220,000 PEs)
#   [220,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:8.1min
#   [221,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:8.1min
#   [221,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:8.0min
#   [222,000/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:7.9min
#   [222,500/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:7.9min
#   [223,000/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:7.8min
#   [223,500/300,765] ok:494 fail:6 | p50:47ms avg:54ms | 165.9 PE/s | retries:0 | ETA:7.8min
#   [224,000/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 166.1 PE/s | retries:0 | ETA:7.7min
#   [224,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 166.3 PE/s | retries:0 | ETA:7.6min
#   [225,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 166.5 PE/s | retries:0 | ETA:7.6min
#     💾 checkpoint saved (225,000 PEs)
#   [225,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:7.6min
#   [226,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 164.8 PE/s | retries:0 | ETA:7.6min
#   [226,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.0 PE/s | retries:0 | ETA:7.5min
#   [227,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 165.2 PE/s | retries:0 | ETA:7.4min
#   [227,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.4 PE/s | retries:0 | ETA:7.4min
#   [228,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.6 PE/s | retries:0 | ETA:7.3min
#   [228,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.8 PE/s | retries:0 | ETA:7.3min
#   [229,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 166.0 PE/s | retries:0 | ETA:7.2min
#   [229,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 166.2 PE/s | retries:0 | ETA:7.1min
#   [230,000/300,765] ok:493 fail:7 | p50:47ms avg:54ms | 166.4 PE/s | retries:0 | ETA:7.1min
#     💾 checkpoint saved (230,000 PEs)
#   [230,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:7.1min
#   [231,000/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:7.1min
#   [231,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:7.0min
#   [232,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:6.9min
#   [232,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:6.9min
#   [233,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:6.8min
#   [233,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:6.8min
#   [234,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.9 PE/s | retries:0 | ETA:6.7min
#   [234,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 166.1 PE/s | retries:0 | ETA:6.7min
#   [235,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 166.3 PE/s | retries:0 | ETA:6.6min
#     💾 checkpoint saved (235,000 PEs)
#   [235,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.4 PE/s | retries:0 | ETA:6.6min
#   [236,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.6 PE/s | retries:0 | ETA:6.6min
#   [236,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:6.5min
#   [237,000/300,765] ok:494 fail:6 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:6.4min
#   [237,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:6.4min
#   [238,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:6.3min
#   [238,500/300,765] ok:494 fail:6 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:6.3min
#   [239,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:6.2min
#   [239,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.9 PE/s | retries:0 | ETA:6.2min
#   [240,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 166.1 PE/s | retries:0 | ETA:6.1min
#     💾 checkpoint saved (240,000 PEs)
#   [240,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.1 PE/s | retries:0 | ETA:6.1min
#   [241,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.3 PE/s | retries:0 | ETA:6.1min
#   [241,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:6.0min
#   [242,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:5.9min
#   [242,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:5.9min
#   [243,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.1 PE/s | retries:0 | ETA:5.8min
#   [243,500/300,765] ok:496 fail:4 | p50:47ms avg:54ms | 165.2 PE/s | retries:0 | ETA:5.8min
#   [244,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.3 PE/s | retries:0 | ETA:5.7min
#   [244,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.5 PE/s | retries:0 | ETA:5.7min
#   [245,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.7 PE/s | retries:0 | ETA:5.6min
#     💾 checkpoint saved (245,000 PEs)
#   [245,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.8 PE/s | retries:0 | ETA:5.6min
#   [246,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.0 PE/s | retries:0 | ETA:5.6min
#   [246,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.1 PE/s | retries:0 | ETA:5.5min
#   [247,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.3 PE/s | retries:0 | ETA:5.5min
#   [247,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:5.4min
#   [248,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:5.3min
#   [248,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:5.3min
#   [249,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 165.0 PE/s | retries:0 | ETA:5.2min
#   [249,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.2 PE/s | retries:0 | ETA:5.2min
#   [250,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 165.4 PE/s | retries:0 | ETA:5.1min
#     💾 checkpoint saved (250,000 PEs)
#   [250,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.5 PE/s | retries:0 | ETA:5.1min
#   [251,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.6 PE/s | retries:0 | ETA:5.1min
#   [251,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 163.8 PE/s | retries:0 | ETA:5.0min
#   [252,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.0 PE/s | retries:0 | ETA:5.0min
#   [252,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 164.2 PE/s | retries:0 | ETA:4.9min
#   [253,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.4 PE/s | retries:0 | ETA:4.8min
#   [253,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:4.8min
#   [254,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:4.7min
#   [254,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.9 PE/s | retries:0 | ETA:4.7min
#   [255,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 165.0 PE/s | retries:0 | ETA:4.6min
#     💾 checkpoint saved (255,000 PEs)
#   [255,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.1 PE/s | retries:0 | ETA:4.6min
#   [256,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.3 PE/s | retries:0 | ETA:4.6min
#   [256,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.5 PE/s | retries:0 | ETA:4.5min
#   [257,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.7 PE/s | retries:0 | ETA:4.5min
#   [257,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.9 PE/s | retries:0 | ETA:4.4min
#   [258,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.0 PE/s | retries:0 | ETA:4.3min
#   [258,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.2 PE/s | retries:0 | ETA:4.3min
#   [259,000/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 164.4 PE/s | retries:0 | ETA:4.2min
#   [259,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 164.6 PE/s | retries:0 | ETA:4.2min
#   [260,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.7 PE/s | retries:0 | ETA:4.1min
#     💾 checkpoint saved (260,000 PEs)
#   [260,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 162.9 PE/s | retries:0 | ETA:4.1min
#   [261,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.0 PE/s | retries:0 | ETA:4.1min
#   [261,500/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 163.2 PE/s | retries:0 | ETA:4.0min
#   [262,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.4 PE/s | retries:0 | ETA:4.0min
#   [262,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.6 PE/s | retries:0 | ETA:3.9min
#   [263,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.8 PE/s | retries:0 | ETA:3.8min
#   [263,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.9 PE/s | retries:0 | ETA:3.8min
#   [264,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.1 PE/s | retries:0 | ETA:3.7min
#   [264,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.3 PE/s | retries:0 | ETA:3.7min
#   [265,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 164.5 PE/s | retries:0 | ETA:3.6min
#     💾 checkpoint saved (265,000 PEs)
#   [265,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.7 PE/s | retries:0 | ETA:3.6min
#   [266,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.9 PE/s | retries:0 | ETA:3.6min
#   [266,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.0 PE/s | retries:0 | ETA:3.5min
#   [267,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.2 PE/s | retries:0 | ETA:3.4min
#   [267,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.3 PE/s | retries:0 | ETA:3.4min
#   [268,000/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 163.4 PE/s | retries:0 | ETA:3.3min
#   [268,500/300,765] ok:495 fail:5 | p50:47ms avg:54ms | 163.5 PE/s | retries:0 | ETA:3.3min
#   [269,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.7 PE/s | retries:0 | ETA:3.2min
#   [269,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.8 PE/s | retries:0 | ETA:3.2min
#   [270,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 164.0 PE/s | retries:0 | ETA:3.1min
#     💾 checkpoint saved (270,000 PEs)
#   [270,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.2 PE/s | retries:0 | ETA:3.1min
#   [271,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.4 PE/s | retries:0 | ETA:3.1min
#   [271,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.6 PE/s | retries:0 | ETA:3.0min
#   [272,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.7 PE/s | retries:0 | ETA:2.9min
#   [272,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.9 PE/s | retries:0 | ETA:2.9min
#   [273,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.1 PE/s | retries:0 | ETA:2.8min
#   [273,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.3 PE/s | retries:0 | ETA:2.8min
#   [274,000/300,765] ok:497 fail:3 | p50:47ms avg:54ms | 163.4 PE/s | retries:0 | ETA:2.7min
#   [274,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.5 PE/s | retries:0 | ETA:2.7min
#   [275,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.6 PE/s | retries:0 | ETA:2.6min
#     💾 checkpoint saved (275,000 PEs)
#   [275,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 161.9 PE/s | retries:0 | ETA:2.6min
#   [276,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.1 PE/s | retries:0 | ETA:2.5min
#   [276,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.2 PE/s | retries:0 | ETA:2.5min
#   [277,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.4 PE/s | retries:0 | ETA:2.4min
#   [277,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.6 PE/s | retries:0 | ETA:2.4min
#   [278,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.7 PE/s | retries:0 | ETA:2.3min
#   [278,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 162.8 PE/s | retries:0 | ETA:2.3min
#   [279,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.0 PE/s | retries:0 | ETA:2.2min
#   [279,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.2 PE/s | retries:0 | ETA:2.2min
#   [280,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 163.3 PE/s | retries:0 | ETA:2.1min
#     💾 checkpoint saved (280,000 PEs)
#   [280,500/300,765] ok:498 fail:2 | p50:47ms avg:54ms | 161.6 PE/s | retries:0 | ETA:2.1min
#   [281,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 161.8 PE/s | retries:0 | ETA:2.0min
#   [281,500/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 161.9 PE/s | retries:0 | ETA:2.0min
#   [282,000/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.1 PE/s | retries:0 | ETA:1.9min
#   [282,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.3 PE/s | retries:0 | ETA:1.9min
#   [283,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.4 PE/s | retries:0 | ETA:1.8min
#   [283,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.6 PE/s | retries:0 | ETA:1.8min
#   [284,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 162.8 PE/s | retries:0 | ETA:1.7min
#   [284,500/300,765] ok:499 fail:1 | p50:47ms avg:54ms | 162.9 PE/s | retries:0 | ETA:1.7min
#   [285,000/300,765] ok:500 fail:0 | p50:47ms avg:54ms | 163.1 PE/s | retries:0 | ETA:1.6min
#     💾 checkpoint saved (285,000 PEs)
#   [285,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.5 PE/s | retries:0 | ETA:1.6min
#   [286,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.7 PE/s | retries:0 | ETA:1.5min
#   [286,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.8 PE/s | retries:0 | ETA:1.5min
#   [287,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.0 PE/s | retries:0 | ETA:1.4min
#   [287,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.2 PE/s | retries:0 | ETA:1.4min
#   [288,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.3 PE/s | retries:0 | ETA:1.3min
#   [288,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.5 PE/s | retries:0 | ETA:1.3min
#   [289,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.6 PE/s | retries:0 | ETA:1.2min
#   [289,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.8 PE/s | retries:0 | ETA:1.2min
#   [290,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 163.0 PE/s | retries:0 | ETA:1.1min
#     💾 checkpoint saved (290,000 PEs)
#   [290,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.5 PE/s | retries:0 | ETA:1.1min
#   [291,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.6 PE/s | retries:0 | ETA:1.0min
#   [291,500/300,765] ok:498 fail:2 | p50:46ms avg:54ms | 161.8 PE/s | retries:0 | ETA:1.0min
#   [292,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.8 PE/s | retries:0 | ETA:0.9min
#   [292,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.9 PE/s | retries:0 | ETA:0.9min
#   [293,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.1 PE/s | retries:0 | ETA:0.8min
#   [293,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.2 PE/s | retries:0 | ETA:0.7min
#   [294,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.4 PE/s | retries:0 | ETA:0.7min
#   [294,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.5 PE/s | retries:0 | ETA:0.6min
#   [295,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.7 PE/s | retries:0 | ETA:0.6min
#     💾 checkpoint saved (295,000 PEs)
#   [295,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.1 PE/s | retries:0 | ETA:0.5min
#   [296,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.2 PE/s | retries:0 | ETA:0.5min
#   [296,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.4 PE/s | retries:0 | ETA:0.4min
#   [297,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.5 PE/s | retries:0 | ETA:0.4min
#   [297,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.7 PE/s | retries:0 | ETA:0.3min
#   [298,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 161.8 PE/s | retries:0 | ETA:0.3min
#   [298,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.0 PE/s | retries:0 | ETA:0.2min
#   [299,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.2 PE/s | retries:0 | ETA:0.2min
#   [299,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.3 PE/s | retries:0 | ETA:0.1min
#   [300,000/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 162.5 PE/s | retries:0 | ETA:0.1min
#     💾 checkpoint saved (300,000 PEs)
#   [300,500/300,765] ok:500 fail:0 | p50:46ms avg:54ms | 160.8 PE/s | retries:0 | ETA:0.0min
#   [300,765/300,765] ok:265 fail:0 | p50:46ms avg:54ms | 160.9 PE/s | retries:0 | ETA:0.0min
#
# Processed 449,914 virksomheder, 300,765 produktionsenheder in 1869.7s (31.2min)
# Coordinates found: 298,192, failed: 2,573
#
# --- API Rate Monitor (CONCURRENCY=25) ---
#   Total lookups:   300,765 (1 HTTP call each)
#   Wall-clock:      160.9 PE/sec
#   API latency p50: 46ms
#   API latency avg: 54ms
#   API latency p95: 96ms
#   API latency max: 1758ms
#   Retries used:    0 (0% of lookups)
#   HTTP status codes: {200: 298192, 404: 2544, 502: 29}
#
#   ✓ API latency healthy — could try CONCURRENCY=30

# %%
# flatten to one feature per produktionsenhed and save as GeoJSON
features = []
for cvr_nr, entry in master_data.items():
    virk = entry.get("virksomhed", {})
    for pe in entry.get("produktionsenheder", []):
        lon = pe.get("longitude")
        lat = pe.get("latitude")
        if lon is None or lat is None:
            continue
        features.append({
            "type": "Feature",
            "geometry": {"type": "Point", "coordinates": [lon, lat]},
            "properties": {
                **virk,
                "CVREnhedsId": pe.get("CVREnhedsId"),
                "Adresse": pe.get("Adresse"),
                "pNummer": pe.get("pNummer"),
                "tilknyttetVirksomhedsCVRNummer": pe.get("tilknyttetVirksomhedsCVRNummer"),
                "produktionsenhedStartdato": pe.get("produktionsenhedStartdato"),
                "produktionsenhedOphoersdato": pe.get("produktionsenhedOphoersdato"),
            },
        })

geojson = {"type": "FeatureCollection", "features": features}

output_path = "../data/processed/cvr/CVR_geo_temporal.geojson"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)
print(f"Saved {len(features)} produktionsenheder as GeoJSON to {output_path}")
# Out:
# Saved 298192 produktionsenheder as GeoJSON to ../data/processed/cvr/CVR_geo_temporal.geojson
